# %%
from bs4 import BeautifulSoup
import time
import urllib.request
import requests
import matplotlib.pyplot as plt
import numpy as np
import cv2
from PIL import Image
import os
from keras.models import load_model
from predealimg import Deal_With_TestImg
import h5py as h5
import scipy.io
import time
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ##THSR抓圖區

# %%
#不建議使用mp，抓太快會被高鐵網站ban，32G記憶體約能一次抓100張
def Crawler(model,count):
    session = requests.Session()
    response = session.get('https://irs.thsrc.com.tw/IMINT/', headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36'})
    source = response.content.decode('utf-8')
    soup = BeautifulSoup(source, 'html.parser')
    img = soup.find('img')
    url = 'https://irs.thsrc.com.tw'+img.get('src')
    print(url)
    response = session.get(url, headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36'})
    if not os.path.exists('DLmidterm/crawlimg'):
        os.mkdir('DLmidterm/crawlimg')
        
    with open('DLmidterm/crawlimg/'+str(count)+'.jpg', 'wb') as file:
        file.write(response.content)
        file.flush()
    img=np.asarray(Image.open('DLmidterm/crawlimg/'+str(count)+'.jpg'))
    img=Deal_With_TestImg(count,img,'crawltest')
    x = np.expand_dims(img,axis=0)/255
    x = np.argmax(model.predict(x),axis=2)
    datasheet={"0":"2","1":"3","2":"4","3":'5',"4":'7',"5":'9',"6":'A',"7":'C',"8":'F',"9":'H',"10":'K',"11":'M',"12":'N',"13":'P',"14":'Q',"15":'R',"16":'T',"17":'Y',"18":'Z'}
    pdt=[datasheet[str(i[0])]for i in x] #預測為['A','B','C','D']

    filename=pdt[0]+pdt[1]+pdt[2]+pdt[3]
    if not os.path.exists('DLmidterm/crawlimg/'+filename+'.jpg'):
        os.rename('DLmidterm/crawlimg/'+str(count)+'.jpg','DLmidterm/crawlimg/'+filename+'.jpg')
    else:
        os.remove('DLmidterm/crawlimg/'+str(count)+'.jpg')

# %%
def CrawlerTHSR_TO_Testdataset():
    model=load_model('DLmidterm/models/RMSprop-11-0.9952.h5')
    count=0
    while (count<=100):
        Crawler(model,count)
        count += 1
CrawlerTHSR_TO_Testdataset()
# Out:
# https://irs.thsrc.com.tw/IMINT/captImg/oEXoLl5LNF.jpg
# now is dealing with: 0
# https://irs.thsrc.com.tw/IMINT/captImg/S5ffmLyUeI.jpg
# now is dealing with: 1
# https://irs.thsrc.com.tw/IMINT/captImg/9oZeKL9GbS.jpg
# now is dealing with: 2
# https://irs.thsrc.com.tw/IMINT/captImg/1e2FUoYIdy.jpg
# now is dealing with: 3
# https://irs.thsrc.com.tw/IMINT/captImg/yAaFHVQkzK.jpg
# now is dealing with: 4
# https://irs.thsrc.com.tw/IMINT/captImg/YkdPY9rNQq.jpg
# now is dealing with: 5
# https://irs.thsrc.com.tw/IMINT/captImg/AKa9AcECue.jpg
# now is dealing with: 6
# https://irs.thsrc.com.tw/IMINT/captImg/UCNdeRhwZO.jpg
# now is dealing with: 7
# https://irs.thsrc.com.tw/IMINT/captImg/Ni0mGANQKk.jpg
# now is dealing with: 8
# https://irs.thsrc.com.tw/IMINT/captImg/c9X4u7WNc4.jpg
# now is dealing with: 9
# https://irs.thsrc.com.tw/IMINT/captImg/a8wsPOifJP.jpg
# now is dealing with: 10
# https://irs.thsrc.com.tw/IMINT/captImg/QyDesiO0nb.jpg
# now is dealing with: 11
# https://irs.thsrc.com.tw/IMINT/captImg/fKC8iJekut.jpg
# now is dealing with: 12
# https://irs.thsrc.com.tw/IMINT/captImg/0QkGrp9JEC.jpg
# now is dealing with: 13
# https://irs.thsrc.com.tw/IMINT/captImg/XvmI1ZLvFs.jpg
# now is dealing with: 14
# https://irs.thsrc.com.tw/IMINT/captImg/uGuL0fRbmx.jpg
# now is dealing with: 15
# https://irs.thsrc.com.tw/IMINT/captImg/UCNdeRhwZO.jpg
# now is dealing with: 16
# https://irs.thsrc.com.tw/IMINT/captImg/S5qOrudNd7.jpg
# now is dealing with: 17
# https://irs.thsrc.com.tw/IMINT/captImg/4lXwo5N68C.jpg
# now is dealing with: 18
# https://irs.thsrc.com.tw/IMINT/captImg/6PBDVLiR3H.jpg
# now is dealing with: 19
# https://irs.thsrc.com.tw/IMINT/captImg/uIQLiud6v7.jpg
# now is dealing with: 20
# https://irs.thsrc.com.tw/IMINT/captImg/Ejtw0cjlqT.jpg
# now is dealing with: 21
# https://irs.thsrc.com.tw/IMINT/captImg/JAwFWgg7RJ.jpg
# now is dealing with: 22
# https://irs.thsrc.com.tw/IMINT/captImg/TlGWW24hci.jpg
# now is dealing with: 23
# https://irs.thsrc.com.tw/IMINT/captImg/bM94xmxkG6.jpg
# now is dealing with: 24
# https://irs.thsrc.com.tw/IMINT/captImg/rdturOiInt.jpg
# now is dealing with: 25
# https://irs.thsrc.com.tw/IMINT/captImg/hBi5hABbO7.jpg
# now is dealing with: 26
# https://irs.thsrc.com.tw/IMINT/captImg/DNPEacYEIX.jpg
# now is dealing with: 27
# https://irs.thsrc.com.tw/IMINT/captImg/AslCQrBVCV.jpg
# now is dealing with: 28
# https://irs.thsrc.com.tw/IMINT/captImg/5Aj9npOS43.jpg
# now is dealing with: 29
# https://irs.thsrc.com.tw/IMINT/captImg/A96R0Hb3FN.jpg
# now is dealing with: 30
# https://irs.thsrc.com.tw/IMINT/captImg/hiX8d0K5jH.jpg
# now is dealing with: 31
# https://irs.thsrc.com.tw/IMINT/captImg/k7FCI2aEhM.jpg
# now is dealing with: 32
# https://irs.thsrc.com.tw/IMINT/captImg/pXMMyYbiGU.jpg
# now is dealing with: 33
# https://irs.thsrc.com.tw/IMINT/captImg/RqIl7mK7ih.jpg
# now is dealing with: 34
# https://irs.thsrc.com.tw/IMINT/captImg/7mYQbE6o9z.jpg
# now is dealing with: 35
# https://irs.thsrc.com.tw/IMINT/captImg/iwgCAIwmXA.jpg
# now is dealing with: 36
# https://irs.thsrc.com.tw/IMINT/captImg/uUoRgKIWdb.jpg
# now is dealing with: 37
# https://irs.thsrc.com.tw/IMINT/captImg/x1L6RyNPvU.jpg
# now is dealing with: 38
# https://irs.thsrc.com.tw/IMINT/captImg/HQ978zJ93V.jpg
# now is dealing with: 39
# https://irs.thsrc.com.tw/IMINT/captImg/Gjzg6bpIuN.jpg
# now is dealing with: 40
# https://irs.thsrc.com.tw/IMINT/captImg/6an4Ne8QRP.jpg
# now is dealing with: 41
# https://irs.thsrc.com.tw/IMINT/captImg/5BqfsgQi3q.jpg
# now is dealing with: 42
# https://irs.thsrc.com.tw/IMINT/captImg/X3bXmoCU00.jpg
# now is dealing with: 43
# https://irs.thsrc.com.tw/IMINT/captImg/9E3sB26vGN.jpg
# now is dealing with: 44
# https://irs.thsrc.com.tw/IMINT/captImg/BIGtDPEwt1.jpg
# now is dealing with: 45
# https://irs.thsrc.com.tw/IMINT/captImg/MJ8HOo9Qti.jpg
# now is dealing with: 46
# https://irs.thsrc.com.tw/IMINT/captImg/15ywfIy4E9.jpg
# now is dealing with: 47
# https://irs.thsrc.com.tw/IMINT/captImg/gv3EUVMS5B.jpg
# now is dealing with: 48
# https://irs.thsrc.com.tw/IMINT/captImg/EbAsXe3FXC.jpg
# now is dealing with: 49
# https://irs.thsrc.com.tw/IMINT/captImg/z0h9YfKtyo.jpg
# now is dealing with: 50
# https://irs.thsrc.com.tw/IMINT/captImg/dTTo7ioC1y.jpg
# now is dealing with: 51
# https://irs.thsrc.com.tw/IMINT/captImg/tr2xkgtRad.jpg
# now is dealing with: 52
# https://irs.thsrc.com.tw/IMINT/captImg/fSTtiHphEU.jpg
# now is dealing with: 53
# https://irs.thsrc.com.tw/IMINT/captImg/wLnw51K7ZI.jpg
# now is dealing with: 54
# https://irs.thsrc.com.tw/IMINT/captImg/W47N5rHxxX.jpg
# now is dealing with: 55
# https://irs.thsrc.com.tw/IMINT/captImg/XU2nVXan4u.jpg
# now is dealing with: 56
# https://irs.thsrc.com.tw/IMINT/captImg/iU2UTIwhtV.jpg
# now is dealing with: 57
# https://irs.thsrc.com.tw/IMINT/captImg/gzMdhggFWj.jpg
# now is dealing with: 58
# https://irs.thsrc.com.tw/IMINT/captImg/YmTzF330j5.jpg
# now is dealing with: 59
# https://irs.thsrc.com.tw/IMINT/captImg/YIO4LPxvRZ.jpg
# now is dealing with: 60
# https://irs.thsrc.com.tw/IMINT/captImg/IxgVJRFnZs.jpg
# now is dealing with: 61
# https://irs.thsrc.com.tw/IMINT/captImg/xSSPwwYBBM.jpg
# now is dealing with: 62
# https://irs.thsrc.com.tw/IMINT/captImg/SARnfBjn7p.jpg
# now is dealing with: 63
# https://irs.thsrc.com.tw/IMINT/captImg/bwgDCs464v.jpg
# now is dealing with: 64
# https://irs.thsrc.com.tw/IMINT/captImg/Ejtw0cjlqT.jpg
# now is dealing with: 65
# https://irs.thsrc.com.tw/IMINT/captImg/apnz77aYHC.jpg
# now is dealing with: 66
# https://irs.thsrc.com.tw/IMINT/captImg/yYSeOtlDpo.jpg
# now is dealing with: 67
# https://irs.thsrc.com.tw/IMINT/captImg/sURl7HtUtc.jpg
# now is dealing with: 68
# https://irs.thsrc.com.tw/IMINT/captImg/FPad74JEuL.jpg
# now is dealing with: 69
# https://irs.thsrc.com.tw/IMINT/captImg/F8UHIOIoav.jpg
# now is dealing with: 70
# https://irs.thsrc.com.tw/IMINT/captImg/hiX8d0K5jH.jpg
# now is dealing with: 71
# https://irs.thsrc.com.tw/IMINT/captImg/qn4Afk8s4L.jpg
# now is dealing with: 72
# https://irs.thsrc.com.tw/IMINT/captImg/UysukaeT7B.jpg
# now is dealing with: 73
# https://irs.thsrc.com.tw/IMINT/captImg/j6FG18Sn05.jpg
# now is dealing with: 74
# https://irs.thsrc.com.tw/IMINT/captImg/I2O1KUMKVG.jpg
# now is dealing with: 75
# https://irs.thsrc.com.tw/IMINT/captImg/pjlNSilNNp.jpg
# now is dealing with: 76
# https://irs.thsrc.com.tw/IMINT/captImg/v9GG0smMiu.jpg
# now is dealing with: 77
# https://irs.thsrc.com.tw/IMINT/captImg/s4yIv3LXTd.jpg
# now is dealing with: 78
# https://irs.thsrc.com.tw/IMINT/captImg/KD9LXZDPx8.jpg
# now is dealing with: 79
# https://irs.thsrc.com.tw/IMINT/captImg/UdeokHft5s.jpg
# now is dealing with: 80
# https://irs.thsrc.com.tw/IMINT/captImg/lknLNadP81.jpg
# now is dealing with: 81
# https://irs.thsrc.com.tw/IMINT/captImg/gOCUkExpWd.jpg
# now is dealing with: 82
# https://irs.thsrc.com.tw/IMINT/captImg/efBl78DSyZ.jpg
# now is dealing with: 83
# https://irs.thsrc.com.tw/IMINT/captImg/V6IyLeIo8k.jpg
# now is dealing with: 84
# https://irs.thsrc.com.tw/IMINT/captImg/MNwT7VQZH3.jpg
# now is dealing with: 85
# https://irs.thsrc.com.tw/IMINT/captImg/Dhnr4RpHwd.jpg
# now is dealing with: 86
# https://irs.thsrc.com.tw/IMINT/captImg/kXxDaEUAc2.jpg
# now is dealing with: 87
# https://irs.thsrc.com.tw/IMINT/captImg/fbovRo8Az6.jpg
# now is dealing with: 88
# https://irs.thsrc.com.tw/IMINT/captImg/08kvZzA4Pb.jpg
# now is dealing with: 89
# https://irs.thsrc.com.tw/IMINT/captImg/5BqfsgQi3q.jpg
# now is dealing with: 90
# https://irs.thsrc.com.tw/IMINT/captImg/3rAgr99hBl.jpg
# now is dealing with: 91
# https://irs.thsrc.com.tw/IMINT/captImg/9vuH1oVLeR.jpg
# now is dealing with: 92
# https://irs.thsrc.com.tw/IMINT/captImg/5Ju4cysDum.jpg
# now is dealing with: 93
# https://irs.thsrc.com.tw/IMINT/captImg/aNgeV4ftFx.jpg
# now is dealing with: 94
# https://irs.thsrc.com.tw/IMINT/captImg/H0Z8NdC8kY.jpg
# now is dealing with: 95
# https://irs.thsrc.com.tw/IMINT/captImg/stPAFfqgcI.jpg
# now is dealing with: 96
# https://irs.thsrc.com.tw/IMINT/captImg/oBt5gH0QbE.jpg
# now is dealing with: 97
# https://irs.thsrc.com.tw/IMINT/captImg/isuRnAwKW3.jpg
# now is dealing with: 98
# https://irs.thsrc.com.tw/IMINT/captImg/tYHaU6rE0s.jpg
# now is dealing with: 99
# https://irs.thsrc.com.tw/IMINT/captImg/DegdbEV910.jpg
# now is dealing with: 100

# %% [markdown]
# ##owntest測試區

# %%
#測試owntest
#先把model load進來
model1=load_model("models/Adamax-10-0.9920.h5")
model2=load_model("models/Adamax-18-0.9920.h5")
model3=load_model("models/RMSprop-11-0.9952.h5")
#將y_onehot和x_test變成global加快速度
with h5.File('owntest.h5','r') as file:
        x_test=file.get("x").value/255
data=scipy.io.loadmat("owntest.mat")
y_onehot=data['y_onehot']
filenum=x_test.shape[0]
def ThreeModelTestOwn(model1,model2,model3):
    global filenum
    time_start1=time.time()
    l=[]
    time_end1=time.time()
    time_start2=time.time()
    for i in range(filenum):
        imacc,facc=ThreeModelPredict(model1,model2,model3,i)
        l.append((imacc,facc))
    time_end2=time.time()
    time_start3=time.time()
    sigma=np.asarray(np.sum(np.asarray(l),axis=0))
    imgaccuracy=sigma[0]/filenum
    fourwordccuracy=sigma[1]/(4*filenum)
    print('%d picture total wrong=%d'%(filenum,4*filenum-sigma[1]))
    print('one word accuracy=',fourwordccuracy)
    print('four word accuracy=',imgaccuracy)  
    time_end3=time.time()
    print(time_end1-time_start1)
    print(time_end2-time_start2)
    print(time_end3-time_start3)

def ThreeModelPredict(model1,model2,model3,count):
    global y_onehot,x_test
    y=y_onehot.reshape((int(y_onehot.shape[0]/4),4,19))
    img = x_test[count]
    img = np.expand_dims(img,axis=0)       
    x1,x2,x3=EeachModelPredict(model1,model2,model3,img)
    datasheet={"0":"2","1":"3","2":"4","3":'5',"4":'7',"5":'9',"6":'A',"7":'C',"8":'F',"9":'H',"10":'K',"11":'M',"12":'N',"13":'P',"14":'Q',"15":'R',"16":'T',"17":'Y',"18":'Z'}
    pdt1=[datasheet[str(i[0])]for i in x1] #預測為['A','B','C','D']
    pdt2=[datasheet[str(i[0])]for i in x2]
    pdt3=[datasheet[str(i[0])]for i in x3]
    ans=[datasheet[str(np.argmax(y[count][i]))] for i in range(4)]#答案為['A','B','C','D']
    fouracc=0
    imgacc=0
    #處理三個網路預測的結果，分析哪個為最終結果
    if pdt1==pdt2==pdt3:
        pdt=pdt1
    elif pdt1==pdt2:
        pdt=pdt1
    elif pdt1==pdt3:  
        pdt=pdt1
    elif pdt2==pdt3:  
        pdt=pdt2
    else:
        pdt=pdt3
    #確認有幾個字對
    for ind,letter in enumerate(pdt):
        if letter==ans[ind]:
            fouracc+=1
        else:
            plt.imshow(x_test[count])
            print("number ",count)
            print("prdict=",pdt)
            print("answer=",ans)
            plt.show()
    if pdt==ans:
        imgacc=1
    if count <=40:
        print("number ",count)
        print("prdict=",pdt)
        print("answer=",ans,",wrong words=",4-fouracc)
    return imgacc,fouracc

def EeachModelPredict(model1,model2,model3,img):
    x1 = np.argmax(model1.predict(img),axis=2) #x1:Adamax-10-0.9920.h5
    x2 = np.argmax(model2.predict(img),axis=2) #x2:Adamax-18-0.9920.h5
    x3 = np.argmax(model3.predict(img),axis=2) #x3:RMSprop-11-0.9952.h5
    return x1,x2,x3
ThreeModelTestOwn(model1,model2,model3)
# Out:
# C:\Users\苯異丙胺\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:8: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
# number  0
# prdict= ['2', '7', 'C', 'Z']
# answer= ['2', '7', 'C', 'Z'] ,wrong words= 0
# number  1
# prdict= ['2', '7', 'P', 'A']
# answer= ['2', '7', 'P', 'A'] ,wrong words= 0
# number  2
# prdict= ['2', 'F', 'Z', 'T']
# answer= ['2', 'F', 'Z', 'T'] ,wrong words= 0
# number  3
# prdict= ['2', 'N', 'C', 'R']
# answer= ['2', 'N', 'C', 'R'] ,wrong words= 0
# number  4
# prdict= ['2', 'Z', 'H', 'A']
# answer= ['2', 'Z', 'H', 'A'] ,wrong words= 0
# number  5
# prdict= ['2', 'Z', 'K', '5']
# answer= ['2', 'Z', 'K', '5'] ,wrong words= 0
# number  6
# prdict= ['3', '3', 'Q', 'F']
# answer= ['3', '3', 'Q', 'F'] ,wrong words= 0
# number  7
# prdict= ['3', '9', 'Y', '2']
# answer= ['3', '9', 'Y', '2'] ,wrong words= 0
# number  8
# prdict= ['3', 'F', '9', 'R']
# answer= ['3', 'F', '9', 'R'] ,wrong words= 0
# number  9
# prdict= ['3', 'Q', 'H', '9']
# answer= ['3', 'Q', 'H', '9'] ,wrong words= 0
# number  10
# prdict= ['4', 'F', 'H', 'K']
# answer= ['4', 'F', 'H', 'K'] ,wrong words= 0
# number  11
# prdict= ['4', 'K', 'R', '2']
# answer= ['4', 'K', 'R', '2'] ,wrong words= 0
# number  12
# prdict= ['4', 'N', 'R', 'K']
# answer= ['4', 'N', 'R', 'K'] ,wrong words= 0
# number  13
# prdict= ['4', 'P', 'P', '4']
# answer= ['4', 'P', 'P', '4'] ,wrong words= 0
# number  14
# prdict= ['5', '2', 'Z', '4']
# answer= ['5', '2', 'Z', '4'] ,wrong words= 0
# number  15
# prdict= ['5', '9', '2', 'Y']
# answer= ['5', '9', '2', 'Y'] ,wrong words= 0
# number  16
# prdict= ['5', 'A', 'P', 'A']
# answer= ['5', 'A', 'P', 'A'] ,wrong words= 0
# number  17
# prdict= ['5', 'F', 'F', 'H']
# answer= ['5', 'F', 'F', 'H'] ,wrong words= 0
# number  18
# prdict= ['7', 'C', '3', 'R']
# answer= ['7', 'C', '3', 'R'] ,wrong words= 0
# number  19
# prdict= ['7', 'F', '7', '5']
# answer= ['7', 'F', '7', '5'] ,wrong words= 0
# number  20
# prdict= ['7', 'M', 'Z', 'Z']
# answer= ['7', 'M', 'Z', 'Z'] ,wrong words= 0
# number  21
# prdict= ['7', 'R', 'R', '9']
# answer= ['7', 'R', 'R', '9'] ,wrong words= 0
# number  22
# prdict= ['9', 'C', 'Y', 'K']
# answer= ['9', 'C', 'Y', 'K'] ,wrong words= 0
# number  23
# prdict= ['9', 'H', 'Z', '7']
# answer= ['9', 'H', 'Z', '7'] ,wrong words= 0
# number  24
# prdict= ['9', 'K', 'N', 'K']
# answer= ['9', 'K', 'N', 'K'] ,wrong words= 0
# number  25
# prdict= ['9', 'K', 'T', 'H']
# answer= ['9', 'K', 'T', 'H'] ,wrong words= 0
# number  26
# prdict= ['A', '2', '4', 'C']
# answer= ['A', '2', '4', 'C'] ,wrong words= 0
# number  27
# prdict= ['A', '3', 'C', '3']
# answer= ['A', '3', 'C', '3'] ,wrong words= 0
# number  28
# prdict= ['A', '4', 'P', 'K']
# answer= ['A', '4', 'P', 'K'] ,wrong words= 0
# number  29
# prdict= ['A', 'C', 'N', 'K']
# answer= ['A', 'C', 'N', 'K'] ,wrong words= 0
# number  30
# prdict= ['A', 'F', 'A', 'Z']
# answer= ['A', 'F', 'A', 'Z'] ,wrong words= 0
# number  31
# prdict= ['A', 'P', 'T', 'Q']
# answer= ['A', 'P', 'T', 'Q'] ,wrong words= 0
# number  32
# prdict= ['A', 'Y', 'Y', 'T']
# answer= ['A', 'Y', 'Y', 'T'] ,wrong words= 0
# number  33
# prdict= ['C', '3', '9', '7']
# answer= ['C', '3', '9', '7'] ,wrong words= 0
# number  34
# prdict= ['C', 'Q', 'Z', 'A']
# answer= ['C', 'Q', 'Z', 'A'] ,wrong words= 0
# number  35
# prdict= ['C', 'T', '3', 'C']
# answer= ['C', 'T', '3', 'C'] ,wrong words= 0
# number  36
# prdict= ['F', '4', '7', 'A']
# answer= ['F', '4', '7', 'A'] ,wrong words= 0
# number  37
# prdict= ['F', '4', 'T', '7']
# answer= ['F', '4', 'T', '7'] ,wrong words= 0
# number  38
# prdict= ['F', '9', 'R', '5']
# answer= ['F', '9', 'R', '5'] ,wrong words= 0
# number  39
# prdict= ['F', 'F', 'C', 'C']
# answer= ['F', 'F', 'C', 'C'] ,wrong words= 0
# number  40
# prdict= ['F', 'H', '2', 'A']
# answer= ['F', 'H', '2', 'A'] ,wrong words= 0
# number  58
# prdict= ['N', 'P', 'Z', 'K']
# answer= ['N', 'H', 'Z', 'K']
# 97 picture total wrong=1
# one word accuracy= 0.9974226804123711
# four word accuracy= 0.9896907216494846
# 0.0
# 2.3581442832946777
# 0.0

# %%
#一個model預測owntest
model=load_model("models/RMSprop-11-0.9952.h5")
with h5.File('owntest.h5','r') as file:
        x_test=file.get("x").value/255
data=scipy.io.loadmat("owntest.mat")
y_onehot=data['y_onehot']
filenum=x_test.shape[0]
def OneModelTestOwn(model):
    global filenum
    time_start1=time.time()
    l=[]

    time_end1=time.time()
    time_start2=time.time()
    for i in range(filenum):
        imacc,facc=OneModelPredict(model,i)
        l.append((imacc,facc))
    time_end2=time.time()
    time_start3=time.time()
    sigma=np.asarray(np.sum(np.asarray(l),axis=0))
    imgaccuracy=sigma[0]/filenum
    fourwordccuracy=sigma[1]/(4*filenum)
    print('%d picture total wrong=%d'%(filenum,4*filenum-sigma[1]))
    print('one word accuracy=',fourwordccuracy)
    print('four word accuracy=',imgaccuracy)  
    time_end3=time.time()
    print(time_end1-time_start1)
    print(time_end2-time_start2)
    print(time_end3-time_start3)

def OneModelPredict(model,count):
    global y_onehot,x_test
    y=y_onehot.reshape((int(y_onehot.shape[0]/4),4,19))
    img = x_test[count]
    img = np.expand_dims(img,axis=0) 
    x1 = np.argmax(model.predict(img),axis=2) 
    datasheet={"0":"2","1":"3","2":"4","3":'5',"4":'7',"5":'9',"6":'A',"7":'C',"8":'F',"9":'H',"10":'K',"11":'M',"12":'N',"13":'P',"14":'Q',"15":'R',"16":'T',"17":'Y',"18":'Z'}
    pdt=[datasheet[str(i[0])]for i in x1] #預測為['A','B','C','D']
    ans=[datasheet[str(np.argmax(y[count][i]))] for i in range(4)]#答案為['A','B','C','D']
    fouracc=0
    imgacc=0

    #確認有幾個字對
    for ind,letter in enumerate(pdt):
        if letter==ans[ind]:
            fouracc+=1
        else:
            plt.imshow(x_test[count])
            print("number ",count)
            print("prdict=",pdt)
            print("answer=",ans)
            plt.show()
    if pdt==ans:
        imgacc=1
    if count <=40:
        print("number ",count)
        print("prdict=",pdt)
        print("answer=",ans,",wrong words=",4-fouracc)
    return imgacc,fouracc
OneModelTestOwn(model)
# Out:
# C:\Users\苯異丙胺\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:4: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   after removing the cwd from sys.path.
# number  0
# prdict= ['2', '7', 'C', 'Z']
# answer= ['2', '7', 'C', 'Z'] ,wrong words= 0
# number  1
# prdict= ['2', '7', 'P', 'A']
# answer= ['2', '7', 'P', 'A'] ,wrong words= 0
# number  2
# prdict= ['2', 'F', 'Z', 'T']
# answer= ['2', 'F', 'Z', 'T'] ,wrong words= 0
# number  3
# prdict= ['2', 'N', 'C', 'R']
# answer= ['2', 'N', 'C', 'R'] ,wrong words= 0
# number  4
# prdict= ['2', 'Z', 'H', 'A']
# answer= ['2', 'Z', 'H', 'A'] ,wrong words= 0
# number  5
# prdict= ['2', 'Z', 'K', '5']
# answer= ['2', 'Z', 'K', '5'] ,wrong words= 0
# number  6
# prdict= ['3', '3', 'Q', 'F']
# answer= ['3', '3', 'Q', 'F'] ,wrong words= 0
# number  7
# prdict= ['3', '9', 'Y', '2']
# answer= ['3', '9', 'Y', '2'] ,wrong words= 0
# number  8
# prdict= ['3', 'F', '9', 'R']
# answer= ['3', 'F', '9', 'R'] ,wrong words= 0
# number  9
# prdict= ['3', 'Q', 'H', '9']
# answer= ['3', 'Q', 'H', '9'] ,wrong words= 0
# number  10
# prdict= ['4', 'F', 'H', 'K']
# answer= ['4', 'F', 'H', 'K'] ,wrong words= 0
# number  11
# prdict= ['4', 'K', 'R', '2']
# answer= ['4', 'K', 'R', '2'] ,wrong words= 0
# number  12
# prdict= ['4', 'N', 'R', 'K']
# answer= ['4', 'N', 'R', 'K'] ,wrong words= 0
# number  13
# prdict= ['4', 'P', 'P', '4']
# answer= ['4', 'P', 'P', '4'] ,wrong words= 0
# number  14
# prdict= ['5', '2', 'Z', '4']
# answer= ['5', '2', 'Z', '4'] ,wrong words= 0
# number  15
# prdict= ['5', '9', '2', 'Y']
# answer= ['5', '9', '2', 'Y'] ,wrong words= 0
# number  16
# prdict= ['5', 'A', 'P', 'A']
# answer= ['5', 'A', 'P', 'A'] ,wrong words= 0
# number  17
# prdict= ['5', 'F', 'F', 'H']
# answer= ['5', 'F', 'F', 'H'] ,wrong words= 0
# number  18
# prdict= ['7', 'C', '3', 'R']
# answer= ['7', 'C', '3', 'R'] ,wrong words= 0
# number  19
# prdict= ['7', 'F', '7', '5']
# answer= ['7', 'F', '7', '5'] ,wrong words= 0
# number  20
# prdict= ['7', 'M', 'Z', 'Z']
# answer= ['7', 'M', 'Z', 'Z'] ,wrong words= 0
# number  21
# prdict= ['7', 'R', 'R', '9']
# answer= ['7', 'R', 'R', '9'] ,wrong words= 0
# number  22
# prdict= ['9', 'C', 'Y', 'K']
# answer= ['9', 'C', 'Y', 'K'] ,wrong words= 0
# number  23
# prdict= ['9', 'H', 'Z', '7']
# answer= ['9', 'H', 'Z', '7'] ,wrong words= 0
# number  24
# prdict= ['9', 'K', 'N', 'K']
# answer= ['9', 'K', 'N', 'K'] ,wrong words= 0
# number  25
# prdict= ['9', 'K', 'T', 'H']
# answer= ['9', 'K', 'T', 'H'] ,wrong words= 0
# number  26
# prdict= ['A', '2', '4', 'C']
# answer= ['A', '2', '4', 'C'] ,wrong words= 0
# number  27
# prdict= ['A', '3', 'C', '3']
# answer= ['A', '3', 'C', '3'] ,wrong words= 0
# number  28
# prdict= ['A', '4', 'P', 'K']
# answer= ['A', '4', 'P', 'K'] ,wrong words= 0
# number  29
# prdict= ['A', 'C', 'N', 'K']
# answer= ['A', 'C', 'N', 'K'] ,wrong words= 0
# number  30
# prdict= ['A', 'F', 'A', 'Z']
# answer= ['A', 'F', 'A', 'Z'] ,wrong words= 0
# number  31
# prdict= ['A', 'P', 'T', 'Q']
# answer= ['A', 'P', 'T', 'Q'] ,wrong words= 0
# number  32
# prdict= ['A', 'Y', 'Y', 'T']
# answer= ['A', 'Y', 'Y', 'T'] ,wrong words= 0
# number  33
# prdict= ['C', '3', '9', '7']
# answer= ['C', '3', '9', '7'] ,wrong words= 0
# number  34
# prdict= ['C', 'Q', 'Z', 'A']
# answer= ['C', 'Q', 'Z', 'A'] ,wrong words= 0
# number  35
# prdict= ['C', 'T', '3', 'C']
# answer= ['C', 'T', '3', 'C'] ,wrong words= 0
# number  36
# prdict= ['F', '4', '7', 'A']
# answer= ['F', '4', '7', 'A'] ,wrong words= 0
# number  37
# prdict= ['F', '4', 'T', '7']
# answer= ['F', '4', 'T', '7'] ,wrong words= 0
# number  38
# prdict= ['F', '9', 'R', '5']
# answer= ['F', '9', 'R', '5'] ,wrong words= 0
# number  39
# prdict= ['F', 'F', 'C', 'C']
# answer= ['F', 'F', 'C', 'C'] ,wrong words= 0
# number  40
# prdict= ['F', 'H', '2', 'A']
# answer= ['F', 'H', '2', 'A'] ,wrong words= 0
# 97 picture total wrong=0
# one word accuracy= 1.0
# four word accuracy= 1.0
# 0.0
# 0.6856157779693604
# 0.0010089874267578125

# %% [markdown]
# ##train測試區

# %%
#測試train
#先把model load進來
model1=load_model("models/Adamax-10-0.9920.h5")
model2=load_model("models/Adamax-18-0.9920.h5")
model3=load_model("models/RMSprop-11-0.9952.h5")
#將y_onehot和x_test變成global加快速度
with h5.File('train.h5','r') as file:
        x_test=file.get("x").value/255
data=scipy.io.loadmat("train.mat")
y_onehot=data['y_onehot']
filenum=x_test.shape[0]
def ThreeModelTestTrain(model1,model2,model3):
    global filenum
    time_start1=time.time()
    l=[]
    time_end1=time.time()
    time_start2=time.time()
    for i in range(filenum):
        imacc,facc=ThreeModelPredict(model1,model2,model3,i)
        l.append((imacc,facc))
    time_end2=time.time()
    time_start3=time.time()
    sigma=np.asarray(np.sum(np.asarray(l),axis=0))
    imgaccuracy=sigma[0]/filenum
    fourwordccuracy=sigma[1]/(4*filenum)
    print('%d picture total wrong=%d'%(filenum,4*filenum-sigma[1]))
    print('one word accuracy=',fourwordccuracy)
    print('four word accuracy=',imgaccuracy)  
    time_end3=time.time()
    print(time_end1-time_start1)
    print(time_end2-time_start2)
    print(time_end3-time_start3)

def ThreeModelPredict(model1,model2,model3,count):
    global y_onehot,x_test
    y=y_onehot.reshape((int(y_onehot.shape[0]/4),4,19))
    img = x_test[count]
    img = np.expand_dims(img,axis=0)       
    x1,x2,x3=EeachModelPredict(model1,model2,model3,img)
    datasheet={"0":"2","1":"3","2":"4","3":'5',"4":'7',"5":'9',"6":'A',"7":'C',"8":'F',"9":'H',"10":'K',"11":'M',"12":'N',"13":'P',"14":'Q',"15":'R',"16":'T',"17":'Y',"18":'Z'}
    pdt1=[datasheet[str(i[0])]for i in x1] #預測為['A','B','C','D']
    pdt2=[datasheet[str(i[0])]for i in x2]
    pdt3=[datasheet[str(i[0])]for i in x3]
    ans=[datasheet[str(np.argmax(y[count][i]))] for i in range(4)]#答案為['A','B','C','D']
    fouracc=0
    imgacc=0
    #處理三個網路預測的結果，分析哪個為最終結果
    if pdt1==pdt2==pdt3:
        pdt=pdt1
    elif pdt1==pdt2:
        pdt=pdt1
    elif pdt1==pdt3:  
        pdt=pdt1
    elif pdt2==pdt3:  
        pdt=pdt2
    else:
        pdt=pdt3
    #確認有幾個字對
    for ind,letter in enumerate(pdt):
        if letter==ans[ind]:
            fouracc+=1
        else:
            plt.imshow(x_test[count])
            print("number ",count)
            print("prdict=",pdt)
            print("answer=",ans)
            plt.show()
    if pdt==ans:
        imgacc=1
    if count <=40:
        print("number ",count)
        print("prdict=",pdt)
        print("answer=",ans,",wrong words=",4-fouracc)
    return imgacc,fouracc

def EeachModelPredict(model1,model2,model3,img):
    x1 = np.argmax(model1.predict(img),axis=2) #x1:Adamax-10-0.9920.h5
    x2 = np.argmax(model2.predict(img),axis=2) #x2:Adamax-18-0.9920.h5
    x3 = np.argmax(model3.predict(img),axis=2) #x3:RMSprop-11-0.9952.h5
    return x1,x2,x3
ThreeModelTestTrain(model1,model2,model3)

# %%
#測試train
#先把model load進來
model1=load_model("models/Adamax-10-0.9920.h5")
model2=load_model("models/Adamax-18-0.9920.h5")
model3=load_model("models/RMSprop-11-0.9952.h5")
#將y_onehot和x_test變成global加快速度
with h5.File('test.h5','r') as file:
        x_test=file.get("x").value/255
data=scipy.io.loadmat("train.mat")
y_onehot=data['y_onehot']
filenum=x_test.shape[0]
def ThreeModelTestTrain(model1,model2,model3):
    global filenum
    time_start1=time.time()
    l=[]
    time_end1=time.time()
    time_start2=time.time()
    for i in range(filenum):
        imacc,facc=ThreeModelPredict(model1,model2,model3,i)
        l.append((imacc,facc))
    time_end2=time.time()
    time_start3=time.time()
    sigma=np.asarray(np.sum(np.asarray(l),axis=0))
    imgaccuracy=sigma[0]/filenum
    fourwordccuracy=sigma[1]/(4*filenum)
    print('%d picture total wrong=%d'%(filenum,4*filenum-sigma[1]))
    print('one word accuracy=',fourwordccuracy)
    print('four word accuracy=',imgaccuracy)  
    time_end3=time.time()
    print(time_end1-time_start1)
    print(time_end2-time_start2)
    print(time_end3-time_start3)

def ThreeModelPredict(model1,model2,model3,count):
    global y_onehot,x_test
    y=y_onehot.reshape((int(y_onehot.shape[0]/4),4,19))
    img = x_test[count]
    img = np.expand_dims(img,axis=0)       
    x1,x2,x3=EeachModelPredict(model1,model2,model3,img)
    datasheet={"0":"2","1":"3","2":"4","3":'5',"4":'7',"5":'9',"6":'A',"7":'C',"8":'F',"9":'H',"10":'K',"11":'M',"12":'N',"13":'P',"14":'Q',"15":'R',"16":'T',"17":'Y',"18":'Z'}
    pdt1=[datasheet[str(i[0])]for i in x1] #預測為['A','B','C','D']
    pdt2=[datasheet[str(i[0])]for i in x2]
    pdt3=[datasheet[str(i[0])]for i in x3]
    ans=[datasheet[str(np.argmax(y[count][i]))] for i in range(4)]#答案為['A','B','C','D']
    fouracc=0
    imgacc=0
    #處理三個網路預測的結果，分析哪個為最終結果
    if pdt1==pdt2==pdt3:
        pdt=pdt1
    elif pdt1==pdt2:
        pdt=pdt1
    elif pdt1==pdt3:  
        pdt=pdt1
    elif pdt2==pdt3:  
        pdt=pdt2
    else:
        pdt=pdt3
    #確認有幾個字對
    for ind,letter in enumerate(pdt):
        if letter==ans[ind]:
            fouracc+=1
        else:
            plt.imshow(x_test[count])
            print("number ",count)
            print("prdict=",pdt)
            print("answer=",ans)
            plt.show()
    if pdt==ans:
        imgacc=1
    if count <=40:
        print("number ",count)
        print("prdict=",pdt)
        print("answer=",ans,",wrong words=",4-fouracc)
    return imgacc,fouracc

def EeachModelPredict(model1,model2,model3,img):
    x1 = np.argmax(model1.predict(img),axis=2) #x1:Adamax-10-0.9920.h5
    x2 = np.argmax(model2.predict(img),axis=2) #x2:Adamax-18-0.9920.h5
    x3 = np.argmax(model3.predict(img),axis=2) #x3:RMSprop-11-0.9952.h5
    return x1,x2,x3
ThreeModelTestTrain(model1,model2,model3)

# %% [markdown]
# ##測試test

# %%
#測試test  0.976
#先把model load進來
model1=load_model("models/Adamax-10-0.9920.h5")
model2=load_model("models/Adamax-30-0.9904.h5")
model3=load_model("models/RMSprop-11-0.9952.h5")
#將y_onehot和x_test變成global加快速度
with h5.File('test.h5','r') as file:
        x_test=file.get("x").value/255
data=scipy.io.loadmat("test.mat")
y_onehot=data['y_onehot']
filenum=x_test.shape[0]
def ThreeModelTestTrain(model1,model2,model3):
    global filenum
    time_start1=time.time()
    l=[]
    time_end1=time.time()
    time_start2=time.time()
    for i in range(filenum):
        imacc,facc=ThreeModelPredict(model1,model2,model3,i)
        l.append((imacc,facc))
    time_end2=time.time()
    time_start3=time.time()
    sigma=np.asarray(np.sum(np.asarray(l),axis=0))
    imgaccuracy=sigma[0]/filenum
    fourwordccuracy=sigma[1]/(4*filenum)
    print('%d picture total wrong=%d'%(filenum,4*filenum-sigma[1]))
    print('one word accuracy=',fourwordccuracy)
    print('four word accuracy=',imgaccuracy)  
    time_end3=time.time()
    print(time_end1-time_start1)
    print(time_end2-time_start2)
    print(time_end3-time_start3)

def ThreeModelPredict(model1,model2,model3,count):
    global y_onehot,x_test
    y=y_onehot.reshape((int(y_onehot.shape[0]/4),4,19))
    img = x_test[count]
    img = np.expand_dims(img,axis=0)       
    x1,x2,x3=EeachModelPredict(model1,model2,model3,img)
    datasheet={"0":"2","1":"3","2":"4","3":'5',"4":'7',"5":'9',"6":'A',"7":'C',"8":'F',"9":'H',"10":'K',"11":'M',"12":'N',"13":'P',"14":'Q',"15":'R',"16":'T',"17":'Y',"18":'Z'}
    pdt1=[datasheet[str(i[0])]for i in x1] #預測為['A','B','C','D']
    pdt2=[datasheet[str(i[0])]for i in x2]
    pdt3=[datasheet[str(i[0])]for i in x3]
    ans=[datasheet[str(np.argmax(y[count][i]))] for i in range(4)]#答案為['A','B','C','D']
    fouracc=0
    imgacc=0
    #處理三個網路預測的結果，分析哪個為最終結果
    if pdt1==pdt2==pdt3:
        pdt=pdt1
    elif pdt1==pdt2:
        pdt=pdt1
    elif pdt1==pdt3:  
        pdt=pdt1
    elif pdt2==pdt3:  
        pdt=pdt2
    else:
        pdt=pdt3
    #確認有幾個字對
    for ind,letter in enumerate(pdt):
        if letter==ans[ind]:
            fouracc+=1

    if pdt==ans:
        imgacc=1
#     if count <40:
#         print("number ",count)
#         if count <=5:
#             plt.imshow(x_test[count])
#             plt.show()
#         print("prdict=",pdt)
#         print("answer=",ans,",wrong words=",4-fouracc)
#         if count==39:
#             print("number ",count)
    if fouracc!=4:
        print("number ",count)
        plt.imshow(x_test[count])
        plt.show()
        print("prdict=",pdt)
        print("answer=",ans,",wrong words=",4-fouracc)
    return imgacc,fouracc

def EeachModelPredict(model1,model2,model3,img):
    x1 = np.argmax(model1.predict(img),axis=2) #x1:Adamax-10-0.9920.h5
    x2 = np.argmax(model2.predict(img),axis=2) #x2:Adamax-30-0.9904.h5
    x3 = np.argmax(model3.predict(img),axis=2) #x3:RMSprop-11-0.9952.h5
    return x1,x2,x3
ThreeModelTestTrain(model1,model2,model3)
# Out:
# C:\Users\苯異丙胺\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:8: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
# number  17
# prdict= ['F', '3', '4', 'A']
# answer= ['F', '3', '4', '3'] ,wrong words= 1
# number  27
# prdict= ['A', 'Y', 'R', 'K']
# answer= ['A', 'Y', 'R', '4'] ,wrong words= 1
# number  37
# prdict= ['7', 'K', 'Q', 'M']
# answer= ['7', 'K', 'Q', '5'] ,wrong words= 1
# number  90
# prdict= ['5', 'Q', 'P', 'N']
# answer= ['3', 'Q', 'P', 'N'] ,wrong words= 1
# number  165
# prdict= ['5', 'C', 'N', 'H']
# answer= ['3', 'C', 'N', 'H'] ,wrong words= 1
# number  168
# prdict= ['K', '9', 'K', 'P']
# answer= ['K', '9', 'K', '9'] ,wrong words= 1
# number  323
# prdict= ['A', '2', 'H', 'Q']
# answer= ['A', 'Z', 'H', 'Q'] ,wrong words= 1
# number  454
# prdict= ['9', 'H', 'R', 'K']
# answer= ['9', 'H', 'R', 'Q'] ,wrong words= 1
# number  502
# prdict= ['T', 'P', 'T', '3']
# answer= ['7', 'P', 'T', '3'] ,wrong words= 1
# number  641
# prdict= ['2', 'M', '4', 'K']
# answer= ['Z', 'M', '4', 'K'] ,wrong words= 1
# number  687
# prdict= ['Y', 'H', 'K', 'T']
# answer= ['Y', 'M', 'K', 'T'] ,wrong words= 1
# number  695
# prdict= ['5', 'Q', 'Y', '2']
# answer= ['5', 'Q', 'Y', 'Z'] ,wrong words= 1
# number  762
# prdict= ['Z', 'H', '2', '3']
# answer= ['Z', 'M', '2', '3'] ,wrong words= 1
# number  782
# prdict= ['P', 'F', 'C', 'Z']
# answer= ['F', 'F', 'C', 'Z'] ,wrong words= 1
# number  859
# prdict= ['A', 'P', '4', 'P']
# answer= ['A', 'F', '4', 'P'] ,wrong words= 1
# number  927
# prdict= ['C', '3', 'N', '3']
# answer= ['C', '3', 'N', 'C'] ,wrong words= 1
# number  1112
# prdict= ['5', 'A', 'C', 'R']
# answer= ['3', 'A', 'C', 'R'] ,wrong words= 1
# number  1174
# prdict= ['H', 'A', 'Z', 'Y']
# answer= ['M', 'A', 'Z', 'Y'] ,wrong words= 1
# number  1243
# prdict= ['T', 'A', 'R', '5']
# answer= ['7', 'A', 'R', '5'] ,wrong words= 1
# number  1292
# prdict= ['5', 'Z', '7', '3']
# answer= ['3', 'Z', '7', '3'] ,wrong words= 1
# number  1306
# prdict= ['2', 'Y', '9', 'H']
# answer= ['Z', 'Y', '9', 'H'] ,wrong words= 1
# number  1313
# prdict= ['K', '2', 'Z', 'P']
# answer= ['K', 'Z', 'Z', 'P'] ,wrong words= 1
# number  1324
# prdict= ['2', 'M', 'K', 'K']
# answer= ['Z', 'M', 'K', 'K'] ,wrong words= 1
# number  1335
# prdict= ['K', 'A', 'Z', 'A']
# answer= ['9', '7', '7', '3'] ,wrong words= 4
# number  1336
# prdict= ['7', 'F', 'H', 'M']
# answer= ['R', 'F', 'K', '3'] ,wrong words= 3
# number  1337
# prdict= ['N', '7', '7', 'M']
# answer= ['Z', 'M', '4', 'N'] ,wrong words= 4
# number  1338
# prdict= ['K', 'Y', '4', 'T']
# answer= ['A', 'F', '4', 'H'] ,wrong words= 3
# number  1348
# prdict= ['7', '3', '2', 'F']
# answer= ['7', '4', '3', 'F'] ,wrong words= 2
# number  1352
# prdict= ['2', 'R', 'M', '9']
# answer= ['Z', 'R', 'M', '9'] ,wrong words= 1
# number  1354
# prdict= ['N', '2', 'H', 'A']
# answer= ['N', 'Z', 'H', 'A'] ,wrong words= 1
# number  1358
# prdict= ['R', '2', 'P', '5']
# answer= ['R', 'Z', 'P', '5'] ,wrong words= 1
# number  1448
# prdict= ['2', 'H', 'K', 'F']
# answer= ['Z', 'H', 'K', 'F'] ,wrong words= 1
# number  1481
# prdict= ['F', 'K', 'N', 'M']
# answer= ['F', 'Q', 'N', 'M'] ,wrong words= 1
# number  1488
# prdict= ['2', 'C', 'P', 'K']
# answer= ['Z', 'C', 'P', 'K'] ,wrong words= 1
# number  1526
# prdict= ['4', 'Z', '2', 'A']
# answer= ['4', 'Z', 'A', '2'] ,wrong words= 2
# number  1568
# prdict= ['F', 'P', '4', '5']
# answer= ['P', 'P', '4', '5'] ,wrong words= 1
# number  1617
# prdict= ['9', 'Y', '7', 'C']
# answer= ['9', 'Y', 'T', 'C'] ,wrong words= 1
# number  1669
# prdict= ['5', 'H', 'Y', '4']
# answer= ['3', 'H', 'Y', '4'] ,wrong words= 1
# number  1732
# prdict= ['A', 'Z', 'C', 'K']
# answer= ['A', 'C', 'Z', 'K'] ,wrong words= 2
# number  1773
# prdict= ['F', '5', '9', 'P']
# answer= ['F', '3', '9', 'P'] ,wrong words= 1
# number  1802
# prdict= ['F', 'A', 'Z', 'Y']
# answer= ['F', '7', 'Z', 'Y'] ,wrong words= 1
# number  1827
# prdict= ['4', 'K', 'A', '7']
# answer= ['4', 'K', 'A', 'T'] ,wrong words= 1
# number  1876
# prdict= ['P', 'Y', 'P', 'N']
# answer= ['P', 'Y', '3', 'N'] ,wrong words= 1
# number  1881
# prdict= ['H', 'Q', 'F', 'Q']
# answer= ['H', 'Q', 'F', 'H'] ,wrong words= 1
# number  1893
# prdict= ['H', 'Q', '7', 'Y']
# answer= ['H', 'Q', '7', 'C'] ,wrong words= 1
# number  1915
# prdict= ['C', 'C', '7', '7']
# answer= ['C', 'C', '7', 'T'] ,wrong words= 1
# number  1919
# prdict= ['9', '2', '4', '7']
# answer= ['9', '2', '4', 'Z'] ,wrong words= 1
# number  2146
# prdict= ['A', 'T', 'K', 'T']
# answer= ['A', 'Y', 'K', 'Y'] ,wrong words= 2
# number  2148
# prdict= ['N', '7', '5', 'T']
# answer= ['N', '7', '5', 'Y'] ,wrong words= 1
# number  2196
# prdict= ['Z', '3', 'C', '9']
# answer= ['Z', 'C', 'C', '9'] ,wrong words= 1
# number  2223
# prdict= ['M', 'N', 'Z', '2']
# answer= ['M', 'N', 'Z', '4'] ,wrong words= 1
# number  2247
# prdict= ['H', 'T', '2', 'H']
# answer= ['H', 'T', '3', 'H'] ,wrong words= 1
# number  2309
# prdict= ['5', 'Z', 'H', '4']
# answer= ['5', 'N', 'H', '4'] ,wrong words= 1
# number  2341
# prdict= ['C', '2', 'R', 'M']
# answer= ['C', '2', 'R', 'N'] ,wrong words= 1
# number  2356
# prdict= ['N', '2', '9', 'N']
# answer= ['N', '2', 'N', '9'] ,wrong words= 2
# number  2369
# prdict= ['Y', 'T', 'H', 'M']
# answer= ['Y', 'T', 'F', 'M'] ,wrong words= 1
# number  2409
# prdict= ['K', '7', 'C', '2']
# answer= ['M', '7', 'C', '2'] ,wrong words= 1
# number  2439
# prdict= ['3', 'A', '9', 'H']
# answer= ['3', 'A', '4', '9'] ,wrong words= 2
# number  2457
# prdict= ['K', '5', '9', 'A']
# answer= ['R', '5', '9', 'A'] ,wrong words= 1
# number  2458
# prdict= ['A', 'M', '3', '4']
# answer= ['A', '3', '3', '4'] ,wrong words= 1
# number  2540
# prdict= ['C', '3', 'A', '4']
# answer= ['C', '3', '4', 'A'] ,wrong words= 2
# number  2568
# prdict= ['P', 'C', 'H', 'R']
# answer= ['F', 'C', 'H', 'R'] ,wrong words= 1
# number  2581
# prdict= ['Q', 'Z', 'F', '7']
# answer= ['Q', 'Z', 'F', 'C'] ,wrong words= 1
# number  2609
# prdict= ['Y', 'F', '3', 'F']
# answer= ['Y', 'F', '3', 'Y'] ,wrong words= 1
# number  2647
# prdict= ['7', 'Y', 'T', 'N']
# answer= ['7', 'Y', 'T', 'M'] ,wrong words= 1
# number  2658
# prdict= ['C', 'Y', '9', 'C']
# answer= ['C', 'Y', 'C', '9'] ,wrong words= 2
# number  2747
# prdict= ['F', 'K', 'Y', 'T']
# answer= ['P', 'K', 'Y', 'T'] ,wrong words= 1
# number  2793
# prdict= ['4', 'T', 'M', 'H']
# answer= ['4', 'T', 'M', 'N'] ,wrong words= 1
# number  2832
# prdict= ['4', '5', 'F', 'T']
# answer= ['4', '5', 'Z', 'T'] ,wrong words= 1
# number  2846
# prdict= ['M', 'M', 'M', 'C']
# answer= ['M', 'M', 'F', 'C'] ,wrong words= 1
# number  2853
# prdict= ['Y', '7', '3', 'Z']
# answer= ['Y', 'A', '3', 'Z'] ,wrong words= 1
# number  2950
# prdict= ['Z', '9', 'T', 'C']
# answer= ['Z', '9', 'T', 'Z'] ,wrong words= 1
# 3000 picture total wrong=90
# one word accuracy= 0.9925
# four word accuracy= 0.976
# 0.0
# 55.9554398059845
# 0.001960277557373047

# %%
#測試test   0.976
#先把model load進來
model1=load_model("models/RMSprop-19-0.9936.h5")
model2=load_model("models/Adamax-30-0.9904.h5")
model3=load_model("models/RMSprop-11-0.9952.h5")
#將y_onehot和x_test變成global加快速度
with h5.File('test.h5','r') as file:
        x_test=file.get("x").value/255
data=scipy.io.loadmat("test.mat")
y_onehot=data['y_onehot']
filenum=x_test.shape[0]
def ThreeModelTestTrain(model1,model2,model3):
    global filenum
    time_start1=time.time()
    l=[]
    time_end1=time.time()
    time_start2=time.time()
    for i in range(filenum):
        imacc,facc=ThreeModelPredict(model1,model2,model3,i)
        l.append((imacc,facc))
    time_end2=time.time()
    time_start3=time.time()
    sigma=np.asarray(np.sum(np.asarray(l),axis=0))
    imgaccuracy=sigma[0]/filenum
    fourwordccuracy=sigma[1]/(4*filenum)
    print('%d picture total wrong=%d'%(filenum,4*filenum-sigma[1]))
    print('one word accuracy=',fourwordccuracy)
    print('four word accuracy=',imgaccuracy)  
    time_end3=time.time()
    print(time_end1-time_start1)
    print(time_end2-time_start2)
    print(time_end3-time_start3)

def ThreeModelPredict(model1,model2,model3,count):
    global y_onehot,x_test
    y=y_onehot.reshape((int(y_onehot.shape[0]/4),4,19))
    img = x_test[count]
    img = np.expand_dims(img,axis=0)       
    x1,x2,x3=EeachModelPredict(model1,model2,model3,img)
    datasheet={"0":"2","1":"3","2":"4","3":'5',"4":'7',"5":'9',"6":'A',"7":'C',"8":'F',"9":'H',"10":'K',"11":'M',"12":'N',"13":'P',"14":'Q',"15":'R',"16":'T',"17":'Y',"18":'Z'}
    pdt1=[datasheet[str(i[0])]for i in x1] #預測為['A','B','C','D']
    pdt2=[datasheet[str(i[0])]for i in x2]
    pdt3=[datasheet[str(i[0])]for i in x3]
    ans=[datasheet[str(np.argmax(y[count][i]))] for i in range(4)]#答案為['A','B','C','D']
    fouracc=0
    imgacc=0
    #處理三個網路預測的結果，分析哪個為最終結果
    if pdt1==pdt2==pdt3:
        pdt=pdt1
    elif pdt1==pdt2:
        pdt=pdt1
    elif pdt1==pdt3:  
        pdt=pdt1
    elif pdt2==pdt3:  
        pdt=pdt2
    else:
        pdt=pdt3
    #確認有幾個字對
    for ind,letter in enumerate(pdt):
        if letter==ans[ind]:
            fouracc+=1

    if pdt==ans:
        imgacc=1
    if count <40:
        print("number ",count)
        if count <=5:
            plt.imshow(x_test[count])
            plt.show()
        print("prdict=",pdt)
        print("answer=",ans,",wrong words=",4-fouracc)
        if count==39:
            print("number ",count)
    if fouracc!=4:
        print("number ",count)
        plt.imshow(x_test[count])
        plt.show()
        print("prdict=",pdt)
        print("answer=",ans,",wrong words=",4-fouracc)
    return imgacc,fouracc

def EeachModelPredict(model1,model2,model3,img):
    x1 = np.argmax(model1.predict(img),axis=2) #x1:RMSprop-19-0.9936.h5
    x2 = np.argmax(model2.predict(img),axis=2) #x2:Adamax-30-0.9904.h5
    x3 = np.argmax(model3.predict(img),axis=2) #x3:RMSprop-11-0.9952.h5
    return x1,x2,x3
ThreeModelTestTrain(model1,model2,model3)
# Out:
# C:\Users\苯異丙胺\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:8: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
# number  0
# prdict= ['7', 'F', '9', '4']
# answer= ['7', 'F', '9', '4'] ,wrong words= 0
# number  1
# prdict= ['4', '2', 'T', '7']
# answer= ['4', '2', 'T', '7'] ,wrong words= 0
# number  2
# prdict= ['C', 'Y', 'T', 'F']
# answer= ['C', 'Y', 'T', 'F'] ,wrong words= 0
# number  3
# prdict= ['T', 'M', 'F', 'T']
# answer= ['T', 'M', 'F', 'T'] ,wrong words= 0
# number  4
# prdict= ['P', '7', 'K', 'R']
# answer= ['P', '7', 'K', 'R'] ,wrong words= 0
# number  5
# prdict= ['N', '2', 'Z', 'K']
# answer= ['N', '2', 'Z', 'K'] ,wrong words= 0
# number  6
# prdict= ['7', '4', 'F', 'Y']
# answer= ['7', '4', 'F', 'Y'] ,wrong words= 0
# number  7
# prdict= ['Z', 'Z', '5', 'C']
# answer= ['Z', 'Z', '5', 'C'] ,wrong words= 0
# number  8
# prdict= ['7', 'Z', '4', '4']
# answer= ['7', 'Z', '4', '4'] ,wrong words= 0
# number  9
# prdict= ['R', '4', 'Z', 'C']
# answer= ['R', '4', 'Z', 'C'] ,wrong words= 0
# number  10
# prdict= ['Y', '2', '5', 'T']
# answer= ['Y', '2', '5', 'T'] ,wrong words= 0
# number  11
# prdict= ['F', 'M', '2', '2']
# answer= ['F', 'M', '2', '2'] ,wrong words= 0
# number  12
# prdict= ['Y', '4', 'M', '4']
# answer= ['Y', '4', 'M', '4'] ,wrong words= 0
# number  13
# prdict= ['M', '2', 'Q', '2']
# answer= ['M', '2', 'Q', '2'] ,wrong words= 0
# number  14
# prdict= ['F', 'F', '7', 'N']
# answer= ['F', 'F', '7', 'N'] ,wrong words= 0
# number  15
# prdict= ['9', '5', 'R', 'M']
# answer= ['9', '5', 'R', 'M'] ,wrong words= 0
# number  16
# prdict= ['T', '4', 'T', '5']
# answer= ['T', '4', 'T', '5'] ,wrong words= 0
# number  17
# prdict= ['F', '3', '4', 'A']
# answer= ['F', '3', '4', '3'] ,wrong words= 1
# number  17
# prdict= ['F', '3', '4', 'A']
# answer= ['F', '3', '4', '3'] ,wrong words= 1
# number  18
# prdict= ['F', 'A', '4', 'A']
# answer= ['F', 'A', '4', 'A'] ,wrong words= 0
# number  19
# prdict= ['3', '2', 'H', '4']
# answer= ['3', '2', 'H', '4'] ,wrong words= 0
# number  20
# prdict= ['Q', 'H', 'N', 'A']
# answer= ['Q', 'H', 'M', 'A'] ,wrong words= 1
# number  20
# prdict= ['Q', 'H', 'N', 'A']
# answer= ['Q', 'H', 'M', 'A'] ,wrong words= 1
# number  21
# prdict= ['P', 'Y', 'C', 'P']
# answer= ['P', 'Y', 'C', 'P'] ,wrong words= 0
# number  22
# prdict= ['A', 'P', 'N', 'M']
# answer= ['A', 'P', 'N', 'M'] ,wrong words= 0
# number  23
# prdict= ['R', 'M', 'Q', 'N']
# answer= ['R', 'M', 'Q', 'N'] ,wrong words= 0
# number  24
# prdict= ['K', 'Z', '7', '4']
# answer= ['K', 'Z', '7', '4'] ,wrong words= 0
# number  25
# prdict= ['N', 'F', 'Z', 'H']
# answer= ['N', 'F', 'Z', 'H'] ,wrong words= 0
# number  26
# prdict= ['Y', '2', '7', 'R']
# answer= ['Y', '2', '7', 'R'] ,wrong words= 0
# number  27
# prdict= ['A', 'Y', 'R', 'K']
# answer= ['A', 'Y', 'R', '4'] ,wrong words= 1
# number  27
# prdict= ['A', 'Y', 'R', 'K']
# answer= ['A', 'Y', 'R', '4'] ,wrong words= 1
# number  28
# prdict= ['M', '9', '4', 'Y']
# answer= ['M', '9', '4', 'Y'] ,wrong words= 0
# number  29
# prdict= ['3', '5', 'Q', '7']
# answer= ['3', '5', 'Q', '7'] ,wrong words= 0
# number  30
# prdict= ['A', 'Y', 'H', 'A']
# answer= ['A', 'Y', 'H', 'A'] ,wrong words= 0
# number  31
# prdict= ['T', 'R', '4', '5']
# answer= ['T', 'R', '4', '5'] ,wrong words= 0
# number  32
# prdict= ['Q', 'T', 'R', '4']
# answer= ['Q', 'T', 'R', '4'] ,wrong words= 0
# number  33
# prdict= ['2', '7', '3', 'A']
# answer= ['2', '7', '3', 'A'] ,wrong words= 0
# number  34
# prdict= ['Q', 'M', 'Y', 'F']
# answer= ['Q', 'M', 'Y', 'F'] ,wrong words= 0
# number  35
# prdict= ['2', 'Y', 'N', 'K']
# answer= ['2', 'Y', 'N', 'K'] ,wrong words= 0
# number  36
# prdict= ['R', 'H', 'T', 'P']
# answer= ['R', 'H', 'T', 'P'] ,wrong words= 0
# number  37
# prdict= ['7', 'K', 'Q', 'M']
# answer= ['7', 'K', 'Q', '5'] ,wrong words= 1
# number  37
# prdict= ['7', 'K', 'Q', 'M']
# answer= ['7', 'K', 'Q', '5'] ,wrong words= 1
# number  38
# prdict= ['7', 'H', 'Y', 'P']
# answer= ['7', 'H', 'Y', 'P'] ,wrong words= 0
# number  39
# prdict= ['5', 'M', '3', 'K']
# answer= ['5', 'M', '3', 'K'] ,wrong words= 0
# number  39
# number  90
# prdict= ['5', 'Q', 'P', 'N']
# answer= ['3', 'Q', 'P', 'N'] ,wrong words= 1
# number  165
# prdict= ['5', 'C', 'N', 'H']
# answer= ['3', 'C', 'N', 'H'] ,wrong words= 1
# number  168
# prdict= ['K', '9', 'K', 'P']
# answer= ['K', '9', 'K', '9'] ,wrong words= 1
# number  454
# prdict= ['9', 'H', 'R', 'K']
# answer= ['9', 'H', 'R', 'Q'] ,wrong words= 1
# number  502
# prdict= ['T', 'P', 'T', '3']
# answer= ['7', 'P', 'T', '3'] ,wrong words= 1
# number  641
# prdict= ['2', 'M', '4', 'K']
# answer= ['Z', 'M', '4', 'K'] ,wrong words= 1
# number  687
# prdict= ['Y', 'H', 'K', 'T']
# answer= ['Y', 'M', 'K', 'T'] ,wrong words= 1
# number  695
# prdict= ['5', 'Q', 'Y', '2']
# answer= ['5', 'Q', 'Y', 'Z'] ,wrong words= 1
# number  762
# prdict= ['Z', 'H', '2', '3']
# answer= ['Z', 'M', '2', '3'] ,wrong words= 1
# number  782
# prdict= ['P', 'F', 'C', 'Z']
# answer= ['F', 'F', 'C', 'Z'] ,wrong words= 1
# number  834
# prdict= ['H', 'F', 'H', 'M']
# answer= ['H', 'F', 'F', 'M'] ,wrong words= 1
# number  859
# prdict= ['A', 'P', '4', 'P']
# answer= ['A', 'F', '4', 'P'] ,wrong words= 1
# number  927
# prdict= ['C', '3', 'N', '3']
# answer= ['C', '3', 'N', 'C'] ,wrong words= 1
# number  1112
# prdict= ['5', 'A', 'C', 'R']
# answer= ['3', 'A', 'C', 'R'] ,wrong words= 1
# number  1174
# prdict= ['H', 'A', 'Z', 'Y']
# answer= ['M', 'A', 'Z', 'Y'] ,wrong words= 1
# number  1243
# prdict= ['T', 'A', 'R', '5']
# answer= ['7', 'A', 'R', '5'] ,wrong words= 1
# number  1292
# prdict= ['5', 'Z', '7', '3']
# answer= ['3', 'Z', '7', '3'] ,wrong words= 1
# number  1304
# prdict= ['R', 'R', 'K', 'T']
# answer= ['F', 'R', 'K', 'T'] ,wrong words= 1
# number  1306
# prdict= ['2', 'Y', '9', 'H']
# answer= ['Z', 'Y', '9', 'H'] ,wrong words= 1
# number  1313
# prdict= ['K', '2', 'Z', 'P']
# answer= ['K', 'Z', 'Z', 'P'] ,wrong words= 1
# number  1324
# prdict= ['2', 'M', 'K', 'K']
# answer= ['Z', 'M', 'K', 'K'] ,wrong words= 1
# number  1335
# prdict= ['K', 'A', 'Z', 'A']
# answer= ['9', '7', '7', '3'] ,wrong words= 4
# number  1336
# prdict= ['7', 'F', 'H', 'M']
# answer= ['R', 'F', 'K', '3'] ,wrong words= 3
# number  1337
# prdict= ['N', '7', '7', 'M']
# answer= ['Z', 'M', '4', 'N'] ,wrong words= 4
# number  1338
# prdict= ['K', 'Y', '4', 'T']
# answer= ['A', 'F', '4', 'H'] ,wrong words= 3
# number  1348
# prdict= ['7', '3', '2', 'F']
# answer= ['7', '4', '3', 'F'] ,wrong words= 2
# number  1352
# prdict= ['2', 'R', 'M', '9']
# answer= ['Z', 'R', 'M', '9'] ,wrong words= 1
# number  1354
# prdict= ['N', '2', 'H', 'A']
# answer= ['N', 'Z', 'H', 'A'] ,wrong words= 1
# number  1358
# prdict= ['R', '2', 'P', '5']
# answer= ['R', 'Z', 'P', '5'] ,wrong words= 1
# number  1448
# prdict= ['2', 'H', 'K', 'F']
# answer= ['Z', 'H', 'K', 'F'] ,wrong words= 1
# number  1481
# prdict= ['F', 'K', 'N', 'M']
# answer= ['F', 'Q', 'N', 'M'] ,wrong words= 1
# number  1488
# prdict= ['2', 'C', 'P', 'K']
# answer= ['Z', 'C', 'P', 'K'] ,wrong words= 1
# number  1526
# prdict= ['4', 'Z', '2', 'A']
# answer= ['4', 'Z', 'A', '2'] ,wrong words= 2
# number  1568
# prdict= ['F', 'P', '4', '5']
# answer= ['P', 'P', '4', '5'] ,wrong words= 1
# number  1617
# prdict= ['9', 'Y', '7', 'C']
# answer= ['9', 'Y', 'T', 'C'] ,wrong words= 1
# number  1669
# prdict= ['5', 'H', 'Y', '4']
# answer= ['3', 'H', 'Y', '4'] ,wrong words= 1
# number  1732
# prdict= ['A', 'Z', 'C', 'K']
# answer= ['A', 'C', 'Z', 'K'] ,wrong words= 2
# number  1773
# prdict= ['F', '5', '9', 'P']
# answer= ['F', '3', '9', 'P'] ,wrong words= 1
# number  1802
# prdict= ['F', 'A', 'Z', 'Y']
# answer= ['F', '7', 'Z', 'Y'] ,wrong words= 1
# number  1827
# prdict= ['4', 'K', 'A', '7']
# answer= ['4', 'K', 'A', 'T'] ,wrong words= 1
# number  1876
# prdict= ['P', 'Y', 'P', 'N']
# answer= ['P', 'Y', '3', 'N'] ,wrong words= 1
# number  1881
# prdict= ['H', 'Q', 'F', 'Q']
# answer= ['H', 'Q', 'F', 'H'] ,wrong words= 1
# number  1893
# prdict= ['H', 'Q', '7', 'Y']
# answer= ['H', 'Q', '7', 'C'] ,wrong words= 1
# number  1915
# prdict= ['C', 'C', '7', '7']
# answer= ['C', 'C', '7', 'T'] ,wrong words= 1
# number  1919
# prdict= ['9', '2', '4', '7']
# answer= ['9', '2', '4', 'Z'] ,wrong words= 1
# number  2146
# prdict= ['A', 'T', 'K', 'T']
# answer= ['A', 'Y', 'K', 'Y'] ,wrong words= 2
# number  2148
# prdict= ['N', '7', '5', 'T']
# answer= ['N', '7', '5', 'Y'] ,wrong words= 1
# number  2196
# prdict= ['Z', '3', 'C', '9']
# answer= ['Z', 'C', 'C', '9'] ,wrong words= 1
# number  2223
# prdict= ['M', 'N', 'Z', '2']
# answer= ['M', 'N', 'Z', '4'] ,wrong words= 1
# number  2247
# prdict= ['H', 'T', '2', 'H']
# answer= ['H', 'T', '3', 'H'] ,wrong words= 1
# number  2309
# prdict= ['5', 'Z', 'H', '4']
# answer= ['5', 'N', 'H', '4'] ,wrong words= 1
# number  2341
# prdict= ['C', '2', 'R', 'M']
# answer= ['C', '2', 'R', 'N'] ,wrong words= 1
# number  2356
# prdict= ['N', '2', '9', 'N']
# answer= ['N', '2', 'N', '9'] ,wrong words= 2
# number  2369
# prdict= ['Y', 'T', 'H', 'M']
# answer= ['Y', 'T', 'F', 'M'] ,wrong words= 1
# number  2409
# prdict= ['K', '7', 'C', '2']
# answer= ['M', '7', 'C', '2'] ,wrong words= 1
# number  2439
# prdict= ['3', 'A', '9', 'H']
# answer= ['3', 'A', '4', '9'] ,wrong words= 2
# number  2457
# prdict= ['K', '5', '9', 'A']
# answer= ['R', '5', '9', 'A'] ,wrong words= 1
# number  2458
# prdict= ['A', 'M', '3', '4']
# answer= ['A', '3', '3', '4'] ,wrong words= 1
# number  2540
# prdict= ['C', '3', 'A', '4']
# answer= ['C', '3', '4', 'A'] ,wrong words= 2
# number  2581
# prdict= ['Q', 'Z', 'F', '7']
# answer= ['Q', 'Z', 'F', 'C'] ,wrong words= 1
# number  2609
# prdict= ['Y', 'F', '3', 'F']
# answer= ['Y', 'F', '3', 'Y'] ,wrong words= 1
# number  2647
# prdict= ['7', 'Y', 'T', 'N']
# answer= ['7', 'Y', 'T', 'M'] ,wrong words= 1
# number  2658
# prdict= ['C', 'Y', '9', 'C']
# answer= ['C', 'Y', 'C', '9'] ,wrong words= 2
# number  2747
# prdict= ['F', 'K', 'Y', 'T']
# answer= ['P', 'K', 'Y', 'T'] ,wrong words= 1
# number  2793
# prdict= ['4', 'T', 'M', 'H']
# answer= ['4', 'T', 'M', 'N'] ,wrong words= 1
# number  2832
# prdict= ['4', '5', 'F', 'T']
# answer= ['4', '5', 'Z', 'T'] ,wrong words= 1
# number  2853
# prdict= ['Y', '7', '3', 'Z']
# answer= ['Y', 'A', '3', 'Z'] ,wrong words= 1
# number  2950
# prdict= ['Z', '9', 'T', 'C']
# answer= ['Z', '9', 'T', 'Z'] ,wrong words= 1
# 3000 picture total wrong=90
# one word accuracy= 0.9925
# four word accuracy= 0.976
# 0.0
# 46.20638084411621
# 0.0009763240814208984

# %%
#測試test 0.9753
#先把model load進來
model1=load_model("models/RMSprop-19-0.9936.h5")
model2=load_model("models/Adamax-18-0.9920.h5")
model3=load_model("models/RMSprop-11-0.9952.h5")
#將y_onehot和x_test變成global加快速度
with h5.File('test.h5','r') as file:
        x_test=file.get("x").value/255
data=scipy.io.loadmat("test.mat")
y_onehot=data['y_onehot']
filenum=x_test.shape[0]
def ThreeModelTestTrain(model1,model2,model3):
    global filenum
    time_start1=time.time()
    l=[]
    time_end1=time.time()
    time_start2=time.time()
    for i in range(filenum):
        imacc,facc=ThreeModelPredict(model1,model2,model3,i)
        l.append((imacc,facc))
    time_end2=time.time()
    time_start3=time.time()
    sigma=np.asarray(np.sum(np.asarray(l),axis=0))
    imgaccuracy=sigma[0]/filenum
    fourwordccuracy=sigma[1]/(4*filenum)
    print('%d picture total wrong=%d'%(filenum,4*filenum-sigma[1]))
    print('one word accuracy=',fourwordccuracy)
    print('four word accuracy=',imgaccuracy)  
    time_end3=time.time()
    print(time_end1-time_start1)
    print(time_end2-time_start2)
    print(time_end3-time_start3)

def ThreeModelPredict(model1,model2,model3,count):
    global y_onehot,x_test
    y=y_onehot.reshape((int(y_onehot.shape[0]/4),4,19))
    img = x_test[count]
    img = np.expand_dims(img,axis=0)       
    x1,x2,x3=EeachModelPredict(model1,model2,model3,img)
    datasheet={"0":"2","1":"3","2":"4","3":'5',"4":'7',"5":'9',"6":'A',"7":'C',"8":'F',"9":'H',"10":'K',"11":'M',"12":'N',"13":'P',"14":'Q',"15":'R',"16":'T',"17":'Y',"18":'Z'}
    pdt1=[datasheet[str(i[0])]for i in x1] #預測為['A','B','C','D']
    pdt2=[datasheet[str(i[0])]for i in x2]
    pdt3=[datasheet[str(i[0])]for i in x3]
    ans=[datasheet[str(np.argmax(y[count][i]))] for i in range(4)]#答案為['A','B','C','D']
    fouracc=0
    imgacc=0
    #處理三個網路預測的結果，分析哪個為最終結果
    if pdt1==pdt2==pdt3:
        pdt=pdt1
    elif pdt1==pdt2:
        pdt=pdt1
    elif pdt1==pdt3:  
        pdt=pdt1
    elif pdt2==pdt3:  
        pdt=pdt2
    else:
        pdt=pdt3
    #確認有幾個字對
    for ind,letter in enumerate(pdt):
        if letter==ans[ind]:
            fouracc+=1

    if pdt==ans:
        imgacc=1
    if count <40:
        print("number ",count)
        if count <=5:
            plt.imshow(x_test[count])
            plt.show()
        print("prdict=",pdt)
        print("answer=",ans,",wrong words=",4-fouracc)
        if count==39:
            print("number ",count)
    if fouracc!=4:
        print("number ",count)
        plt.imshow(x_test[count])
        plt.show()
        print("prdict=",pdt)
        print("answer=",ans,",wrong words=",4-fouracc)
    return imgacc,fouracc

def EeachModelPredict(model1,model2,model3,img):
    x1 = np.argmax(model1.predict(img),axis=2) #x1:RMSprop-19-0.9936.h5
    x2 = np.argmax(model2.predict(img),axis=2) #x2:Adamax-18-0.9920.h5
    x3 = np.argmax(model3.predict(img),axis=2) #x3:RMSprop-11-0.9952.h5
    return x1,x2,x3
ThreeModelTestTrain(model1,model2,model3)
# Out:
# C:\Users\苯異丙胺\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:8: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
# number  0
# prdict= ['7', 'F', '9', '4']
# answer= ['7', 'F', '9', '4'] ,wrong words= 0
# number  1
# prdict= ['4', '2', 'T', '7']
# answer= ['4', '2', 'T', '7'] ,wrong words= 0
# number  2
# prdict= ['C', 'Y', 'T', 'F']
# answer= ['C', 'Y', 'T', 'F'] ,wrong words= 0
# number  3
# prdict= ['T', 'M', 'F', 'T']
# answer= ['T', 'M', 'F', 'T'] ,wrong words= 0
# number  4
# prdict= ['P', '7', 'K', 'R']
# answer= ['P', '7', 'K', 'R'] ,wrong words= 0
# number  5
# prdict= ['N', '2', 'Z', 'K']
# answer= ['N', '2', 'Z', 'K'] ,wrong words= 0
# number  6
# prdict= ['7', '4', 'F', 'Y']
# answer= ['7', '4', 'F', 'Y'] ,wrong words= 0
# number  7
# prdict= ['Z', 'Z', '5', 'C']
# answer= ['Z', 'Z', '5', 'C'] ,wrong words= 0
# number  8
# prdict= ['7', 'Z', '4', '4']
# answer= ['7', 'Z', '4', '4'] ,wrong words= 0
# number  9
# prdict= ['R', '4', 'Z', 'C']
# answer= ['R', '4', 'Z', 'C'] ,wrong words= 0
# number  10
# prdict= ['Y', '2', '5', 'T']
# answer= ['Y', '2', '5', 'T'] ,wrong words= 0
# number  11
# prdict= ['F', 'M', '2', '2']
# answer= ['F', 'M', '2', '2'] ,wrong words= 0
# number  12
# prdict= ['Y', '4', 'M', '4']
# answer= ['Y', '4', 'M', '4'] ,wrong words= 0
# number  13
# prdict= ['M', '2', 'Q', '2']
# answer= ['M', '2', 'Q', '2'] ,wrong words= 0
# number  14
# prdict= ['F', 'F', '7', 'N']
# answer= ['F', 'F', '7', 'N'] ,wrong words= 0
# number  15
# prdict= ['9', '5', 'R', 'M']
# answer= ['9', '5', 'R', 'M'] ,wrong words= 0
# number  16
# prdict= ['T', '4', 'T', '5']
# answer= ['T', '4', 'T', '5'] ,wrong words= 0
# number  17
# prdict= ['F', '3', '4', 'A']
# answer= ['F', '3', '4', '3'] ,wrong words= 1
# number  17
# prdict= ['F', '3', '4', 'A']
# answer= ['F', '3', '4', '3'] ,wrong words= 1
# number  18
# prdict= ['F', 'A', '4', 'A']
# answer= ['F', 'A', '4', 'A'] ,wrong words= 0
# number  19
# prdict= ['3', '2', 'H', '4']
# answer= ['3', '2', 'H', '4'] ,wrong words= 0
# number  20
# prdict= ['Q', 'H', 'M', 'A']
# answer= ['Q', 'H', 'M', 'A'] ,wrong words= 0
# number  21
# prdict= ['P', 'Y', 'C', 'P']
# answer= ['P', 'Y', 'C', 'P'] ,wrong words= 0
# number  22
# prdict= ['A', 'P', 'N', 'M']
# answer= ['A', 'P', 'N', 'M'] ,wrong words= 0
# number  23
# prdict= ['R', 'M', 'Q', 'N']
# answer= ['R', 'M', 'Q', 'N'] ,wrong words= 0
# number  24
# prdict= ['K', 'Z', '7', '4']
# answer= ['K', 'Z', '7', '4'] ,wrong words= 0
# number  25
# prdict= ['N', 'F', 'Z', 'H']
# answer= ['N', 'F', 'Z', 'H'] ,wrong words= 0
# number  26
# prdict= ['Y', '2', '7', 'R']
# answer= ['Y', '2', '7', 'R'] ,wrong words= 0
# number  27
# prdict= ['A', 'Y', 'R', 'K']
# answer= ['A', 'Y', 'R', '4'] ,wrong words= 1
# number  27
# prdict= ['A', 'Y', 'R', 'K']
# answer= ['A', 'Y', 'R', '4'] ,wrong words= 1
# number  28
# prdict= ['M', '9', '4', 'Y']
# answer= ['M', '9', '4', 'Y'] ,wrong words= 0
# number  29
# prdict= ['3', '5', 'Q', '7']
# answer= ['3', '5', 'Q', '7'] ,wrong words= 0
# number  30
# prdict= ['A', 'Y', 'H', 'A']
# answer= ['A', 'Y', 'H', 'A'] ,wrong words= 0
# number  31
# prdict= ['T', 'R', '4', '5']
# answer= ['T', 'R', '4', '5'] ,wrong words= 0
# number  32
# prdict= ['Q', 'T', 'R', '4']
# answer= ['Q', 'T', 'R', '4'] ,wrong words= 0
# number  33
# prdict= ['2', '7', '3', 'A']
# answer= ['2', '7', '3', 'A'] ,wrong words= 0
# number  34
# prdict= ['Q', 'M', 'Y', 'F']
# answer= ['Q', 'M', 'Y', 'F'] ,wrong words= 0
# number  35
# prdict= ['2', 'Y', 'N', 'K']
# answer= ['2', 'Y', 'N', 'K'] ,wrong words= 0
# number  36
# prdict= ['R', 'H', 'T', 'P']
# answer= ['R', 'H', 'T', 'P'] ,wrong words= 0
# number  37
# prdict= ['7', 'K', 'Q', 'M']
# answer= ['7', 'K', 'Q', '5'] ,wrong words= 1
# number  37
# prdict= ['7', 'K', 'Q', 'M']
# answer= ['7', 'K', 'Q', '5'] ,wrong words= 1
# number  38
# prdict= ['7', 'H', 'Y', 'P']
# answer= ['7', 'H', 'Y', 'P'] ,wrong words= 0
# number  39
# prdict= ['5', 'M', '3', 'K']
# answer= ['5', 'M', '3', 'K'] ,wrong words= 0
# number  39
# number  90
# prdict= ['5', 'Q', 'P', 'N']
# answer= ['3', 'Q', 'P', 'N'] ,wrong words= 1
# number  165
# prdict= ['5', 'C', 'N', 'H']
# answer= ['3', 'C', 'N', 'H'] ,wrong words= 1
# number  168
# prdict= ['K', '9', 'K', 'P']
# answer= ['K', '9', 'K', '9'] ,wrong words= 1
# number  454
# prdict= ['9', 'H', 'R', 'K']
# answer= ['9', 'H', 'R', 'Q'] ,wrong words= 1
# number  502
# prdict= ['T', 'P', 'T', '3']
# answer= ['7', 'P', 'T', '3'] ,wrong words= 1
# number  641
# prdict= ['2', 'M', '4', 'K']
# answer= ['Z', 'M', '4', 'K'] ,wrong words= 1
# number  687
# prdict= ['Y', 'H', 'K', 'T']
# answer= ['Y', 'M', 'K', 'T'] ,wrong words= 1
# number  695
# prdict= ['5', 'Q', 'Y', '2']
# answer= ['5', 'Q', 'Y', 'Z'] ,wrong words= 1
# number  762
# prdict= ['Z', 'H', '2', '3']
# answer= ['Z', 'M', '2', '3'] ,wrong words= 1
# number  834
# prdict= ['H', 'F', 'H', 'M']
# answer= ['H', 'F', 'F', 'M'] ,wrong words= 1
# number  859
# prdict= ['A', 'P', '4', 'P']
# answer= ['A', 'F', '4', 'P'] ,wrong words= 1
# number  927
# prdict= ['C', '3', 'N', '3']
# answer= ['C', '3', 'N', 'C'] ,wrong words= 1
# number  1112
# prdict= ['5', 'A', 'C', 'R']
# answer= ['3', 'A', 'C', 'R'] ,wrong words= 1
# number  1174
# prdict= ['H', 'A', 'Z', 'Y']
# answer= ['M', 'A', 'Z', 'Y'] ,wrong words= 1
# number  1243
# prdict= ['T', 'A', 'R', '5']
# answer= ['7', 'A', 'R', '5'] ,wrong words= 1
# number  1292
# prdict= ['5', 'Z', '7', '3']
# answer= ['3', 'Z', '7', '3'] ,wrong words= 1
# number  1304
# prdict= ['R', 'R', 'K', 'T']
# answer= ['F', 'R', 'K', 'T'] ,wrong words= 1
# number  1306
# prdict= ['2', 'Y', '9', 'H']
# answer= ['Z', 'Y', '9', 'H'] ,wrong words= 1
# number  1313
# prdict= ['K', '2', 'Z', 'P']
# answer= ['K', 'Z', 'Z', 'P'] ,wrong words= 1
# number  1324
# prdict= ['2', 'M', 'K', 'K']
# answer= ['Z', 'M', 'K', 'K'] ,wrong words= 1
# number  1335
# prdict= ['K', 'A', 'Z', 'A']
# answer= ['9', '7', '7', '3'] ,wrong words= 4
# number  1336
# prdict= ['7', 'F', 'H', 'M']
# answer= ['R', 'F', 'K', '3'] ,wrong words= 3
# number  1337
# prdict= ['N', '7', '7', 'M']
# answer= ['Z', 'M', '4', 'N'] ,wrong words= 4
# number  1338
# prdict= ['K', 'Y', '4', 'T']
# answer= ['A', 'F', '4', 'H'] ,wrong words= 3
# number  1348
# prdict= ['7', '3', '2', 'F']
# answer= ['7', '4', '3', 'F'] ,wrong words= 2
# number  1352
# prdict= ['2', 'R', 'M', '9']
# answer= ['Z', 'R', 'M', '9'] ,wrong words= 1
# number  1354
# prdict= ['N', '2', 'H', 'A']
# answer= ['N', 'Z', 'H', 'A'] ,wrong words= 1
# number  1358
# prdict= ['R', '2', 'P', '5']
# answer= ['R', 'Z', 'P', '5'] ,wrong words= 1
# number  1448
# prdict= ['2', 'H', 'K', 'F']
# answer= ['Z', 'H', 'K', 'F'] ,wrong words= 1
# number  1481
# prdict= ['F', 'K', 'N', 'M']
# answer= ['F', 'Q', 'N', 'M'] ,wrong words= 1
# number  1488
# prdict= ['2', 'C', 'P', 'K']
# answer= ['Z', 'C', 'P', 'K'] ,wrong words= 1
# number  1526
# prdict= ['4', 'Z', '2', 'A']
# answer= ['4', 'Z', 'A', '2'] ,wrong words= 2
# number  1527
# prdict= ['C', 'P', '9', 'F']
# answer= ['C', 'F', '9', 'F'] ,wrong words= 1
# number  1568
# prdict= ['F', 'P', '4', '5']
# answer= ['P', 'P', '4', '5'] ,wrong words= 1
# number  1617
# prdict= ['9', 'Y', '7', 'C']
# answer= ['9', 'Y', 'T', 'C'] ,wrong words= 1
# number  1669
# prdict= ['5', 'H', 'Y', '4']
# answer= ['3', 'H', 'Y', '4'] ,wrong words= 1
# number  1732
# prdict= ['A', 'Z', 'C', 'K']
# answer= ['A', 'C', 'Z', 'K'] ,wrong words= 2
# number  1773
# prdict= ['F', '5', '9', 'P']
# answer= ['F', '3', '9', 'P'] ,wrong words= 1
# number  1802
# prdict= ['F', 'A', 'Z', 'Y']
# answer= ['F', '7', 'Z', 'Y'] ,wrong words= 1
# number  1827
# prdict= ['4', 'K', 'A', '7']
# answer= ['4', 'K', 'A', 'T'] ,wrong words= 1
# number  1876
# prdict= ['P', 'Y', 'P', 'N']
# answer= ['P', 'Y', '3', 'N'] ,wrong words= 1
# number  1881
# prdict= ['H', 'Q', 'F', 'Q']
# answer= ['H', 'Q', 'F', 'H'] ,wrong words= 1
# number  1893
# prdict= ['H', 'Q', '7', 'Y']
# answer= ['H', 'Q', '7', 'C'] ,wrong words= 1
# number  1915
# prdict= ['C', 'C', '7', '7']
# answer= ['C', 'C', '7', 'T'] ,wrong words= 1
# number  1919
# prdict= ['9', '2', '4', '7']
# answer= ['9', '2', '4', 'Z'] ,wrong words= 1
# number  2093
# prdict= ['5', 'K', '2', '5']
# answer= ['5', 'K', 'Z', '5'] ,wrong words= 1
# number  2098
# prdict= ['P', 'K', 'M', '4']
# answer= ['P', 'R', 'M', '4'] ,wrong words= 1
# number  2146
# prdict= ['A', 'T', 'K', 'T']
# answer= ['A', 'Y', 'K', 'Y'] ,wrong words= 2
# number  2148
# prdict= ['N', '7', '5', 'T']
# answer= ['N', '7', '5', 'Y'] ,wrong words= 1
# number  2196
# prdict= ['Z', '3', 'C', '9']
# answer= ['Z', 'C', 'C', '9'] ,wrong words= 1
# number  2223
# prdict= ['M', 'N', 'Z', '2']
# answer= ['M', 'N', 'Z', '4'] ,wrong words= 1
# number  2247
# prdict= ['H', 'T', '2', 'H']
# answer= ['H', 'T', '3', 'H'] ,wrong words= 1
# number  2309
# prdict= ['5', 'Z', 'H', '4']
# answer= ['5', 'N', 'H', '4'] ,wrong words= 1
# number  2341
# prdict= ['C', '2', 'R', 'M']
# answer= ['C', '2', 'R', 'N'] ,wrong words= 1
# number  2356
# prdict= ['N', '2', '9', 'N']
# answer= ['N', '2', 'N', '9'] ,wrong words= 2
# number  2369
# prdict= ['Y', 'T', 'H', 'M']
# answer= ['Y', 'T', 'F', 'M'] ,wrong words= 1
# number  2409
# prdict= ['K', '7', 'C', '2']
# answer= ['M', '7', 'C', '2'] ,wrong words= 1
# number  2439
# prdict= ['3', 'A', '9', 'H']
# answer= ['3', 'A', '4', '9'] ,wrong words= 2
# number  2457
# prdict= ['K', '5', '9', 'A']
# answer= ['R', '5', '9', 'A'] ,wrong words= 1
# number  2458
# prdict= ['A', 'M', '3', '4']
# answer= ['A', '3', '3', '4'] ,wrong words= 1
# number  2540
# prdict= ['C', '3', 'A', '4']
# answer= ['C', '3', '4', 'A'] ,wrong words= 2
# number  2568
# prdict= ['P', 'C', 'H', 'R']
# answer= ['F', 'C', 'H', 'R'] ,wrong words= 1
# number  2581
# prdict= ['Q', 'Z', 'F', '7']
# answer= ['Q', 'Z', 'F', 'C'] ,wrong words= 1
# number  2609
# prdict= ['Y', 'F', '3', 'F']
# answer= ['Y', 'F', '3', 'Y'] ,wrong words= 1
# number  2647
# prdict= ['7', 'Y', 'T', 'N']
# answer= ['7', 'Y', 'T', 'M'] ,wrong words= 1
# number  2658
# prdict= ['C', 'Y', '9', 'C']
# answer= ['C', 'Y', 'C', '9'] ,wrong words= 2
# number  2747
# prdict= ['F', 'K', 'Y', 'T']
# answer= ['P', 'K', 'Y', 'T'] ,wrong words= 1
# number  2793
# prdict= ['4', 'T', 'M', 'H']
# answer= ['4', 'T', 'M', 'N'] ,wrong words= 1
# number  2832
# prdict= ['4', '5', 'F', 'T']
# answer= ['4', '5', 'Z', 'T'] ,wrong words= 1
# number  2853
# prdict= ['Y', '7', '3', 'Z']
# answer= ['Y', 'A', '3', 'Z'] ,wrong words= 1
# number  2950
# prdict= ['Z', '9', 'T', 'C']
# answer= ['Z', '9', 'T', 'Z'] ,wrong words= 1
# 3000 picture total wrong=92
# one word accuracy= 0.9923333333333333
# four word accuracy= 0.9753333333333334
# 0.0
# 46.63959527015686
# 0.0019533634185791016

# %%
#測試test
#先把model load進來
model1=load_model("models/Adamax-10-0.9920.h5")
model2=load_model("models/Adamax-18-0.9920.h5")
model3=load_model("models/Adamax-30-0.9904.h5")
#將y_onehot和x_test變成global加快速度
with h5.File('test.h5','r') as file:
        x_test=file.get("x").value/255
data=scipy.io.loadmat("test.mat")
y_onehot=data['y_onehot']
filenum=x_test.shape[0]
def ThreeModelTestTrain(model1,model2,model3):
    global filenum
    time_start1=time.time()
    l=[]
    time_end1=time.time()
    time_start2=time.time()
    for i in range(filenum):
        imacc,facc=ThreeModelPredict(model1,model2,model3,i)
        l.append((imacc,facc))
    time_end2=time.time()
    time_start3=time.time()
    sigma=np.asarray(np.sum(np.asarray(l),axis=0))
    imgaccuracy=sigma[0]/filenum
    fourwordccuracy=sigma[1]/(4*filenum)
    print('%d picture total wrong=%d'%(filenum,4*filenum-sigma[1]))
    print('one word accuracy=',fourwordccuracy)
    print('four word accuracy=',imgaccuracy)  
    time_end3=time.time()
    print(time_end1-time_start1)
    print(time_end2-time_start2)
    print(time_end3-time_start3)

def ThreeModelPredict(model1,model2,model3,count):
    global y_onehot,x_test
    y=y_onehot.reshape((int(y_onehot.shape[0]/4),4,19))
    img = x_test[count]
    img = np.expand_dims(img,axis=0)       
    x1,x2,x3=EeachModelPredict(model1,model2,model3,img)
    datasheet={"0":"2","1":"3","2":"4","3":'5',"4":'7',"5":'9',"6":'A',"7":'C',"8":'F',"9":'H',"10":'K',"11":'M',"12":'N',"13":'P',"14":'Q',"15":'R',"16":'T',"17":'Y',"18":'Z'}
    pdt1=[datasheet[str(i[0])]for i in x1] #預測為['A','B','C','D']
    pdt2=[datasheet[str(i[0])]for i in x2]
    pdt3=[datasheet[str(i[0])]for i in x3]
    ans=[datasheet[str(np.argmax(y[count][i]))] for i in range(4)]#答案為['A','B','C','D']
    fouracc=0
    imgacc=0
    #處理三個網路預測的結果，分析哪個為最終結果
    if pdt1==pdt2==pdt3:
        pdt=pdt1
    elif pdt1==pdt2:
        pdt=pdt1
    elif pdt1==pdt3:  
        pdt=pdt1
    elif pdt2==pdt3:  
        pdt=pdt2
    else:
        pdt=pdt3
    #確認有幾個字對
    for ind,letter in enumerate(pdt):
        if letter==ans[ind]:
            fouracc+=1

    if pdt==ans:
        imgacc=1
    if count <40:
        print("number ",count)
        if count <=5:
            plt.imshow(x_test[count])
            plt.show()
        print("prdict=",pdt)
        print("answer=",ans,",wrong words=",4-fouracc)
        if count==39:
            print("number ",count)
    if fouracc!=4:
        print("number ",count)
        plt.imshow(x_test[count])
        plt.show()
        print("prdict=",pdt)
        print("answer=",ans,",wrong words=",4-fouracc)
    return imgacc,fouracc

def EeachModelPredict(model1,model2,model3,img):
    x1 = np.argmax(model1.predict(img),axis=2) #x1:Adamax-10-0.9920.h5
    x2 = np.argmax(model2.predict(img),axis=2) #x2:Adamax-18-0.9920.h5
    x3 = np.argmax(model3.predict(img),axis=2) #x3:Adamax-30-0.9904.h5
    return x1,x2,x3
ThreeModelTestTrain(model1,model2,model3)
# Out:
# C:\Users\苯異丙胺\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:8: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
# number  0
# prdict= ['7', 'F', '9', '4']
# answer= ['7', 'F', '9', '4'] ,wrong words= 0
# number  1
# prdict= ['4', '2', 'T', '7']
# answer= ['4', '2', 'T', '7'] ,wrong words= 0
# number  2
# prdict= ['C', 'Y', 'T', 'F']
# answer= ['C', 'Y', 'T', 'F'] ,wrong words= 0
# number  3
# prdict= ['T', 'M', 'F', 'T']
# answer= ['T', 'M', 'F', 'T'] ,wrong words= 0
# number  4
# prdict= ['P', '7', 'K', 'R']
# answer= ['P', '7', 'K', 'R'] ,wrong words= 0
# number  5
# prdict= ['N', '2', 'Z', 'K']
# answer= ['N', '2', 'Z', 'K'] ,wrong words= 0
# number  6
# prdict= ['7', '4', 'F', 'Y']
# answer= ['7', '4', 'F', 'Y'] ,wrong words= 0
# number  7
# prdict= ['Z', 'Z', '5', 'C']
# answer= ['Z', 'Z', '5', 'C'] ,wrong words= 0
# number  8
# prdict= ['7', 'Z', '4', '4']
# answer= ['7', 'Z', '4', '4'] ,wrong words= 0
# number  9
# prdict= ['R', '4', 'Z', 'C']
# answer= ['R', '4', 'Z', 'C'] ,wrong words= 0
# number  10
# prdict= ['Y', '2', '5', 'T']
# answer= ['Y', '2', '5', 'T'] ,wrong words= 0
# number  11
# prdict= ['F', 'M', '2', '2']
# answer= ['F', 'M', '2', '2'] ,wrong words= 0
# number  12
# prdict= ['Y', '4', 'M', '4']
# answer= ['Y', '4', 'M', '4'] ,wrong words= 0
# number  13
# prdict= ['M', '2', 'Q', '2']
# answer= ['M', '2', 'Q', '2'] ,wrong words= 0
# number  14
# prdict= ['F', 'F', '7', 'N']
# answer= ['F', 'F', '7', 'N'] ,wrong words= 0
# number  15
# prdict= ['9', '5', 'R', 'M']
# answer= ['9', '5', 'R', 'M'] ,wrong words= 0
# number  16
# prdict= ['T', '4', 'T', '5']
# answer= ['T', '4', 'T', '5'] ,wrong words= 0
# number  17
# prdict= ['F', '3', '4', 'A']
# answer= ['F', '3', '4', '3'] ,wrong words= 1
# number  17
# prdict= ['F', '3', '4', 'A']
# answer= ['F', '3', '4', '3'] ,wrong words= 1
# number  18
# prdict= ['F', 'A', '4', 'A']
# answer= ['F', 'A', '4', 'A'] ,wrong words= 0
# number  19
# prdict= ['3', '2', 'H', '4']
# answer= ['3', '2', 'H', '4'] ,wrong words= 0
# number  20
# prdict= ['Q', 'H', 'M', 'A']
# answer= ['Q', 'H', 'M', 'A'] ,wrong words= 0
# number  21
# prdict= ['P', 'Y', 'C', 'P']
# answer= ['P', 'Y', 'C', 'P'] ,wrong words= 0
# number  22
# prdict= ['A', 'P', 'N', 'M']
# answer= ['A', 'P', 'N', 'M'] ,wrong words= 0
# number  23
# prdict= ['R', 'M', 'Q', 'N']
# answer= ['R', 'M', 'Q', 'N'] ,wrong words= 0
# number  24
# prdict= ['K', 'Z', '7', '4']
# answer= ['K', 'Z', '7', '4'] ,wrong words= 0
# number  25
# prdict= ['N', 'F', 'Z', 'H']
# answer= ['N', 'F', 'Z', 'H'] ,wrong words= 0
# number  26
# prdict= ['Y', '2', '7', 'R']
# answer= ['Y', '2', '7', 'R'] ,wrong words= 0
# number  27
# prdict= ['A', 'Y', 'R', 'K']
# answer= ['A', 'Y', 'R', '4'] ,wrong words= 1
# number  27
# prdict= ['A', 'Y', 'R', 'K']
# answer= ['A', 'Y', 'R', '4'] ,wrong words= 1
# number  28
# prdict= ['M', '9', '4', 'Y']
# answer= ['M', '9', '4', 'Y'] ,wrong words= 0
# number  29
# prdict= ['3', '5', 'Q', '7']
# answer= ['3', '5', 'Q', '7'] ,wrong words= 0
# number  30
# prdict= ['A', 'Y', 'H', 'A']
# answer= ['A', 'Y', 'H', 'A'] ,wrong words= 0
# number  31
# prdict= ['T', 'R', '4', '5']
# answer= ['T', 'R', '4', '5'] ,wrong words= 0
# number  32
# prdict= ['Q', 'T', 'R', '4']
# answer= ['Q', 'T', 'R', '4'] ,wrong words= 0
# number  33
# prdict= ['2', '7', '3', 'A']
# answer= ['2', '7', '3', 'A'] ,wrong words= 0
# number  34
# prdict= ['Q', 'M', 'Y', 'F']
# answer= ['Q', 'M', 'Y', 'F'] ,wrong words= 0
# number  35
# prdict= ['2', 'Y', 'N', 'K']
# answer= ['2', 'Y', 'N', 'K'] ,wrong words= 0
# number  36
# prdict= ['R', 'H', 'T', 'P']
# answer= ['R', 'H', 'T', 'P'] ,wrong words= 0
# number  37
# prdict= ['7', 'K', 'Q', 'M']
# answer= ['7', 'K', 'Q', '5'] ,wrong words= 1
# number  37
# prdict= ['7', 'K', 'Q', 'M']
# answer= ['7', 'K', 'Q', '5'] ,wrong words= 1
# number  38
# prdict= ['7', 'H', 'Y', 'P']
# answer= ['7', 'H', 'Y', 'P'] ,wrong words= 0
# number  39
# prdict= ['5', 'M', '3', 'K']
# answer= ['5', 'M', '3', 'K'] ,wrong words= 0
# number  39
# number  90
# prdict= ['5', 'Q', 'P', 'N']
# answer= ['3', 'Q', 'P', 'N'] ,wrong words= 1
# number  165
# prdict= ['5', 'C', 'N', 'H']
# answer= ['3', 'C', 'N', 'H'] ,wrong words= 1
# number  168
# prdict= ['K', '9', 'K', 'P']
# answer= ['K', '9', 'K', '9'] ,wrong words= 1
# number  323
# prdict= ['A', '2', 'H', 'Q']
# answer= ['A', 'Z', 'H', 'Q'] ,wrong words= 1
# number  351
# prdict= ['K', 'T', 'T', 'N']
# answer= ['K', 'T', 'Q', 'N'] ,wrong words= 1
# number  441
# prdict= ['K', '3', 'A', 'T']
# answer= ['K', '9', 'A', 'T'] ,wrong words= 1
# number  454
# prdict= ['9', 'H', 'R', 'K']
# answer= ['9', 'H', 'R', 'Q'] ,wrong words= 1
# number  502
# prdict= ['T', 'P', 'T', '3']
# answer= ['7', 'P', 'T', '3'] ,wrong words= 1
# number  641
# prdict= ['2', 'M', '4', 'K']
# answer= ['Z', 'M', '4', 'K'] ,wrong words= 1
# number  687
# prdict= ['Y', 'H', 'K', 'T']
# answer= ['Y', 'M', 'K', 'T'] ,wrong words= 1
# number  695
# prdict= ['5', 'Q', 'Y', '2']
# answer= ['5', 'Q', 'Y', 'Z'] ,wrong words= 1
# number  762
# prdict= ['Z', 'H', '2', '3']
# answer= ['Z', 'M', '2', '3'] ,wrong words= 1
# number  782
# prdict= ['P', 'F', 'C', 'Z']
# answer= ['F', 'F', 'C', 'Z'] ,wrong words= 1
# number  834
# prdict= ['H', 'F', 'H', 'M']
# answer= ['H', 'F', 'F', 'M'] ,wrong words= 1
# number  859
# prdict= ['A', 'P', '4', 'P']
# answer= ['A', 'F', '4', 'P'] ,wrong words= 1
# number  927
# prdict= ['C', '3', 'N', '3']
# answer= ['C', '3', 'N', 'C'] ,wrong words= 1
# number  1112
# prdict= ['5', 'A', 'C', 'R']
# answer= ['3', 'A', 'C', 'R'] ,wrong words= 1
# number  1115
# prdict= ['9', 'H', 'M', 'A']
# answer= ['9', 'F', 'M', 'A'] ,wrong words= 1
# number  1174
# prdict= ['H', 'A', 'Z', 'Y']
# answer= ['M', 'A', 'Z', 'Y'] ,wrong words= 1
# number  1190
# prdict= ['C', 'H', 'T', 'Q']
# answer= ['C', 'H', 'Z', 'Q'] ,wrong words= 1
# number  1243
# prdict= ['T', 'A', 'R', '5']
# answer= ['7', 'A', 'R', '5'] ,wrong words= 1
# number  1292
# prdict= ['5', 'Z', '7', '3']
# answer= ['3', 'Z', '7', '3'] ,wrong words= 1
# number  1306
# prdict= ['2', 'Y', '9', 'H']
# answer= ['Z', 'Y', '9', 'H'] ,wrong words= 1
# number  1313
# prdict= ['K', '2', 'Z', 'P']
# answer= ['K', 'Z', 'Z', 'P'] ,wrong words= 1
# number  1324
# prdict= ['2', 'M', 'K', 'K']
# answer= ['Z', 'M', 'K', 'K'] ,wrong words= 1
# number  1335
# prdict= ['K', 'A', 'Z', 'A']
# answer= ['9', '7', '7', '3'] ,wrong words= 4
# number  1336
# prdict= ['7', 'F', 'H', 'M']
# answer= ['R', 'F', 'K', '3'] ,wrong words= 3
# number  1337
# prdict= ['N', '7', '7', 'M']
# answer= ['Z', 'M', '4', 'N'] ,wrong words= 4
# number  1338
# prdict= ['K', 'Y', '4', 'T']
# answer= ['A', 'F', '4', 'H'] ,wrong words= 3
# number  1348
# prdict= ['7', '3', '2', 'F']
# answer= ['7', '4', '3', 'F'] ,wrong words= 2
# number  1352
# prdict= ['2', 'R', 'M', '9']
# answer= ['Z', 'R', 'M', '9'] ,wrong words= 1
# number  1354
# prdict= ['N', '2', 'H', 'A']
# answer= ['N', 'Z', 'H', 'A'] ,wrong words= 1
# number  1358
# prdict= ['R', '2', 'P', '5']
# answer= ['R', 'Z', 'P', '5'] ,wrong words= 1
# number  1448
# prdict= ['2', 'H', 'K', 'F']
# answer= ['Z', 'H', 'K', 'F'] ,wrong words= 1
# number  1481
# prdict= ['F', 'K', 'N', 'M']
# answer= ['F', 'Q', 'N', 'M'] ,wrong words= 1
# number  1488
# prdict= ['2', 'C', 'P', 'K']
# answer= ['Z', 'C', 'P', 'K'] ,wrong words= 1
# number  1526
# prdict= ['4', 'Z', '2', 'A']
# answer= ['4', 'Z', 'A', '2'] ,wrong words= 2
# number  1568
# prdict= ['F', 'P', '4', '5']
# answer= ['P', 'P', '4', '5'] ,wrong words= 1
# number  1573
# prdict= ['K', '2', 'A', '5']
# answer= ['K', 'Z', 'A', '5'] ,wrong words= 1
# number  1617
# prdict= ['9', 'Y', '7', 'C']
# answer= ['9', 'Y', 'T', 'C'] ,wrong words= 1
# number  1669
# prdict= ['5', 'H', 'Y', '4']
# answer= ['3', 'H', 'Y', '4'] ,wrong words= 1
# number  1732
# prdict= ['A', 'Z', 'C', 'K']
# answer= ['A', 'C', 'Z', 'K'] ,wrong words= 2
# number  1773
# prdict= ['F', '5', '9', 'P']
# answer= ['F', '3', '9', 'P'] ,wrong words= 1
# number  1802
# prdict= ['F', 'A', 'Z', 'Y']
# answer= ['F', '7', 'Z', 'Y'] ,wrong words= 1
# number  1827
# prdict= ['4', 'K', 'A', '7']
# answer= ['4', 'K', 'A', 'T'] ,wrong words= 1
# number  1876
# prdict= ['F', 'Y', '3', 'N']
# answer= ['P', 'Y', '3', 'N'] ,wrong words= 1
# number  1881
# prdict= ['H', 'Q', 'F', 'Q']
# answer= ['H', 'Q', 'F', 'H'] ,wrong words= 1
# number  1893
# prdict= ['H', 'Q', '7', 'Y']
# answer= ['H', 'Q', '7', 'C'] ,wrong words= 1
# number  1915
# prdict= ['C', 'C', '7', '7']
# answer= ['C', 'C', '7', 'T'] ,wrong words= 1
# number  1919
# prdict= ['9', '2', '4', '7']
# answer= ['9', '2', '4', 'Z'] ,wrong words= 1
# number  2093
# prdict= ['5', 'K', '2', '5']
# answer= ['5', 'K', 'Z', '5'] ,wrong words= 1
# number  2098
# prdict= ['P', 'K', 'M', '4']
# answer= ['P', 'R', 'M', '4'] ,wrong words= 1
# number  2146
# prdict= ['A', 'T', 'K', 'T']
# answer= ['A', 'Y', 'K', 'Y'] ,wrong words= 2
# number  2148
# prdict= ['N', '7', '5', 'T']
# answer= ['N', '7', '5', 'Y'] ,wrong words= 1
# number  2185
# prdict= ['T', '5', 'M', '7']
# answer= ['T', '3', 'M', '7'] ,wrong words= 1
# number  2196
# prdict= ['Z', '3', 'C', '9']
# answer= ['Z', 'C', 'C', '9'] ,wrong words= 1
# number  2223
# prdict= ['M', 'N', 'Z', '2']
# answer= ['M', 'N', 'Z', '4'] ,wrong words= 1
# number  2247
# prdict= ['H', 'T', '2', 'H']
# answer= ['H', 'T', '3', 'H'] ,wrong words= 1
# number  2309
# prdict= ['5', 'Z', 'H', '4']
# answer= ['5', 'N', 'H', '4'] ,wrong words= 1
# number  2341
# prdict= ['C', '2', 'R', 'M']
# answer= ['C', '2', 'R', 'N'] ,wrong words= 1
# number  2356
# prdict= ['N', '2', '9', 'N']
# answer= ['N', '2', 'N', '9'] ,wrong words= 2
# number  2369
# prdict= ['Y', 'T', 'H', 'M']
# answer= ['Y', 'T', 'F', 'M'] ,wrong words= 1
# number  2409
# prdict= ['K', '7', 'C', '2']
# answer= ['M', '7', 'C', '2'] ,wrong words= 1
# number  2439
# prdict= ['3', 'A', '9', 'H']
# answer= ['3', 'A', '4', '9'] ,wrong words= 2
# number  2457
# prdict= ['R', '5', '5', 'A']
# answer= ['R', '5', '9', 'A'] ,wrong words= 1
# number  2458
# prdict= ['A', 'M', '3', '4']
# answer= ['A', '3', '3', '4'] ,wrong words= 1
# number  2540
# prdict= ['C', '3', 'A', '4']
# answer= ['C', '3', '4', 'A'] ,wrong words= 2
# number  2559
# prdict= ['2', 'Z', '3', 'P']
# answer= ['Z', 'Z', '3', 'P'] ,wrong words= 1
# number  2581
# prdict= ['Q', 'Z', 'F', '7']
# answer= ['Q', 'Z', 'F', 'C'] ,wrong words= 1
# number  2609
# prdict= ['Y', 'F', '3', 'F']
# answer= ['Y', 'F', '3', 'Y'] ,wrong words= 1
# number  2647
# prdict= ['7', 'Y', 'T', 'N']
# answer= ['7', 'Y', 'T', 'M'] ,wrong words= 1
# number  2658
# prdict= ['C', 'Y', '9', 'C']
# answer= ['C', 'Y', 'C', '9'] ,wrong words= 2
# number  2682
# prdict= ['F', 'A', 'T', 'M']
# answer= ['F', 'A', 'Y', 'M'] ,wrong words= 1
# number  2747
# prdict= ['F', 'K', 'Y', 'T']
# answer= ['P', 'K', 'Y', 'T'] ,wrong words= 1
# number  2793
# prdict= ['4', 'T', 'M', 'H']
# answer= ['4', 'T', 'M', 'N'] ,wrong words= 1
# number  2832
# prdict= ['4', '5', 'F', 'T']
# answer= ['4', '5', 'Z', 'T'] ,wrong words= 1
# number  2846
# prdict= ['M', 'M', 'M', 'C']
# answer= ['M', 'M', 'F', 'C'] ,wrong words= 1
# number  2853
# prdict= ['Y', '7', '3', 'Z']
# answer= ['Y', 'A', '3', 'Z'] ,wrong words= 1
# number  2950
# prdict= ['Z', '9', 'T', 'C']
# answer= ['Z', '9', 'T', 'Z'] ,wrong words= 1
# 3000 picture total wrong=100
# one word accuracy= 0.9916666666666667
# four word accuracy= 0.9726666666666667
# 0.0
# 47.84217667579651
# 0.001961231231689453

# %%
#測試test
#先把model load進來
model1=load_model("models/Adamax-10-0.9920.h5")
model2=load_model("models/Adamax-18-0.9920.h5")
model3=load_model("models/RMSprop-11-0.9952.h5")
#將y_onehot和x_test變成global加快速度
with h5.File('test.h5','r') as file:
        x_test=file.get("x").value/255
data=scipy.io.loadmat("test.mat")
y_onehot=data['y_onehot']
filenum=x_test.shape[0]
def ThreeModelTestTrain(model1,model2,model3):
    global filenum
    time_start1=time.time()
    l=[]
    time_end1=time.time()
    time_start2=time.time()
    for i in range(filenum):
        imacc,facc=ThreeModelPredict(model1,model2,model3,i)
        l.append((imacc,facc))
    time_end2=time.time()
    time_start3=time.time()
    sigma=np.asarray(np.sum(np.asarray(l),axis=0))
    imgaccuracy=sigma[0]/filenum
    fourwordccuracy=sigma[1]/(4*filenum)
    print('%d picture total wrong=%d'%(filenum,4*filenum-sigma[1]))
    print('one word accuracy=',fourwordccuracy)
    print('four word accuracy=',imgaccuracy)  
    time_end3=time.time()
    print(time_end1-time_start1)
    print(time_end2-time_start2)
    print(time_end3-time_start3)

def ThreeModelPredict(model1,model2,model3,count):
    global y_onehot,x_test
    y=y_onehot.reshape((int(y_onehot.shape[0]/4),4,19))
    img = x_test[count]
    img = np.expand_dims(img,axis=0)       
    x1,x2,x3=EeachModelPredict(model1,model2,model3,img)
    datasheet={"0":"2","1":"3","2":"4","3":'5',"4":'7',"5":'9',"6":'A',"7":'C',"8":'F',"9":'H',"10":'K',"11":'M',"12":'N',"13":'P',"14":'Q',"15":'R',"16":'T',"17":'Y',"18":'Z'}
    pdt1=[datasheet[str(i[0])]for i in x1] #預測為['A','B','C','D']
    pdt2=[datasheet[str(i[0])]for i in x2]
    pdt3=[datasheet[str(i[0])]for i in x3]
    ans=[datasheet[str(np.argmax(y[count][i]))] for i in range(4)]#答案為['A','B','C','D']
    fouracc=0
    imgacc=0
    #處理三個網路預測的結果，分析哪個為最終結果
    if pdt1==pdt2==pdt3:
        pdt=pdt1
    elif pdt1==pdt2:
        pdt=pdt1
    elif pdt1==pdt3:  
        pdt=pdt1
    elif pdt2==pdt3:  
        pdt=pdt2
    else:
        pdt=pdt3
    #確認有幾個字對
    for ind,letter in enumerate(pdt):
        if letter==ans[ind]:
            fouracc+=1

    if pdt==ans:
        imgacc=1
    if count <40:
        print("number ",count)
        if count <=5:
            plt.imshow(x_test[count])
            plt.show()
        print("prdict=",pdt)
        print("answer=",ans,",wrong words=",4-fouracc)
        if count==39:
            print("number ",count)
    if fouracc!=4:
        print("number ",count)
        plt.imshow(x_test[count])
        plt.show()
        print("prdict=",pdt)
        print("answer=",ans,",wrong words=",4-fouracc)
    return imgacc,fouracc

def EeachModelPredict(model1,model2,model3,img):
    x1 = np.argmax(model1.predict(img),axis=2) #x1:Adamax-10-0.9920.h5
    x2 = np.argmax(model2.predict(img),axis=2) #x2:Adamax-18-0.9920.h5
    x3 = np.argmax(model3.predict(img),axis=2) #x3:RMSprop-11-0.9952.h5
    return x1,x2,x3
ThreeModelTestTrain(model1,model2,model3)
# Out:
# C:\Users\苯異丙胺\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:8: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
# number  0
# prdict= ['7', 'F', '9', '4']
# answer= ['7', 'F', '9', '4'] ,wrong words= 0
# number  1
# prdict= ['4', '2', 'T', '7']
# answer= ['4', '2', 'T', '7'] ,wrong words= 0
# number  2
# prdict= ['C', 'Y', 'T', 'F']
# answer= ['C', 'Y', 'T', 'F'] ,wrong words= 0
# number  3
# prdict= ['T', 'M', 'F', 'T']
# answer= ['T', 'M', 'F', 'T'] ,wrong words= 0
# number  4
# prdict= ['P', '7', 'K', 'R']
# answer= ['P', '7', 'K', 'R'] ,wrong words= 0
# number  5
# prdict= ['N', '2', 'Z', 'K']
# answer= ['N', '2', 'Z', 'K'] ,wrong words= 0
# number  6
# prdict= ['7', '4', 'F', 'Y']
# answer= ['7', '4', 'F', 'Y'] ,wrong words= 0
# number  7
# prdict= ['Z', 'Z', '5', 'C']
# answer= ['Z', 'Z', '5', 'C'] ,wrong words= 0
# number  8
# prdict= ['7', 'Z', '4', '4']
# answer= ['7', 'Z', '4', '4'] ,wrong words= 0
# number  9
# prdict= ['R', '4', 'Z', 'C']
# answer= ['R', '4', 'Z', 'C'] ,wrong words= 0
# number  10
# prdict= ['Y', '2', '5', 'T']
# answer= ['Y', '2', '5', 'T'] ,wrong words= 0
# number  11
# prdict= ['F', 'M', '2', '2']
# answer= ['F', 'M', '2', '2'] ,wrong words= 0
# number  12
# prdict= ['Y', '4', 'M', '4']
# answer= ['Y', '4', 'M', '4'] ,wrong words= 0
# number  13
# prdict= ['M', '2', 'Q', '2']
# answer= ['M', '2', 'Q', '2'] ,wrong words= 0
# number  14
# prdict= ['F', 'F', '7', 'N']
# answer= ['F', 'F', '7', 'N'] ,wrong words= 0
# number  15
# prdict= ['9', '5', 'R', 'M']
# answer= ['9', '5', 'R', 'M'] ,wrong words= 0
# number  16
# prdict= ['T', '4', 'T', '5']
# answer= ['T', '4', 'T', '5'] ,wrong words= 0
# number  17
# prdict= ['F', '3', '4', 'A']
# answer= ['F', '3', '4', '3'] ,wrong words= 1
# number  17
# prdict= ['F', '3', '4', 'A']
# answer= ['F', '3', '4', '3'] ,wrong words= 1
# number  18
# prdict= ['F', 'A', '4', 'A']
# answer= ['F', 'A', '4', 'A'] ,wrong words= 0
# number  19
# prdict= ['3', '2', 'H', '4']
# answer= ['3', '2', 'H', '4'] ,wrong words= 0
# number  20
# prdict= ['Q', 'H', 'M', 'A']
# answer= ['Q', 'H', 'M', 'A'] ,wrong words= 0
# number  21
# prdict= ['P', 'Y', 'C', 'P']
# answer= ['P', 'Y', 'C', 'P'] ,wrong words= 0
# number  22
# prdict= ['A', 'P', 'N', 'M']
# answer= ['A', 'P', 'N', 'M'] ,wrong words= 0
# number  23
# prdict= ['R', 'M', 'Q', 'N']
# answer= ['R', 'M', 'Q', 'N'] ,wrong words= 0
# number  24
# prdict= ['K', 'Z', '7', '4']
# answer= ['K', 'Z', '7', '4'] ,wrong words= 0
# number  25
# prdict= ['N', 'F', 'Z', 'H']
# answer= ['N', 'F', 'Z', 'H'] ,wrong words= 0
# number  26
# prdict= ['Y', '2', '7', 'R']
# answer= ['Y', '2', '7', 'R'] ,wrong words= 0
# number  27
# prdict= ['A', 'Y', 'R', 'K']
# answer= ['A', 'Y', 'R', '4'] ,wrong words= 1
# number  27
# prdict= ['A', 'Y', 'R', 'K']
# answer= ['A', 'Y', 'R', '4'] ,wrong words= 1
# number  28
# prdict= ['M', '9', '4', 'Y']
# answer= ['M', '9', '4', 'Y'] ,wrong words= 0
# number  29
# prdict= ['3', '5', 'Q', '7']
# answer= ['3', '5', 'Q', '7'] ,wrong words= 0
# number  30
# prdict= ['A', 'Y', 'H', 'A']
# answer= ['A', 'Y', 'H', 'A'] ,wrong words= 0
# number  31
# prdict= ['T', 'R', '4', '5']
# answer= ['T', 'R', '4', '5'] ,wrong words= 0
# number  32
# prdict= ['Q', 'T', 'R', '4']
# answer= ['Q', 'T', 'R', '4'] ,wrong words= 0
# number  33
# prdict= ['2', '7', '3', 'A']
# answer= ['2', '7', '3', 'A'] ,wrong words= 0
# number  34
# prdict= ['Q', 'M', 'Y', 'F']
# answer= ['Q', 'M', 'Y', 'F'] ,wrong words= 0
# number  35
# prdict= ['2', 'Y', 'N', 'K']
# answer= ['2', 'Y', 'N', 'K'] ,wrong words= 0
# number  36
# prdict= ['R', 'H', 'T', 'P']
# answer= ['R', 'H', 'T', 'P'] ,wrong words= 0
# number  37
# prdict= ['7', 'K', 'Q', 'M']
# answer= ['7', 'K', 'Q', '5'] ,wrong words= 1
# number  37
# prdict= ['7', 'K', 'Q', 'M']
# answer= ['7', 'K', 'Q', '5'] ,wrong words= 1
# number  38
# prdict= ['7', 'H', 'Y', 'P']
# answer= ['7', 'H', 'Y', 'P'] ,wrong words= 0
# number  39
# prdict= ['5', 'M', '3', 'K']
# answer= ['5', 'M', '3', 'K'] ,wrong words= 0
# number  39
# number  90
# prdict= ['5', 'Q', 'P', 'N']
# answer= ['3', 'Q', 'P', 'N'] ,wrong words= 1
# number  165
# prdict= ['5', 'C', 'N', 'H']
# answer= ['3', 'C', 'N', 'H'] ,wrong words= 1
# number  168
# prdict= ['K', '9', 'K', 'P']
# answer= ['K', '9', 'K', '9'] ,wrong words= 1
# number  454
# prdict= ['9', 'H', 'R', 'K']
# answer= ['9', 'H', 'R', 'Q'] ,wrong words= 1
# number  502
# prdict= ['T', 'P', 'T', '3']
# answer= ['7', 'P', 'T', '3'] ,wrong words= 1
# number  641
# prdict= ['2', 'M', '4', 'K']
# answer= ['Z', 'M', '4', 'K'] ,wrong words= 1
# number  687
# prdict= ['Y', 'H', 'K', 'T']
# answer= ['Y', 'M', 'K', 'T'] ,wrong words= 1
# number  695
# prdict= ['5', 'Q', 'Y', '2']
# answer= ['5', 'Q', 'Y', 'Z'] ,wrong words= 1
# number  762
# prdict= ['Z', 'H', '2', '3']
# answer= ['Z', 'M', '2', '3'] ,wrong words= 1
# number  782
# prdict= ['P', 'F', 'C', 'Z']
# answer= ['F', 'F', 'C', 'Z'] ,wrong words= 1
# number  859
# prdict= ['A', 'P', '4', 'P']
# answer= ['A', 'F', '4', 'P'] ,wrong words= 1
# number  927
# prdict= ['C', '3', 'N', '3']
# answer= ['C', '3', 'N', 'C'] ,wrong words= 1
# number  1112
# prdict= ['5', 'A', 'C', 'R']
# answer= ['3', 'A', 'C', 'R'] ,wrong words= 1
# number  1174
# prdict= ['H', 'A', 'Z', 'Y']
# answer= ['M', 'A', 'Z', 'Y'] ,wrong words= 1
# number  1243
# prdict= ['T', 'A', 'R', '5']
# answer= ['7', 'A', 'R', '5'] ,wrong words= 1
# number  1292
# prdict= ['5', 'Z', '7', '3']
# answer= ['3', 'Z', '7', '3'] ,wrong words= 1
# number  1306
# prdict= ['2', 'Y', '9', 'H']
# answer= ['Z', 'Y', '9', 'H'] ,wrong words= 1
# number  1313
# prdict= ['K', '2', 'Z', 'P']
# answer= ['K', 'Z', 'Z', 'P'] ,wrong words= 1
# number  1324
# prdict= ['2', 'M', 'K', 'K']
# answer= ['Z', 'M', 'K', 'K'] ,wrong words= 1
# number  1335
# prdict= ['K', 'A', 'Z', 'A']
# answer= ['9', '7', '7', '3'] ,wrong words= 4
# number  1336
# prdict= ['7', 'F', 'H', 'M']
# answer= ['R', 'F', 'K', '3'] ,wrong words= 3
# number  1337
# prdict= ['N', '7', '7', 'M']
# answer= ['Z', 'M', '4', 'N'] ,wrong words= 4
# number  1338
# prdict= ['K', 'Y', '4', 'T']
# answer= ['A', 'F', '4', 'H'] ,wrong words= 3
# number  1348
# prdict= ['7', '3', '2', 'F']
# answer= ['7', '4', '3', 'F'] ,wrong words= 2
# number  1352
# prdict= ['2', 'R', 'M', '9']
# answer= ['Z', 'R', 'M', '9'] ,wrong words= 1
# number  1354
# prdict= ['N', '2', 'H', 'A']
# answer= ['N', 'Z', 'H', 'A'] ,wrong words= 1
# number  1358
# prdict= ['R', '2', 'P', '5']
# answer= ['R', 'Z', 'P', '5'] ,wrong words= 1
# number  1448
# prdict= ['2', 'H', 'K', 'F']
# answer= ['Z', 'H', 'K', 'F'] ,wrong words= 1
# number  1481
# prdict= ['F', 'K', 'N', 'M']
# answer= ['F', 'Q', 'N', 'M'] ,wrong words= 1
# number  1488
# prdict= ['2', 'C', 'P', 'K']
# answer= ['Z', 'C', 'P', 'K'] ,wrong words= 1
# number  1526
# prdict= ['4', 'Z', '2', 'A']
# answer= ['4', 'Z', 'A', '2'] ,wrong words= 2
# number  1568
# prdict= ['F', 'P', '4', '5']
# answer= ['P', 'P', '4', '5'] ,wrong words= 1
# number  1617
# prdict= ['9', 'Y', '7', 'C']
# answer= ['9', 'Y', 'T', 'C'] ,wrong words= 1
# number  1669
# prdict= ['5', 'H', 'Y', '4']
# answer= ['3', 'H', 'Y', '4'] ,wrong words= 1
# number  1732
# prdict= ['A', 'Z', 'C', 'K']
# answer= ['A', 'C', 'Z', 'K'] ,wrong words= 2
# number  1773
# prdict= ['F', '5', '9', 'P']
# answer= ['F', '3', '9', 'P'] ,wrong words= 1
# number  1802
# prdict= ['F', 'A', 'Z', 'Y']
# answer= ['F', '7', 'Z', 'Y'] ,wrong words= 1
# number  1827
# prdict= ['4', 'K', 'A', '7']
# answer= ['4', 'K', 'A', 'T'] ,wrong words= 1
# number  1876
# prdict= ['P', 'Y', 'P', 'N']
# answer= ['P', 'Y', '3', 'N'] ,wrong words= 1
# number  1881
# prdict= ['H', 'Q', 'F', 'Q']
# answer= ['H', 'Q', 'F', 'H'] ,wrong words= 1
# number  1893
# prdict= ['H', 'Q', '7', 'Y']
# answer= ['H', 'Q', '7', 'C'] ,wrong words= 1
# number  1915
# prdict= ['C', 'C', '7', '7']
# answer= ['C', 'C', '7', 'T'] ,wrong words= 1
# number  1919
# prdict= ['9', '2', '4', '7']
# answer= ['9', '2', '4', 'Z'] ,wrong words= 1
# number  2093
# prdict= ['5', 'K', '2', '5']
# answer= ['5', 'K', 'Z', '5'] ,wrong words= 1
# number  2098
# prdict= ['P', 'K', 'M', '4']
# answer= ['P', 'R', 'M', '4'] ,wrong words= 1
# number  2146
# prdict= ['A', 'T', 'K', 'T']
# answer= ['A', 'Y', 'K', 'Y'] ,wrong words= 2
# number  2148
# prdict= ['N', '7', '5', 'T']
# answer= ['N', '7', '5', 'Y'] ,wrong words= 1
# number  2185
# prdict= ['T', '5', 'M', '7']
# answer= ['T', '3', 'M', '7'] ,wrong words= 1
# number  2196
# prdict= ['Z', '3', 'C', '9']
# answer= ['Z', 'C', 'C', '9'] ,wrong words= 1
# number  2223
# prdict= ['M', 'N', 'Z', '2']
# answer= ['M', 'N', 'Z', '4'] ,wrong words= 1
# number  2247
# prdict= ['H', 'T', '2', 'H']
# answer= ['H', 'T', '3', 'H'] ,wrong words= 1
# number  2309
# prdict= ['5', 'Z', 'H', '4']
# answer= ['5', 'N', 'H', '4'] ,wrong words= 1
# number  2341
# prdict= ['C', '2', 'R', 'M']
# answer= ['C', '2', 'R', 'N'] ,wrong words= 1
# number  2356
# prdict= ['N', '2', '9', 'N']
# answer= ['N', '2', 'N', '9'] ,wrong words= 2
# number  2369
# prdict= ['Y', 'T', 'H', 'M']
# answer= ['Y', 'T', 'F', 'M'] ,wrong words= 1
# number  2409
# prdict= ['K', '7', 'C', '2']
# answer= ['M', '7', 'C', '2'] ,wrong words= 1
# number  2439
# prdict= ['3', 'A', '9', 'H']
# answer= ['3', 'A', '4', '9'] ,wrong words= 2
# number  2457
# prdict= ['K', '5', '9', 'A']
# answer= ['R', '5', '9', 'A'] ,wrong words= 1
# number  2458
# prdict= ['A', 'M', '3', '4']
# answer= ['A', '3', '3', '4'] ,wrong words= 1
# number  2540
# prdict= ['C', '3', 'A', '4']
# answer= ['C', '3', '4', 'A'] ,wrong words= 2
# number  2568
# prdict= ['P', 'C', 'H', 'R']
# answer= ['F', 'C', 'H', 'R'] ,wrong words= 1
# number  2581
# prdict= ['Q', 'Z', 'F', '7']
# answer= ['Q', 'Z', 'F', 'C'] ,wrong words= 1
# number  2609
# prdict= ['Y', 'F', '3', 'F']
# answer= ['Y', 'F', '3', 'Y'] ,wrong words= 1
# number  2647
# prdict= ['7', 'Y', 'T', 'N']
# answer= ['7', 'Y', 'T', 'M'] ,wrong words= 1
# number  2658
# prdict= ['C', 'Y', '9', 'C']
# answer= ['C', 'Y', 'C', '9'] ,wrong words= 2
# number  2747
# prdict= ['F', 'K', 'Y', 'T']
# answer= ['P', 'K', 'Y', 'T'] ,wrong words= 1
# number  2793
# prdict= ['4', 'T', 'M', 'H']
# answer= ['4', 'T', 'M', 'N'] ,wrong words= 1
# number  2832
# prdict= ['4', '5', 'F', 'T']
# answer= ['4', '5', 'Z', 'T'] ,wrong words= 1
# number  2853
# prdict= ['Y', '7', '3', 'Z']
# answer= ['Y', 'A', '3', 'Z'] ,wrong words= 1
# number  2950
# prdict= ['Z', '9', 'T', 'C']
# answer= ['Z', '9', 'T', 'Z'] ,wrong words= 1
# 3000 picture total wrong=91
# one word accuracy= 0.9924166666666666
# four word accuracy= 0.9756666666666667
# 0.0
# 46.91606092453003
# 0.0019533634185791016

# %%
#一個model預測test
model=load_model("models/Adamax-10-0.9920.h5")
with h5.File('test.h5','r') as file:
        x_test=file.get("x").value/255
data=scipy.io.loadmat("test.mat")
y_onehot=data['y_onehot']
filenum=x_test.shape[0]
def OneModelTestOwn(model):
    global filenum
    time_start1=time.time()
    l=[]
    time_end1=time.time()
    time_start2=time.time()
    for i in range(filenum):
        imacc,facc=OneModelPredict(model,i)
        l.append((imacc,facc))
    time_end2=time.time()
    time_start3=time.time()
    sigma=np.asarray(np.sum(np.asarray(l),axis=0))
    imgaccuracy=sigma[0]/filenum
    fourwordccuracy=sigma[1]/(4*filenum)
    print('%d picture total wrong=%d'%(filenum,4*filenum-sigma[1]))
    print('one word accuracy=',fourwordccuracy)
    print('four word accuracy=',imgaccuracy)  
    time_end3=time.time()
    print(time_end1-time_start1)
    print(time_end2-time_start2)
    print(time_end3-time_start3)

def OneModelPredict(model,count):
    global y_onehot,x_test
    y=y_onehot.reshape((int(y_onehot.shape[0]/4),4,19))
    img = x_test[count]
    img = np.expand_dims(img,axis=0) 
    x1 = np.argmax(model.predict(img),axis=2) 
    datasheet={"0":"2","1":"3","2":"4","3":'5',"4":'7',"5":'9',"6":'A',"7":'C',"8":'F',"9":'H',"10":'K',"11":'M',"12":'N',"13":'P',"14":'Q',"15":'R',"16":'T',"17":'Y',"18":'Z'}
    pdt=[datasheet[str(i[0])]for i in x1] #預測為['A','B','C','D']
    ans=[datasheet[str(np.argmax(y[count][i]))] for i in range(4)]#答案為['A','B','C','D']
    fouracc=0
    imgacc=0

    #確認有幾個字對
    for ind,letter in enumerate(pdt):
        if letter==ans[ind]:
            fouracc+=1
    if pdt==ans:
        imgacc=1
    if count <=40:
        print("number ",count)
        if count <=5:
            plt.imshow(x_test[count])
            plt.show()
        print("prdict=",pdt)
        print("answer=",ans,",wrong words=",4-fouracc)
    if fouracc!=4:
        print("number ",count)
        plt.imshow(x_test[count])
        plt.show()
        print("prdict=",pdt)
        print("answer=",ans,",wrong words=",4-fouracc)
    return imgacc,fouracc
OneModelTestOwn(model)
# Out:
# C:\Users\苯異丙胺\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:4: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   after removing the cwd from sys.path.
# number  0
# prdict= ['7', 'F', '9', '4']
# answer= ['7', 'F', '9', '4'] ,wrong words= 0
# number  1
# prdict= ['4', '2', 'T', '7']
# answer= ['4', '2', 'T', '7'] ,wrong words= 0
# number  2
# prdict= ['C', 'Y', 'T', 'F']
# answer= ['C', 'Y', 'T', 'F'] ,wrong words= 0
# number  3
# prdict= ['T', 'M', 'F', 'T']
# answer= ['T', 'M', 'F', 'T'] ,wrong words= 0
# number  4
# prdict= ['P', '7', 'K', 'R']
# answer= ['P', '7', 'K', 'R'] ,wrong words= 0
# number  5
# prdict= ['N', '2', 'Z', 'K']
# answer= ['N', '2', 'Z', 'K'] ,wrong words= 0
# number  6
# prdict= ['7', '4', 'F', 'Y']
# answer= ['7', '4', 'F', 'Y'] ,wrong words= 0
# number  7
# prdict= ['Z', 'Z', '5', 'C']
# answer= ['Z', 'Z', '5', 'C'] ,wrong words= 0
# number  8
# prdict= ['7', 'Z', '4', '4']
# answer= ['7', 'Z', '4', '4'] ,wrong words= 0
# number  9
# prdict= ['R', '4', 'Z', 'C']
# answer= ['R', '4', 'Z', 'C'] ,wrong words= 0
# number  10
# prdict= ['Y', '2', '5', 'T']
# answer= ['Y', '2', '5', 'T'] ,wrong words= 0
# number  11
# prdict= ['F', 'M', '2', '2']
# answer= ['F', 'M', '2', '2'] ,wrong words= 0
# number  12
# prdict= ['Y', '4', 'M', '4']
# answer= ['Y', '4', 'M', '4'] ,wrong words= 0
# number  13
# prdict= ['M', '2', 'Q', '2']
# answer= ['M', '2', 'Q', '2'] ,wrong words= 0
# number  14
# prdict= ['P', 'F', '7', 'N']
# answer= ['F', 'F', '7', 'N'] ,wrong words= 1
# number  14
# prdict= ['P', 'F', '7', 'N']
# answer= ['F', 'F', '7', 'N'] ,wrong words= 1
# number  15
# prdict= ['9', '5', 'R', 'M']
# answer= ['9', '5', 'R', 'M'] ,wrong words= 0
# number  16
# prdict= ['T', '4', 'T', '5']
# answer= ['T', '4', 'T', '5'] ,wrong words= 0
# number  17
# prdict= ['F', '3', '4', 'A']
# answer= ['F', '3', '4', '3'] ,wrong words= 1
# number  17
# prdict= ['F', '3', '4', 'A']
# answer= ['F', '3', '4', '3'] ,wrong words= 1
# number  18
# prdict= ['F', 'A', '4', 'A']
# answer= ['F', 'A', '4', 'A'] ,wrong words= 0
# number  19
# prdict= ['3', '2', 'H', '4']
# answer= ['3', '2', 'H', '4'] ,wrong words= 0
# number  20
# prdict= ['Q', 'H', 'M', 'A']
# answer= ['Q', 'H', 'M', 'A'] ,wrong words= 0
# number  21
# prdict= ['P', 'Y', 'C', 'P']
# answer= ['P', 'Y', 'C', 'P'] ,wrong words= 0
# number  22
# prdict= ['A', 'P', 'N', 'M']
# answer= ['A', 'P', 'N', 'M'] ,wrong words= 0
# number  23
# prdict= ['R', 'M', 'Q', 'N']
# answer= ['R', 'M', 'Q', 'N'] ,wrong words= 0
# number  24
# prdict= ['K', 'Z', '7', '4']
# answer= ['K', 'Z', '7', '4'] ,wrong words= 0
# number  25
# prdict= ['N', 'F', 'Z', 'H']
# answer= ['N', 'F', 'Z', 'H'] ,wrong words= 0
# number  26
# prdict= ['Y', '2', '7', 'R']
# answer= ['Y', '2', '7', 'R'] ,wrong words= 0
# number  27
# prdict= ['A', 'Y', 'R', 'K']
# answer= ['A', 'Y', 'R', '4'] ,wrong words= 1
# number  27
# prdict= ['A', 'Y', 'R', 'K']
# answer= ['A', 'Y', 'R', '4'] ,wrong words= 1
# number  28
# prdict= ['M', '9', '4', 'Y']
# answer= ['M', '9', '4', 'Y'] ,wrong words= 0
# number  29
# prdict= ['3', '5', 'Q', '7']
# answer= ['3', '5', 'Q', '7'] ,wrong words= 0
# number  30
# prdict= ['A', 'Y', 'H', 'A']
# answer= ['A', 'Y', 'H', 'A'] ,wrong words= 0
# number  31
# prdict= ['T', 'R', '4', '5']
# answer= ['T', 'R', '4', '5'] ,wrong words= 0
# number  32
# prdict= ['Q', 'T', 'R', '4']
# answer= ['Q', 'T', 'R', '4'] ,wrong words= 0
# number  33
# prdict= ['2', '7', '3', 'A']
# answer= ['2', '7', '3', 'A'] ,wrong words= 0
# number  34
# prdict= ['Q', 'M', 'Y', 'F']
# answer= ['Q', 'M', 'Y', 'F'] ,wrong words= 0
# number  35
# prdict= ['2', 'Y', 'N', 'K']
# answer= ['2', 'Y', 'N', 'K'] ,wrong words= 0
# number  36
# prdict= ['R', 'H', 'T', 'P']
# answer= ['R', 'H', 'T', 'P'] ,wrong words= 0
# number  37
# prdict= ['7', 'K', 'Q', 'M']
# answer= ['7', 'K', 'Q', '5'] ,wrong words= 1
# number  37
# prdict= ['7', 'K', 'Q', 'M']
# answer= ['7', 'K', 'Q', '5'] ,wrong words= 1
# number  38
# prdict= ['7', 'H', 'Y', 'P']
# answer= ['7', 'H', 'Y', 'P'] ,wrong words= 0
# number  39
# prdict= ['5', 'M', '3', 'K']
# answer= ['5', 'M', '3', 'K'] ,wrong words= 0
# number  40
# prdict= ['H', 'C', 'Y', 'C']
# answer= ['H', 'C', 'Y', 'C'] ,wrong words= 0
# number  55
# prdict= ['P', 'K', 'F', 'Q']
# answer= ['F', 'K', 'F', 'Q'] ,wrong words= 1
# number  72
# prdict= ['2', '2', 'Z', '2']
# answer= ['2', 'Z', 'Z', 'Z'] ,wrong words= 2
# number  74
# prdict= ['N', '7', '2', 'T']
# answer= ['N', '7', 'Z', 'T'] ,wrong words= 1
# number  90
# prdict= ['5', 'Q', 'P', 'N']
# answer= ['3', 'Q', 'P', 'N'] ,wrong words= 1
# number  140
# prdict= ['C', 'F', 'K', 'T']
# answer= ['C', '2', 'K', 'T'] ,wrong words= 1
# number  165
# prdict= ['5', 'C', 'N', 'H']
# answer= ['3', 'C', 'N', 'H'] ,wrong words= 1
# number  168
# prdict= ['K', '9', 'K', 'P']
# answer= ['K', '9', 'K', '9'] ,wrong words= 1
# number  172
# prdict= ['M', 'P', '3', 'Q']
# answer= ['M', '9', '3', 'Q'] ,wrong words= 1
# number  268
# prdict= ['3', 'H', 'C', 'F']
# answer= ['5', 'H', 'C', 'F'] ,wrong words= 1
# number  323
# prdict= ['A', '2', 'H', 'Q']
# answer= ['A', 'Z', 'H', 'Q'] ,wrong words= 1
# number  351
# prdict= ['K', 'T', 'R', 'N']
# answer= ['K', 'T', 'Q', 'N'] ,wrong words= 1
# number  419
# prdict= ['M', 'F', 'K', 'F']
# answer= ['M', '4', 'K', 'F'] ,wrong words= 1
# number  441
# prdict= ['K', 'P', 'A', 'T']
# answer= ['K', '9', 'A', 'T'] ,wrong words= 1
# number  454
# prdict= ['9', 'H', 'R', 'K']
# answer= ['9', 'H', 'R', 'Q'] ,wrong words= 1
# number  502
# prdict= ['T', 'P', 'T', '3']
# answer= ['7', 'P', 'T', '3'] ,wrong words= 1
# number  641
# prdict= ['2', 'M', '4', 'K']
# answer= ['Z', 'M', '4', 'K'] ,wrong words= 1
# number  687
# prdict= ['Y', 'H', 'K', 'T']
# answer= ['Y', 'M', 'K', 'T'] ,wrong words= 1
# number  695
# prdict= ['5', 'Q', 'Y', '2']
# answer= ['5', 'Q', 'Y', 'Z'] ,wrong words= 1
# number  762
# prdict= ['Z', 'H', '2', '3']
# answer= ['Z', 'M', '2', '3'] ,wrong words= 1
# number  782
# prdict= ['P', 'F', 'C', 'Z']
# answer= ['F', 'F', 'C', 'Z'] ,wrong words= 1
# number  803
# prdict= ['P', '5', '2', 'N']
# answer= ['F', '5', '2', 'N'] ,wrong words= 1
# number  841
# prdict= ['Y', 'Y', 'F', '4']
# answer= ['Y', 'Y', 'P', '4'] ,wrong words= 1
# number  859
# prdict= ['A', 'P', '4', 'P']
# answer= ['A', 'F', '4', 'P'] ,wrong words= 1
# number  882
# prdict= ['P', '5', 'F', 'Q']
# answer= ['F', '5', 'F', 'Q'] ,wrong words= 1
# number  927
# prdict= ['C', '3', 'N', '3']
# answer= ['C', '3', 'N', 'C'] ,wrong words= 1
# number  945
# prdict= ['7', 'N', '4', 'F']
# answer= ['2', 'N', '4', 'F'] ,wrong words= 1
# number  974
# prdict= ['H', 'T', 'F', 'Z']
# answer= ['H', 'Y', 'F', 'Z'] ,wrong words= 1
# number  1079
# prdict= ['5', 'P', '7', 'Q']
# answer= ['5', 'P', 'P', 'Q'] ,wrong words= 1
# number  1084
# prdict= ['7', 'T', 'R', 'M']
# answer= ['5', 'Y', 'R', 'M'] ,wrong words= 2
# number  1112
# prdict= ['5', 'A', 'C', 'R']
# answer= ['3', 'A', 'C', 'R'] ,wrong words= 1
# number  1124
# prdict= ['P', '2', 'F', 'K']
# answer= ['F', '2', 'F', 'K'] ,wrong words= 1
# number  1174
# prdict= ['H', 'A', 'Z', 'Y']
# answer= ['M', 'A', 'Z', 'Y'] ,wrong words= 1
# number  1190
# prdict= ['C', 'H', 'F', 'Q']
# answer= ['C', 'H', 'Z', 'Q'] ,wrong words= 1
# number  1243
# prdict= ['T', 'A', 'R', '5']
# answer= ['7', 'A', 'R', '5'] ,wrong words= 1
# number  1282
# prdict= ['H', 'K', '7', 'R']
# answer= ['H', 'C', '7', 'R'] ,wrong words= 1
# number  1292
# prdict= ['5', 'Z', '7', '3']
# answer= ['3', 'Z', '7', '3'] ,wrong words= 1
# number  1306
# prdict= ['2', 'Y', '9', 'H']
# answer= ['Z', 'Y', '9', 'H'] ,wrong words= 1
# number  1313
# prdict= ['K', '2', 'Z', 'P']
# answer= ['K', 'Z', 'Z', 'P'] ,wrong words= 1
# number  1324
# prdict= ['2', 'M', 'K', 'K']
# answer= ['Z', 'M', 'K', 'K'] ,wrong words= 1
# number  1335
# prdict= ['K', 'A', 'Z', 'A']
# answer= ['9', '7', '7', '3'] ,wrong words= 4
# number  1336
# prdict= ['7', 'F', 'H', 'M']
# answer= ['R', 'F', 'K', '3'] ,wrong words= 3
# number  1337
# prdict= ['N', '7', '7', 'M']
# answer= ['Z', 'M', '4', 'N'] ,wrong words= 4
# number  1338
# prdict= ['K', 'Y', '4', 'T']
# answer= ['A', 'F', '4', 'H'] ,wrong words= 3
# number  1348
# prdict= ['7', '3', '2', 'F']
# answer= ['7', '4', '3', 'F'] ,wrong words= 2
# number  1352
# prdict= ['2', 'R', 'M', '9']
# answer= ['Z', 'R', 'M', '9'] ,wrong words= 1
# number  1354
# prdict= ['N', '2', 'H', 'A']
# answer= ['N', 'Z', 'H', 'A'] ,wrong words= 1
# number  1358
# prdict= ['R', '2', 'P', '5']
# answer= ['R', 'Z', 'P', '5'] ,wrong words= 1
# number  1386
# prdict= ['7', 'T', 'N', '7']
# answer= ['7', 'Y', 'N', '7'] ,wrong words= 1
# number  1448
# prdict= ['2', 'H', 'K', 'F']
# answer= ['Z', 'H', 'K', 'F'] ,wrong words= 1
# number  1459
# prdict= ['Y', 'T', 'M', 'T']
# answer= ['Y', 'T', 'M', 'Y'] ,wrong words= 1
# number  1481
# prdict= ['F', 'K', 'N', 'M']
# answer= ['F', 'Q', 'N', 'M'] ,wrong words= 1
# number  1488
# prdict= ['2', 'C', 'P', 'K']
# answer= ['Z', 'C', 'P', 'K'] ,wrong words= 1
# number  1526
# prdict= ['4', 'Z', '2', 'A']
# answer= ['4', 'Z', 'A', '2'] ,wrong words= 2
# number  1568
# prdict= ['F', 'P', '4', '5']
# answer= ['P', 'P', '4', '5'] ,wrong words= 1
# number  1603
# prdict= ['P', 'K', '9', '7']
# answer= ['F', 'K', '9', '7'] ,wrong words= 1
# number  1617
# prdict= ['9', 'Y', '7', 'C']
# answer= ['9', 'Y', 'T', 'C'] ,wrong words= 1
# number  1641
# prdict= ['M', '9', 'T', 'Q']
# answer= ['M', '9', 'F', 'Q'] ,wrong words= 1
# number  1669
# prdict= ['5', 'H', 'Y', '4']
# answer= ['3', 'H', 'Y', '4'] ,wrong words= 1
# number  1732
# prdict= ['A', 'Z', 'C', 'K']
# answer= ['A', 'C', 'Z', 'K'] ,wrong words= 2
# number  1748
# prdict= ['3', 'T', '3', 'C']
# answer= ['5', 'T', '3', 'C'] ,wrong words= 1
# number  1773
# prdict= ['F', '5', '9', 'P']
# answer= ['F', '3', '9', 'P'] ,wrong words= 1
# number  1783
# prdict= ['P', '5', 'M', '7']
# answer= ['F', '5', 'M', '7'] ,wrong words= 1
# number  1793
# prdict= ['P', '2', '2', '7']
# answer= ['F', '2', '2', '7'] ,wrong words= 1
# number  1797
# prdict= ['H', 'P', 'F', 'R']
# answer= ['H', '2', 'F', 'R'] ,wrong words= 1
# number  1802
# prdict= ['F', 'A', 'Z', 'Y']
# answer= ['F', '7', 'Z', 'Y'] ,wrong words= 1
# number  1804
# prdict= ['P', 'H', '7', 'M']
# answer= ['F', 'H', '7', 'M'] ,wrong words= 1
# number  1827
# prdict= ['4', 'K', 'A', '7']
# answer= ['4', 'K', 'A', 'T'] ,wrong words= 1
# number  1845
# prdict= ['A', '2', '7', 'T']
# answer= ['A', 'Z', '7', 'T'] ,wrong words= 1
# number  1868
# prdict= ['A', '2', 'Q', 'A']
# answer= ['A', 'Z', 'Q', 'A'] ,wrong words= 1
# number  1881
# prdict= ['H', 'Q', 'F', 'Q']
# answer= ['H', 'Q', 'F', 'H'] ,wrong words= 1
# number  1893
# prdict= ['H', 'Q', '7', 'Y']
# answer= ['H', 'Q', '7', 'C'] ,wrong words= 1
# number  1915
# prdict= ['C', 'C', '7', '7']
# answer= ['C', 'C', '7', 'T'] ,wrong words= 1
# number  1919
# prdict= ['9', '2', '4', '7']
# answer= ['9', '2', '4', 'Z'] ,wrong words= 1
# number  1965
# prdict= ['M', 'F', 'Q', '5']
# answer= ['M', '4', 'Q', '5'] ,wrong words= 1
# number  1972
# prdict= ['K', 'T', 'P', '5']
# answer= ['K', 'Y', 'P', '5'] ,wrong words= 1
# number  2013
# prdict= ['3', 'P', '5', '4']
# answer= ['3', 'P', '3', '4'] ,wrong words= 1
# number  2093
# prdict= ['5', 'K', '2', '5']
# answer= ['5', 'K', 'Z', '5'] ,wrong words= 1
# number  2098
# prdict= ['P', 'K', 'M', '4']
# answer= ['P', 'R', 'M', '4'] ,wrong words= 1
# number  2146
# prdict= ['A', 'T', 'K', 'T']
# answer= ['A', 'Y', 'K', 'Y'] ,wrong words= 2
# number  2148
# prdict= ['N', '7', '5', 'T']
# answer= ['N', '7', '5', 'Y'] ,wrong words= 1
# number  2149
# prdict= ['3', 'N', 'F', 'K']
# answer= ['5', 'N', 'F', 'K'] ,wrong words= 1
# number  2163
# prdict= ['P', 'P', '5', 'K']
# answer= ['F', 'P', '5', 'K'] ,wrong words= 1
# number  2185
# prdict= ['T', '5', 'M', '7']
# answer= ['T', '3', 'M', '7'] ,wrong words= 1
# number  2196
# prdict= ['Z', '3', 'C', '9']
# answer= ['Z', 'C', 'C', '9'] ,wrong words= 1
# number  2222
# prdict= ['R', 'A', 'Z', 'Q']
# answer= ['F', 'A', 'Z', 'Q'] ,wrong words= 1
# number  2223
# prdict= ['M', 'N', 'Z', '2']
# answer= ['M', 'N', 'Z', '4'] ,wrong words= 1
# number  2232
# prdict= ['K', 'P', 'A', '5']
# answer= ['K', 'P', 'N', '5'] ,wrong words= 1
# number  2242
# prdict= ['3', '2', 'T', 'R']
# answer= ['3', 'Z', 'T', 'R'] ,wrong words= 1
# number  2247
# prdict= ['H', 'T', '2', 'H']
# answer= ['H', 'T', '3', 'H'] ,wrong words= 1
# number  2309
# prdict= ['5', 'Z', 'H', '4']
# answer= ['5', 'N', 'H', '4'] ,wrong words= 1
# number  2311
# prdict= ['M', 'H', '2', 'K']
# answer= ['M', 'H', 'Z', 'K'] ,wrong words= 1
# number  2315
# prdict= ['3', 'M', 'T', '9']
# answer= ['5', 'M', 'T', '9'] ,wrong words= 1
# number  2341
# prdict= ['C', '2', 'R', 'M']
# answer= ['C', '2', 'R', 'N'] ,wrong words= 1
# number  2345
# prdict= ['M', 'K', 'T', 'T']
# answer= ['M', 'R', 'T', 'T'] ,wrong words= 1
# number  2356
# prdict= ['N', '2', '9', 'N']
# answer= ['N', '2', 'N', '9'] ,wrong words= 2
# number  2369
# prdict= ['Y', 'T', 'H', 'M']
# answer= ['Y', 'T', 'F', 'M'] ,wrong words= 1
# number  2409
# prdict= ['K', '7', 'C', '2']
# answer= ['M', '7', 'C', '2'] ,wrong words= 1
# number  2439
# prdict= ['3', 'A', '9', 'H']
# answer= ['3', 'A', '4', '9'] ,wrong words= 2
# number  2458
# prdict= ['A', 'M', '3', '4']
# answer= ['A', '3', '3', '4'] ,wrong words= 1
# number  2462
# prdict= ['C', '3', '7', '2']
# answer= ['C', '9', '7', '2'] ,wrong words= 1
# number  2540
# prdict= ['C', '3', 'A', '4']
# answer= ['C', '3', '4', 'A'] ,wrong words= 2
# number  2543
# prdict= ['K', 'F', 'Y', 'R']
# answer= ['K', 'Y', 'Y', 'R'] ,wrong words= 1
# number  2559
# prdict= ['Z', '2', '3', 'P']
# answer= ['Z', 'Z', '3', 'P'] ,wrong words= 1
# number  2568
# prdict= ['F', 'F', 'H', 'R']
# answer= ['F', 'C', 'H', 'R'] ,wrong words= 1
# number  2581
# prdict= ['Q', 'Z', 'F', '7']
# answer= ['Q', 'Z', 'F', 'C'] ,wrong words= 1
# number  2609
# prdict= ['Y', 'F', '3', 'F']
# answer= ['Y', 'F', '3', 'Y'] ,wrong words= 1
# number  2618
# prdict= ['F', '9', 'Y', 'F']
# answer= ['H', '9', 'Y', 'F'] ,wrong words= 1
# number  2647
# prdict= ['7', 'Y', 'T', 'N']
# answer= ['7', 'Y', 'T', 'M'] ,wrong words= 1
# number  2658
# prdict= ['C', 'Y', '9', 'C']
# answer= ['C', 'Y', 'C', '9'] ,wrong words= 2
# number  2681
# prdict= ['P', '9', 'H', 'K']
# answer= ['F', '9', 'H', 'K'] ,wrong words= 1
# number  2691
# prdict= ['C', '2', '3', '3']
# answer= ['C', 'Z', '3', '3'] ,wrong words= 1
# number  2747
# prdict= ['F', 'K', 'Y', 'T']
# answer= ['P', 'K', 'Y', 'T'] ,wrong words= 1
# number  2793
# prdict= ['4', 'T', 'M', 'H']
# answer= ['4', 'T', 'M', 'N'] ,wrong words= 1
# number  2832
# prdict= ['4', '5', 'F', 'T']
# answer= ['4', '5', 'Z', 'T'] ,wrong words= 1
# number  2846
# prdict= ['M', 'M', 'M', 'C']
# answer= ['M', 'M', 'F', 'C'] ,wrong words= 1
# number  2853
# prdict= ['Y', '7', '3', 'Z']
# answer= ['Y', 'A', '3', 'Z'] ,wrong words= 1
# number  2920
# prdict= ['M', 'C', '2', '4']
# answer= ['M', 'C', 'Z', '4'] ,wrong words= 1
# number  2950
# prdict= ['Z', '9', 'T', 'C']
# answer= ['Z', '9', 'T', 'Z'] ,wrong words= 1
# number  2990
# prdict= ['H', 'H', '7', 'C']
# answer= ['H', 'F', '7', 'C'] ,wrong words= 1
# 3000 picture total wrong=143
# one word accuracy= 0.9880833333333333
# four word accuracy= 0.959
# 0.0
# 28.271981239318848
# 0.0009760856628417969

# %%
#一個model預測test
model=load_model("models/Adamax-18-0.9920.h5")
with h5.File('test.h5','r') as file:
        x_test=file.get("x").value/255
data=scipy.io.loadmat("test.mat")
y_onehot=data['y_onehot']
filenum=x_test.shape[0]
def OneModelTestOwn(model):
    global filenum
    time_start1=time.time()
    l=[]
    time_end1=time.time()
    time_start2=time.time()
    for i in range(filenum):
        imacc,facc=OneModelPredict(model,i)
        l.append((imacc,facc))
    time_end2=time.time()
    time_start3=time.time()
    sigma=np.asarray(np.sum(np.asarray(l),axis=0))
    imgaccuracy=sigma[0]/filenum
    fourwordccuracy=sigma[1]/(4*filenum)
    print('%d picture total wrong=%d'%(filenum,4*filenum-sigma[1]))
    print('one word accuracy=',fourwordccuracy)
    print('four word accuracy=',imgaccuracy)  
    time_end3=time.time()
    print(time_end1-time_start1)
    print(time_end2-time_start2)
    print(time_end3-time_start3)

def OneModelPredict(model,count):
    global y_onehot,x_test
    y=y_onehot.reshape((int(y_onehot.shape[0]/4),4,19))
    img = x_test[count]
    img = np.expand_dims(img,axis=0) 
    x1 = np.argmax(model.predict(img),axis=2) 
    datasheet={"0":"2","1":"3","2":"4","3":'5',"4":'7',"5":'9',"6":'A',"7":'C',"8":'F',"9":'H',"10":'K',"11":'M',"12":'N',"13":'P',"14":'Q',"15":'R',"16":'T',"17":'Y',"18":'Z'}
    pdt=[datasheet[str(i[0])]for i in x1] #預測為['A','B','C','D']
    ans=[datasheet[str(np.argmax(y[count][i]))] for i in range(4)]#答案為['A','B','C','D']
    fouracc=0
    imgacc=0

    #確認有幾個字對
    for ind,letter in enumerate(pdt):
        if letter==ans[ind]:
            fouracc+=1
    if pdt==ans:
        imgacc=1
    if count <=40:
        print("number ",count)
        if count <=5:
            plt.imshow(x_test[count])
            plt.show()
        print("prdict=",pdt)
        print("answer=",ans,",wrong words=",4-fouracc)
    if fouracc!=4:
        print("number ",count)
        plt.imshow(x_test[count])
        plt.show()
        print("prdict=",pdt)
        print("answer=",ans,",wrong words=",4-fouracc)
    return imgacc,fouracc
OneModelTestOwn(model)
# Out:
# C:\Users\苯異丙胺\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:4: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   after removing the cwd from sys.path.
# number  0
# prdict= ['7', 'F', '9', '4']
# answer= ['7', 'F', '9', '4'] ,wrong words= 0
# number  1
# prdict= ['4', '2', 'T', '7']
# answer= ['4', '2', 'T', '7'] ,wrong words= 0
# number  2
# prdict= ['C', 'Y', 'T', 'F']
# answer= ['C', 'Y', 'T', 'F'] ,wrong words= 0
# number  3
# prdict= ['T', 'M', 'F', 'T']
# answer= ['T', 'M', 'F', 'T'] ,wrong words= 0
# number  4
# prdict= ['P', '7', 'K', 'R']
# answer= ['P', '7', 'K', 'R'] ,wrong words= 0
# number  5
# prdict= ['N', '2', 'Z', 'K']
# answer= ['N', '2', 'Z', 'K'] ,wrong words= 0
# number  6
# prdict= ['7', '4', 'F', 'Y']
# answer= ['7', '4', 'F', 'Y'] ,wrong words= 0
# number  7
# prdict= ['Z', 'Z', '5', 'C']
# answer= ['Z', 'Z', '5', 'C'] ,wrong words= 0
# number  8
# prdict= ['7', 'Z', '4', '4']
# answer= ['7', 'Z', '4', '4'] ,wrong words= 0
# number  9
# prdict= ['R', '4', 'Z', 'C']
# answer= ['R', '4', 'Z', 'C'] ,wrong words= 0
# number  10
# prdict= ['Y', '2', '5', 'T']
# answer= ['Y', '2', '5', 'T'] ,wrong words= 0
# number  11
# prdict= ['F', 'M', '2', '2']
# answer= ['F', 'M', '2', '2'] ,wrong words= 0
# number  12
# prdict= ['Y', '4', 'M', '4']
# answer= ['Y', '4', 'M', '4'] ,wrong words= 0
# number  13
# prdict= ['M', '2', 'Q', '2']
# answer= ['M', '2', 'Q', '2'] ,wrong words= 0
# number  14
# prdict= ['F', 'F', '7', 'N']
# answer= ['F', 'F', '7', 'N'] ,wrong words= 0
# number  15
# prdict= ['9', '5', 'R', 'M']
# answer= ['9', '5', 'R', 'M'] ,wrong words= 0
# number  16
# prdict= ['T', '4', 'T', '5']
# answer= ['T', '4', 'T', '5'] ,wrong words= 0
# number  17
# prdict= ['F', '3', '4', 'A']
# answer= ['F', '3', '4', '3'] ,wrong words= 1
# number  17
# prdict= ['F', '3', '4', 'A']
# answer= ['F', '3', '4', '3'] ,wrong words= 1
# number  18
# prdict= ['F', 'A', '4', 'A']
# answer= ['F', 'A', '4', 'A'] ,wrong words= 0
# number  19
# prdict= ['3', '2', 'H', '4']
# answer= ['3', '2', 'H', '4'] ,wrong words= 0
# number  20
# prdict= ['Q', 'H', 'M', 'A']
# answer= ['Q', 'H', 'M', 'A'] ,wrong words= 0
# number  21
# prdict= ['P', 'Y', 'C', 'P']
# answer= ['P', 'Y', 'C', 'P'] ,wrong words= 0
# number  22
# prdict= ['A', 'P', 'N', 'M']
# answer= ['A', 'P', 'N', 'M'] ,wrong words= 0
# number  23
# prdict= ['R', 'M', 'Q', 'N']
# answer= ['R', 'M', 'Q', 'N'] ,wrong words= 0
# number  24
# prdict= ['K', 'Z', '7', '4']
# answer= ['K', 'Z', '7', '4'] ,wrong words= 0
# number  25
# prdict= ['N', 'F', 'Z', 'H']
# answer= ['N', 'F', 'Z', 'H'] ,wrong words= 0
# number  26
# prdict= ['Y', '2', '7', 'R']
# answer= ['Y', '2', '7', 'R'] ,wrong words= 0
# number  27
# prdict= ['A', 'Y', 'R', 'K']
# answer= ['A', 'Y', 'R', '4'] ,wrong words= 1
# number  27
# prdict= ['A', 'Y', 'R', 'K']
# answer= ['A', 'Y', 'R', '4'] ,wrong words= 1
# number  28
# prdict= ['M', '9', '4', 'Y']
# answer= ['M', '9', '4', 'Y'] ,wrong words= 0
# number  29
# prdict= ['3', '5', 'Q', '7']
# answer= ['3', '5', 'Q', '7'] ,wrong words= 0
# number  30
# prdict= ['A', 'Y', 'H', 'A']
# answer= ['A', 'Y', 'H', 'A'] ,wrong words= 0
# number  31
# prdict= ['T', 'R', '4', '5']
# answer= ['T', 'R', '4', '5'] ,wrong words= 0
# number  32
# prdict= ['Q', '7', 'R', '4']
# answer= ['Q', 'T', 'R', '4'] ,wrong words= 1
# number  32
# prdict= ['Q', '7', 'R', '4']
# answer= ['Q', 'T', 'R', '4'] ,wrong words= 1
# number  33
# prdict= ['2', '7', '3', 'A']
# answer= ['2', '7', '3', 'A'] ,wrong words= 0
# number  34
# prdict= ['Q', 'M', 'Y', 'F']
# answer= ['Q', 'M', 'Y', 'F'] ,wrong words= 0
# number  35
# prdict= ['2', 'Y', 'N', 'K']
# answer= ['2', 'Y', 'N', 'K'] ,wrong words= 0
# number  36
# prdict= ['R', 'H', 'T', 'P']
# answer= ['R', 'H', 'T', 'P'] ,wrong words= 0
# number  37
# prdict= ['7', 'K', 'Q', 'M']
# answer= ['7', 'K', 'Q', '5'] ,wrong words= 1
# number  37
# prdict= ['7', 'K', 'Q', 'M']
# answer= ['7', 'K', 'Q', '5'] ,wrong words= 1
# number  38
# prdict= ['7', 'H', 'Y', 'P']
# answer= ['7', 'H', 'Y', 'P'] ,wrong words= 0
# number  39
# prdict= ['5', 'M', '3', 'K']
# answer= ['5', 'M', '3', 'K'] ,wrong words= 0
# number  40
# prdict= ['H', 'C', 'Y', 'C']
# answer= ['H', 'C', 'Y', 'C'] ,wrong words= 0
# number  90
# prdict= ['9', 'Q', 'P', 'N']
# answer= ['3', 'Q', 'P', 'N'] ,wrong words= 1
# number  116
# prdict= ['2', '7', 'M', 'Y']
# answer= ['P', '7', 'M', 'Y'] ,wrong words= 1
# number  165
# prdict= ['5', 'C', 'N', 'H']
# answer= ['3', 'C', 'N', 'H'] ,wrong words= 1
# number  168
# prdict= ['K', '9', 'K', 'P']
# answer= ['K', '9', 'K', '9'] ,wrong words= 1
# number  197
# prdict= ['5', 'Y', '4', 'A']
# answer= ['5', 'Y', 'Z', 'A'] ,wrong words= 1
# number  207
# prdict= ['M', 'A', 'N', '3']
# answer= ['M', 'A', 'M', '3'] ,wrong words= 1
# number  350
# prdict= ['K', 'R', 'N', 'F']
# answer= ['K', 'R', 'M', 'F'] ,wrong words= 1
# number  351
# prdict= ['K', 'T', '9', 'N']
# answer= ['K', 'T', 'Q', 'N'] ,wrong words= 1
# number  419
# prdict= ['M', 'H', 'K', 'F']
# answer= ['M', '4', 'K', 'F'] ,wrong words= 1
# number  454
# prdict= ['9', 'H', 'R', 'K']
# answer= ['9', 'H', 'R', 'Q'] ,wrong words= 1
# number  502
# prdict= ['T', 'P', 'T', '3']
# answer= ['7', 'P', 'T', '3'] ,wrong words= 1
# number  580
# prdict= ['H', '7', 'K', 'H']
# answer= ['H', 'T', 'K', 'H'] ,wrong words= 1
# number  641
# prdict= ['2', 'M', '4', 'K']
# answer= ['Z', 'M', '4', 'K'] ,wrong words= 1
# number  644
# prdict= ['P', 'H', 'M', 'H']
# answer= ['P', 'F', 'M', 'H'] ,wrong words= 1
# number  687
# prdict= ['Y', 'H', 'K', 'T']
# answer= ['Y', 'M', 'K', 'T'] ,wrong words= 1
# number  695
# prdict= ['5', 'Q', 'Y', '2']
# answer= ['5', 'Q', 'Y', 'Z'] ,wrong words= 1
# number  762
# prdict= ['Z', 'H', '2', '3']
# answer= ['Z', 'M', '2', '3'] ,wrong words= 1
# number  819
# prdict= ['7', '2', 'Z', 'K']
# answer= ['7', '2', '2', 'K'] ,wrong words= 1
# number  834
# prdict= ['H', 'F', 'H', 'M']
# answer= ['H', 'F', 'F', 'M'] ,wrong words= 1
# number  859
# prdict= ['A', 'P', '4', 'P']
# answer= ['A', 'F', '4', 'P'] ,wrong words= 1
# number  867
# prdict= ['7', 'R', '7', 'Y']
# answer= ['7', 'R', 'T', 'Y'] ,wrong words= 1
# number  927
# prdict= ['C', '3', 'N', '3']
# answer= ['C', '3', 'N', 'C'] ,wrong words= 1
# number  983
# prdict= ['K', '5', 'A', 'P']
# answer= ['K', '3', 'A', 'P'] ,wrong words= 1
# number  1097
# prdict= ['N', 'P', 'K', 'Y']
# answer= ['N', 'P', 'K', 'R'] ,wrong words= 1
# number  1112
# prdict= ['5', 'A', 'C', 'R']
# answer= ['3', 'A', 'C', 'R'] ,wrong words= 1
# number  1115
# prdict= ['9', 'H', 'M', 'A']
# answer= ['9', 'F', 'M', 'A'] ,wrong words= 1
# number  1122
# prdict= ['N', '3', '7', '2']
# answer= ['N', '3', 'T', '2'] ,wrong words= 1
# number  1145
# prdict= ['4', '3', '7', 'F']
# answer= ['4', '5', '7', 'F'] ,wrong words= 1
# number  1174
# prdict= ['H', 'A', 'Z', 'Y']
# answer= ['M', 'A', 'Z', 'Y'] ,wrong words= 1
# number  1202
# prdict= ['2', 'H', '9', 'M']
# answer= ['2', 'H', 'T', 'M'] ,wrong words= 1
# number  1243
# prdict= ['T', 'A', 'R', '5']
# answer= ['7', 'A', 'R', '5'] ,wrong words= 1
# number  1254
# prdict= ['P', '7', 'Z', 'A']
# answer= ['P', '7', '2', 'A'] ,wrong words= 1
# number  1292
# prdict= ['5', 'Z', '7', '3']
# answer= ['3', 'Z', '7', '3'] ,wrong words= 1
# number  1306
# prdict= ['2', 'Y', '9', 'H']
# answer= ['Z', 'Y', '9', 'H'] ,wrong words= 1
# number  1313
# prdict= ['K', '2', 'Z', 'P']
# answer= ['K', 'Z', 'Z', 'P'] ,wrong words= 1
# number  1324
# prdict= ['2', 'M', 'K', 'K']
# answer= ['Z', 'M', 'K', 'K'] ,wrong words= 1
# number  1327
# prdict= ['7', '2', '7', '5']
# answer= ['7', '2', 'T', '5'] ,wrong words= 1
# number  1335
# prdict= ['K', 'A', 'Z', 'A']
# answer= ['9', '7', '7', '3'] ,wrong words= 4
# number  1336
# prdict= ['7', 'F', 'H', 'M']
# answer= ['R', 'F', 'K', '3'] ,wrong words= 3
# number  1337
# prdict= ['N', '7', '7', 'M']
# answer= ['Z', 'M', '4', 'N'] ,wrong words= 4
# number  1338
# prdict= ['K', 'Y', '4', 'T']
# answer= ['A', 'F', '4', 'H'] ,wrong words= 3
# number  1348
# prdict= ['7', '3', '2', 'F']
# answer= ['7', '4', '3', 'F'] ,wrong words= 2
# number  1352
# prdict= ['2', 'R', 'M', '9']
# answer= ['Z', 'R', 'M', '9'] ,wrong words= 1
# number  1354
# prdict= ['N', '2', 'H', 'A']
# answer= ['N', 'Z', 'H', 'A'] ,wrong words= 1
# number  1358
# prdict= ['R', '2', 'P', '5']
# answer= ['R', 'Z', 'P', '5'] ,wrong words= 1
# number  1448
# prdict= ['2', 'H', 'K', 'F']
# answer= ['Z', 'H', 'K', 'F'] ,wrong words= 1
# number  1452
# prdict= ['2', 'F', '9', '9']
# answer= ['2', 'F', 'T', '9'] ,wrong words= 1
# number  1468
# prdict= ['H', '4', '4', 'Y']
# answer= ['H', 'Z', '4', 'Y'] ,wrong words= 1
# number  1478
# prdict= ['H', 'P', 'K', 'T']
# answer= ['H', 'P', 'K', 'F'] ,wrong words= 1
# number  1481
# prdict= ['F', 'K', 'N', 'M']
# answer= ['F', 'Q', 'N', 'M'] ,wrong words= 1
# number  1488
# prdict= ['2', 'C', 'P', 'K']
# answer= ['Z', 'C', 'P', 'K'] ,wrong words= 1
# number  1526
# prdict= ['4', 'Z', '2', 'A']
# answer= ['4', 'Z', 'A', '2'] ,wrong words= 2
# number  1527
# prdict= ['C', 'P', '9', 'F']
# answer= ['C', 'F', '9', 'F'] ,wrong words= 1
# number  1538
# prdict= ['M', '7', '7', 'Y']
# answer= ['M', '7', 'T', 'Y'] ,wrong words= 1
# number  1568
# prdict= ['F', 'P', '4', '5']
# answer= ['P', 'P', '4', '5'] ,wrong words= 1
# number  1573
# prdict= ['K', '2', 'A', '5']
# answer= ['K', 'Z', 'A', '5'] ,wrong words= 1
# number  1594
# prdict= ['P', '7', 'Q', '4']
# answer= ['P', 'T', 'Q', '4'] ,wrong words= 1
# number  1600
# prdict= ['F', 'T', 'M', '4']
# answer= ['P', 'T', 'M', '4'] ,wrong words= 1
# number  1603
# prdict= ['T', 'K', '9', '7']
# answer= ['F', 'K', '9', '7'] ,wrong words= 1
# number  1617
# prdict= ['9', 'Y', '7', 'C']
# answer= ['9', 'Y', 'T', 'C'] ,wrong words= 1
# number  1641
# prdict= ['M', '9', '9', 'Q']
# answer= ['M', '9', 'F', 'Q'] ,wrong words= 1
# number  1669
# prdict= ['5', 'H', 'Y', '4']
# answer= ['3', 'H', 'Y', '4'] ,wrong words= 1
# number  1732
# prdict= ['A', 'Z', 'C', 'K']
# answer= ['A', 'C', 'Z', 'K'] ,wrong words= 2
# number  1773
# prdict= ['F', '5', '9', 'P']
# answer= ['F', '3', '9', 'P'] ,wrong words= 1
# number  1802
# prdict= ['F', 'A', 'Z', 'Y']
# answer= ['F', '7', 'Z', 'Y'] ,wrong words= 1
# number  1827
# prdict= ['4', 'K', 'A', '7']
# answer= ['4', 'K', 'A', 'T'] ,wrong words= 1
# number  1876
# prdict= ['F', 'Y', '9', 'N']
# answer= ['P', 'Y', '3', 'N'] ,wrong words= 2
# number  1881
# prdict= ['H', 'Q', 'F', 'Q']
# answer= ['H', 'Q', 'F', 'H'] ,wrong words= 1
# number  1893
# prdict= ['H', 'Q', '7', 'Y']
# answer= ['H', 'Q', '7', 'C'] ,wrong words= 1
# number  1915
# prdict= ['C', 'C', '7', '7']
# answer= ['C', 'C', '7', 'T'] ,wrong words= 1
# number  1919
# prdict= ['9', '2', '4', '7']
# answer= ['9', '2', '4', 'Z'] ,wrong words= 1
# number  1943
# prdict= ['H', '4', '9', 'M']
# answer= ['H', '4', 'M', 'M'] ,wrong words= 1
# number  2013
# prdict= ['3', 'P', '9', '4']
# answer= ['3', 'P', '3', '4'] ,wrong words= 1
# number  2046
# prdict= ['T', 'F', 'T', '3']
# answer= ['T', 'P', 'T', '3'] ,wrong words= 1
# number  2093
# prdict= ['5', 'K', '2', '5']
# answer= ['5', 'K', 'Z', '5'] ,wrong words= 1
# number  2098
# prdict= ['P', 'K', 'M', '4']
# answer= ['P', 'R', 'M', '4'] ,wrong words= 1
# number  2101
# prdict= ['M', 'H', 'N', 'Y']
# answer= ['M', 'H', 'Y', 'Y'] ,wrong words= 1
# number  2146
# prdict= ['A', 'T', 'K', 'T']
# answer= ['A', 'Y', 'K', 'Y'] ,wrong words= 2
# number  2148
# prdict= ['N', '7', '5', 'T']
# answer= ['N', '7', '5', 'Y'] ,wrong words= 1
# number  2185
# prdict= ['T', '5', 'M', '7']
# answer= ['T', '3', 'M', '7'] ,wrong words= 1
# number  2187
# prdict= ['N', '9', 'H', '4']
# answer= ['N', '3', 'H', '4'] ,wrong words= 1
# number  2196
# prdict= ['Z', '3', 'C', '9']
# answer= ['Z', 'C', 'C', '9'] ,wrong words= 1
# number  2223
# prdict= ['M', 'N', 'Z', '2']
# answer= ['M', 'N', 'Z', '4'] ,wrong words= 1
# number  2247
# prdict= ['H', 'T', '2', 'H']
# answer= ['H', 'T', '3', 'H'] ,wrong words= 1
# number  2309
# prdict= ['5', 'Z', 'H', '4']
# answer= ['5', 'N', 'H', '4'] ,wrong words= 1
# number  2341
# prdict= ['C', '2', 'R', 'M']
# answer= ['C', '2', 'R', 'N'] ,wrong words= 1
# number  2356
# prdict= ['N', '2', '9', 'N']
# answer= ['N', '2', 'N', '9'] ,wrong words= 2
# number  2369
# prdict= ['Y', 'T', 'H', 'M']
# answer= ['Y', 'T', 'F', 'M'] ,wrong words= 1
# number  2405
# prdict= ['F', '3', '9', '7']
# answer= ['F', '5', '9', '7'] ,wrong words= 1
# number  2409
# prdict= ['K', '7', 'C', '2']
# answer= ['M', '7', 'C', '2'] ,wrong words= 1
# number  2439
# prdict= ['3', 'A', '9', 'H']
# answer= ['3', 'A', '4', '9'] ,wrong words= 2
# number  2457
# prdict= ['K', '5', '9', 'A']
# answer= ['R', '5', '9', 'A'] ,wrong words= 1
# number  2458
# prdict= ['A', 'M', '3', '4']
# answer= ['A', '3', '3', '4'] ,wrong words= 1
# number  2540
# prdict= ['C', '3', 'A', '4']
# answer= ['C', '3', '4', 'A'] ,wrong words= 2
# number  2546
# prdict= ['9', 'P', '7', '9']
# answer= ['9', 'P', 'T', '9'] ,wrong words= 1
# number  2568
# prdict= ['T', 'C', 'H', 'R']
# answer= ['F', 'C', 'H', 'R'] ,wrong words= 1
# number  2581
# prdict= ['Q', 'Z', 'F', '7']
# answer= ['Q', 'Z', 'F', 'C'] ,wrong words= 1
# number  2609
# prdict= ['Y', 'F', '3', 'F']
# answer= ['Y', 'F', '3', 'Y'] ,wrong words= 1
# number  2647
# prdict= ['7', 'Y', 'T', 'N']
# answer= ['7', 'Y', 'T', 'M'] ,wrong words= 1
# number  2654
# prdict= ['F', '2', 'F', 'A']
# answer= ['P', '2', 'F', 'A'] ,wrong words= 1
# number  2658
# prdict= ['C', 'Y', '9', 'C']
# answer= ['C', 'Y', 'C', '9'] ,wrong words= 2
# number  2682
# prdict= ['F', 'A', '9', 'M']
# answer= ['F', 'A', 'Y', 'M'] ,wrong words= 1
# number  2715
# prdict= ['Z', '7', '7', 'P']
# answer= ['Z', '7', 'F', 'P'] ,wrong words= 1
# number  2731
# prdict= ['T', 'F', 'P', 'T']
# answer= ['T', 'F', 'P', 'F'] ,wrong words= 1
# number  2747
# prdict= ['F', 'K', 'Y', 'T']
# answer= ['P', 'K', 'Y', 'T'] ,wrong words= 1
# number  2793
# prdict= ['4', 'T', 'M', 'H']
# answer= ['4', 'T', 'M', 'N'] ,wrong words= 1
# number  2819
# prdict= ['R', '7', '2', '4']
# answer= ['R', 'T', '2', '4'] ,wrong words= 1
# number  2832
# prdict= ['4', '5', 'F', 'T']
# answer= ['4', '5', 'Z', 'T'] ,wrong words= 1
# number  2839
# prdict= ['N', 'P', 'T', 'T']
# answer= ['N', 'P', 'T', 'F'] ,wrong words= 1
# number  2840
# prdict= ['A', 'N', '7', '2']
# answer= ['A', 'N', 'F', '2'] ,wrong words= 1
# number  2846
# prdict= ['M', 'M', '7', 'C']
# answer= ['M', 'M', 'F', 'C'] ,wrong words= 1
# number  2853
# prdict= ['Y', '7', '3', 'Z']
# answer= ['Y', 'A', '3', 'Z'] ,wrong words= 1
# number  2950
# prdict= ['Z', '9', 'T', 'C']
# answer= ['Z', '9', 'T', 'Z'] ,wrong words= 1
# number  2976
# prdict= ['T', '7', 'P', 'M']
# answer= ['T', 'T', 'P', 'M'] ,wrong words= 1
# 3000 picture total wrong=137
# one word accuracy= 0.9885833333333334
# four word accuracy= 0.9606666666666667
# 0.0
# 26.275159120559692
# 0.0009768009185791016

# %%
#一個model預測test
model=load_model("models/RMSprop-11-0.9952.h5")
with h5.File('test.h5','r') as file:
        x_test=file.get("x").value/255
data=scipy.io.loadmat("test.mat")
y_onehot=data['y_onehot']
filenum=x_test.shape[0]
def OneModelTestOwn(model):
    global filenum
    time_start1=time.time()
    l=[]
    time_end1=time.time()
    time_start2=time.time()
    for i in range(filenum):
        imacc,facc=OneModelPredict(model,i)
        l.append((imacc,facc))
    time_end2=time.time()
    time_start3=time.time()
    sigma=np.asarray(np.sum(np.asarray(l),axis=0))
    imgaccuracy=sigma[0]/filenum
    fourwordccuracy=sigma[1]/(4*filenum)
    print('%d picture total wrong=%d'%(filenum,4*filenum-sigma[1]))
    print('one word accuracy=',fourwordccuracy)
    print('four word accuracy=',imgaccuracy)  
    time_end3=time.time()
    print(time_end1-time_start1)
    print(time_end2-time_start2)
    print(time_end3-time_start3)

def OneModelPredict(model,count):
    global y_onehot,x_test
    y=y_onehot.reshape((int(y_onehot.shape[0]/4),4,19))
    img = x_test[count]
    img = np.expand_dims(img,axis=0) 
    x1 = np.argmax(model.predict(img),axis=2) 
    datasheet={"0":"2","1":"3","2":"4","3":'5',"4":'7',"5":'9',"6":'A',"7":'C',"8":'F',"9":'H',"10":'K',"11":'M',"12":'N',"13":'P',"14":'Q',"15":'R',"16":'T',"17":'Y',"18":'Z'}
    pdt=[datasheet[str(i[0])]for i in x1] #預測為['A','B','C','D']
    ans=[datasheet[str(np.argmax(y[count][i]))] for i in range(4)]#答案為['A','B','C','D']
    fouracc=0
    imgacc=0

    #確認有幾個字對
    for ind,letter in enumerate(pdt):
        if letter==ans[ind]:
            fouracc+=1
    if pdt==ans:
        imgacc=1
    if count <=40:
        print("number ",count)
        if count <=5:
            plt.imshow(x_test[count])
            plt.show()
        print("prdict=",pdt)
        print("answer=",ans,",wrong words=",4-fouracc)
    if fouracc!=4:
        print("number ",count)
        plt.imshow(x_test[count])
        plt.show()
        print("prdict=",pdt)
        print("answer=",ans,",wrong words=",4-fouracc)
    return imgacc,fouracc
OneModelTestOwn(model)
# Out:
# C:\Users\苯異丙胺\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:4: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   after removing the cwd from sys.path.
# number  0
# prdict= ['7', 'F', '9', '4']
# answer= ['7', 'F', '9', '4'] ,wrong words= 0
# number  1
# prdict= ['4', '2', 'T', '7']
# answer= ['4', '2', 'T', '7'] ,wrong words= 0
# number  2
# prdict= ['C', 'Y', 'T', 'F']
# answer= ['C', 'Y', 'T', 'F'] ,wrong words= 0
# number  3
# prdict= ['T', 'M', 'F', 'T']
# answer= ['T', 'M', 'F', 'T'] ,wrong words= 0
# number  4
# prdict= ['P', '7', 'K', 'R']
# answer= ['P', '7', 'K', 'R'] ,wrong words= 0
# number  5
# prdict= ['N', '2', 'Z', 'K']
# answer= ['N', '2', 'Z', 'K'] ,wrong words= 0
# number  6
# prdict= ['7', '4', 'F', 'Y']
# answer= ['7', '4', 'F', 'Y'] ,wrong words= 0
# number  7
# prdict= ['Z', 'Z', '5', 'C']
# answer= ['Z', 'Z', '5', 'C'] ,wrong words= 0
# number  8
# prdict= ['7', 'Z', '4', '4']
# answer= ['7', 'Z', '4', '4'] ,wrong words= 0
# number  9
# prdict= ['R', '4', 'Z', 'C']
# answer= ['R', '4', 'Z', 'C'] ,wrong words= 0
# number  10
# prdict= ['Y', '2', '5', 'T']
# answer= ['Y', '2', '5', 'T'] ,wrong words= 0
# number  11
# prdict= ['F', 'M', '2', '2']
# answer= ['F', 'M', '2', '2'] ,wrong words= 0
# number  12
# prdict= ['Y', '4', 'M', '4']
# answer= ['Y', '4', 'M', '4'] ,wrong words= 0
# number  13
# prdict= ['M', '2', 'Q', '2']
# answer= ['M', '2', 'Q', '2'] ,wrong words= 0
# number  14
# prdict= ['F', 'F', '7', 'N']
# answer= ['F', 'F', '7', 'N'] ,wrong words= 0
# number  15
# prdict= ['9', '5', 'R', 'M']
# answer= ['9', '5', 'R', 'M'] ,wrong words= 0
# number  16
# prdict= ['T', '4', 'T', '5']
# answer= ['T', '4', 'T', '5'] ,wrong words= 0
# number  17
# prdict= ['F', '3', '4', 'A']
# answer= ['F', '3', '4', '3'] ,wrong words= 1
# number  17
# prdict= ['F', '3', '4', 'A']
# answer= ['F', '3', '4', '3'] ,wrong words= 1
# number  18
# prdict= ['F', 'A', '4', 'A']
# answer= ['F', 'A', '4', 'A'] ,wrong words= 0
# number  19
# prdict= ['3', '2', 'H', '4']
# answer= ['3', '2', 'H', '4'] ,wrong words= 0
# number  20
# prdict= ['Q', 'H', 'M', 'A']
# answer= ['Q', 'H', 'M', 'A'] ,wrong words= 0
# number  21
# prdict= ['P', 'Y', 'C', 'P']
# answer= ['P', 'Y', 'C', 'P'] ,wrong words= 0
# number  22
# prdict= ['A', 'P', 'N', 'M']
# answer= ['A', 'P', 'N', 'M'] ,wrong words= 0
# number  23
# prdict= ['R', 'M', 'Q', 'N']
# answer= ['R', 'M', 'Q', 'N'] ,wrong words= 0
# number  24
# prdict= ['K', 'Z', '7', '4']
# answer= ['K', 'Z', '7', '4'] ,wrong words= 0
# number  25
# prdict= ['N', 'F', 'Z', 'H']
# answer= ['N', 'F', 'Z', 'H'] ,wrong words= 0
# number  26
# prdict= ['Y', '2', '7', 'R']
# answer= ['Y', '2', '7', 'R'] ,wrong words= 0
# number  27
# prdict= ['A', 'Y', 'R', 'K']
# answer= ['A', 'Y', 'R', '4'] ,wrong words= 1
# number  27
# prdict= ['A', 'Y', 'R', 'K']
# answer= ['A', 'Y', 'R', '4'] ,wrong words= 1
# number  28
# prdict= ['M', '9', '4', 'Y']
# answer= ['M', '9', '4', 'Y'] ,wrong words= 0
# number  29
# prdict= ['3', '5', 'Q', '7']
# answer= ['3', '5', 'Q', '7'] ,wrong words= 0
# number  30
# prdict= ['A', 'Y', 'H', 'A']
# answer= ['A', 'Y', 'H', 'A'] ,wrong words= 0
# number  31
# prdict= ['T', 'R', '4', '5']
# answer= ['T', 'R', '4', '5'] ,wrong words= 0
# number  32
# prdict= ['Q', 'T', 'R', '4']
# answer= ['Q', 'T', 'R', '4'] ,wrong words= 0
# number  33
# prdict= ['2', '7', '3', 'A']
# answer= ['2', '7', '3', 'A'] ,wrong words= 0
# number  34
# prdict= ['Q', 'M', 'Y', 'F']
# answer= ['Q', 'M', 'Y', 'F'] ,wrong words= 0
# number  35
# prdict= ['2', 'Y', 'N', 'K']
# answer= ['2', 'Y', 'N', 'K'] ,wrong words= 0
# number  36
# prdict= ['R', 'H', 'T', 'P']
# answer= ['R', 'H', 'T', 'P'] ,wrong words= 0
# number  37
# prdict= ['7', 'K', 'Q', 'M']
# answer= ['7', 'K', 'Q', '5'] ,wrong words= 1
# number  37
# prdict= ['7', 'K', 'Q', 'M']
# answer= ['7', 'K', 'Q', '5'] ,wrong words= 1
# number  38
# prdict= ['7', 'H', 'Y', 'P']
# answer= ['7', 'H', 'Y', 'P'] ,wrong words= 0
# number  39
# prdict= ['5', 'M', '3', 'K']
# answer= ['5', 'M', '3', 'K'] ,wrong words= 0
# number  40
# prdict= ['H', 'C', 'Y', 'C']
# answer= ['H', 'C', 'Y', 'C'] ,wrong words= 0
# number  90
# prdict= ['5', 'Q', 'P', 'N']
# answer= ['3', 'Q', 'P', 'N'] ,wrong words= 1
# number  165
# prdict= ['5', 'C', 'N', 'H']
# answer= ['3', 'C', 'N', 'H'] ,wrong words= 1
# number  168
# prdict= ['K', '9', 'K', 'P']
# answer= ['K', '9', 'K', '9'] ,wrong words= 1
# number  271
# prdict= ['R', '5', 'Z', 'M']
# answer= ['R', '5', '2', 'M'] ,wrong words= 1
# number  454
# prdict= ['9', 'H', 'R', 'K']
# answer= ['9', 'H', 'R', 'Q'] ,wrong words= 1
# number  502
# prdict= ['T', 'P', 'T', '3']
# answer= ['7', 'P', 'T', '3'] ,wrong words= 1
# number  641
# prdict= ['2', 'M', '4', 'K']
# answer= ['Z', 'M', '4', 'K'] ,wrong words= 1
# number  687
# prdict= ['Y', 'H', 'K', 'T']
# answer= ['Y', 'M', 'K', 'T'] ,wrong words= 1
# number  695
# prdict= ['5', 'Q', 'Y', '2']
# answer= ['5', 'Q', 'Y', 'Z'] ,wrong words= 1
# number  762
# prdict= ['Z', 'H', '2', '3']
# answer= ['Z', 'M', '2', '3'] ,wrong words= 1
# number  765
# prdict= ['P', 'P', 'P', 'K']
# answer= ['P', '7', 'P', 'K'] ,wrong words= 1
# number  782
# prdict= ['P', 'F', 'C', 'Z']
# answer= ['F', 'F', 'C', 'Z'] ,wrong words= 1
# number  832
# prdict= ['P', 'M', 'Z', 'F']
# answer= ['F', 'M', 'Z', 'F'] ,wrong words= 1
# number  859
# prdict= ['A', 'P', '4', 'P']
# answer= ['A', 'F', '4', 'P'] ,wrong words= 1
# number  861
# prdict= ['P', 'T', 'R', 'C']
# answer= ['F', 'T', 'R', 'C'] ,wrong words= 1
# number  927
# prdict= ['C', '3', 'N', '3']
# answer= ['C', '3', 'N', 'C'] ,wrong words= 1
# number  1112
# prdict= ['5', 'A', 'C', 'R']
# answer= ['3', 'A', 'C', 'R'] ,wrong words= 1
# number  1174
# prdict= ['H', 'A', 'Z', 'Y']
# answer= ['M', 'A', 'Z', 'Y'] ,wrong words= 1
# number  1243
# prdict= ['T', 'A', 'R', '5']
# answer= ['7', 'A', 'R', '5'] ,wrong words= 1
# number  1292
# prdict= ['5', 'Z', '7', '3']
# answer= ['3', 'Z', '7', '3'] ,wrong words= 1
# number  1304
# prdict= ['R', 'R', 'K', 'T']
# answer= ['F', 'R', 'K', 'T'] ,wrong words= 1
# number  1306
# prdict= ['2', 'Y', '9', 'H']
# answer= ['Z', 'Y', '9', 'H'] ,wrong words= 1
# number  1313
# prdict= ['K', '2', 'Z', 'P']
# answer= ['K', 'Z', 'Z', 'P'] ,wrong words= 1
# number  1324
# prdict= ['2', 'M', 'K', 'K']
# answer= ['Z', 'M', 'K', 'K'] ,wrong words= 1
# number  1335
# prdict= ['K', 'A', 'Z', 'A']
# answer= ['9', '7', '7', '3'] ,wrong words= 4
# number  1336
# prdict= ['7', 'F', 'H', 'M']
# answer= ['R', 'F', 'K', '3'] ,wrong words= 3
# number  1337
# prdict= ['N', '7', '7', 'M']
# answer= ['Z', 'M', '4', 'N'] ,wrong words= 4
# number  1338
# prdict= ['K', 'Y', '4', 'T']
# answer= ['A', 'F', '4', 'H'] ,wrong words= 3
# number  1348
# prdict= ['7', '3', '2', 'F']
# answer= ['7', '4', '3', 'F'] ,wrong words= 2
# number  1352
# prdict= ['2', 'R', 'M', '9']
# answer= ['Z', 'R', 'M', '9'] ,wrong words= 1
# number  1354
# prdict= ['N', '2', 'H', 'A']
# answer= ['N', 'Z', 'H', 'A'] ,wrong words= 1
# number  1358
# prdict= ['R', '2', 'P', '5']
# answer= ['R', 'Z', 'P', '5'] ,wrong words= 1
# number  1448
# prdict= ['2', 'H', 'K', 'F']
# answer= ['Z', 'H', 'K', 'F'] ,wrong words= 1
# number  1481
# prdict= ['F', 'K', 'N', 'M']
# answer= ['F', 'Q', 'N', 'M'] ,wrong words= 1
# number  1488
# prdict= ['2', 'C', 'P', 'K']
# answer= ['Z', 'C', 'P', 'K'] ,wrong words= 1
# number  1526
# prdict= ['4', 'Z', '2', 'A']
# answer= ['4', 'Z', 'A', '2'] ,wrong words= 2
# number  1568
# prdict= ['F', 'P', '4', '5']
# answer= ['P', 'P', '4', '5'] ,wrong words= 1
# number  1617
# prdict= ['9', 'Y', '7', 'C']
# answer= ['9', 'Y', 'T', 'C'] ,wrong words= 1
# number  1669
# prdict= ['5', 'H', 'Y', '4']
# answer= ['3', 'H', 'Y', '4'] ,wrong words= 1
# number  1679
# prdict= ['P', '5', 'C', 'C']
# answer= ['F', '5', 'C', 'C'] ,wrong words= 1
# number  1732
# prdict= ['A', 'Z', 'C', 'K']
# answer= ['A', 'C', 'Z', 'K'] ,wrong words= 2
# number  1773
# prdict= ['F', '5', '9', 'P']
# answer= ['F', '3', '9', 'P'] ,wrong words= 1
# number  1802
# prdict= ['F', 'A', 'Z', 'Y']
# answer= ['F', '7', 'Z', 'Y'] ,wrong words= 1
# number  1827
# prdict= ['4', 'K', 'A', '7']
# answer= ['4', 'K', 'A', 'T'] ,wrong words= 1
# number  1876
# prdict= ['P', 'Y', 'P', 'N']
# answer= ['P', 'Y', '3', 'N'] ,wrong words= 1
# number  1881
# prdict= ['H', 'Q', 'F', 'Q']
# answer= ['H', 'Q', 'F', 'H'] ,wrong words= 1
# number  1893
# prdict= ['H', 'Q', '7', 'Y']
# answer= ['H', 'Q', '7', 'C'] ,wrong words= 1
# number  1915
# prdict= ['C', 'C', '7', '7']
# answer= ['C', 'C', '7', 'T'] ,wrong words= 1
# number  1919
# prdict= ['9', '2', '4', '7']
# answer= ['9', '2', '4', 'Z'] ,wrong words= 1
# number  2146
# prdict= ['A', 'T', 'K', 'T']
# answer= ['A', 'Y', 'K', 'Y'] ,wrong words= 2
# number  2148
# prdict= ['N', '7', '5', 'T']
# answer= ['N', '7', '5', 'Y'] ,wrong words= 1
# number  2196
# prdict= ['Z', '3', 'C', '9']
# answer= ['Z', 'C', 'C', '9'] ,wrong words= 1
# number  2223
# prdict= ['M', 'N', 'Z', '2']
# answer= ['M', 'N', 'Z', '4'] ,wrong words= 1
# number  2247
# prdict= ['H', 'T', '2', 'H']
# answer= ['H', 'T', '3', 'H'] ,wrong words= 1
# number  2309
# prdict= ['5', 'Z', 'H', '4']
# answer= ['5', 'N', 'H', '4'] ,wrong words= 1
# number  2341
# prdict= ['C', '2', 'R', 'M']
# answer= ['C', '2', 'R', 'N'] ,wrong words= 1
# number  2356
# prdict= ['N', '2', '9', 'N']
# answer= ['N', '2', 'N', '9'] ,wrong words= 2
# number  2369
# prdict= ['Y', 'T', 'H', 'M']
# answer= ['Y', 'T', 'F', 'M'] ,wrong words= 1
# number  2391
# prdict= ['R', 'K', 'Z', 'C']
# answer= ['F', 'K', 'Z', 'C'] ,wrong words= 1
# number  2409
# prdict= ['K', '7', 'C', '2']
# answer= ['M', '7', 'C', '2'] ,wrong words= 1
# number  2439
# prdict= ['3', 'A', '9', 'H']
# answer= ['3', 'A', '4', '9'] ,wrong words= 2
# number  2457
# prdict= ['K', '5', '9', 'A']
# answer= ['R', '5', '9', 'A'] ,wrong words= 1
# number  2458
# prdict= ['A', 'M', '3', '4']
# answer= ['A', '3', '3', '4'] ,wrong words= 1
# number  2539
# prdict= ['M', '4', 'M', 'A']
# answer= ['M', '2', 'M', 'A'] ,wrong words= 1
# number  2540
# prdict= ['C', '3', 'A', '4']
# answer= ['C', '3', '4', 'A'] ,wrong words= 2
# number  2568
# prdict= ['P', 'C', 'H', 'R']
# answer= ['F', 'C', 'H', 'R'] ,wrong words= 1
# number  2581
# prdict= ['Q', 'Z', 'F', '7']
# answer= ['Q', 'Z', 'F', 'C'] ,wrong words= 1
# number  2609
# prdict= ['Y', 'F', '3', 'F']
# answer= ['Y', 'F', '3', 'Y'] ,wrong words= 1
# number  2647
# prdict= ['7', 'Y', 'T', 'N']
# answer= ['7', 'Y', 'T', 'M'] ,wrong words= 1
# number  2658
# prdict= ['C', 'Y', '9', 'C']
# answer= ['C', 'Y', 'C', '9'] ,wrong words= 2
# number  2747
# prdict= ['F', 'K', 'Y', 'T']
# answer= ['P', 'K', 'Y', 'T'] ,wrong words= 1
# number  2793
# prdict= ['4', 'T', 'M', 'H']
# answer= ['4', 'T', 'M', 'N'] ,wrong words= 1
# number  2832
# prdict= ['4', '5', 'F', 'T']
# answer= ['4', '5', 'Z', 'T'] ,wrong words= 1
# number  2853
# prdict= ['Y', '7', '3', 'Z']
# answer= ['Y', 'A', '3', 'Z'] ,wrong words= 1
# number  2950
# prdict= ['Z', '9', 'T', 'C']
# answer= ['Z', '9', 'T', 'Z'] ,wrong words= 1
# 3000 picture total wrong=96
# one word accuracy= 0.992
# four word accuracy= 0.974
# 0.0
# 23.30148148536682
# 0.0009768009185791016

# %%
model1=load_model("models/Adamax-10-0.9920.h5")
Test_Wrong_Img(model1)
# Out:
# prdict= ['Q', 'H', 'M', 'A']
# answer= ['Q', 'H', 'M', 'A']
# prdict= ['5', 'Q', 'P', 'N']
# answer= ['3', 'Q', 'P', 'N']
# prdict= ['A', '2', 'H', 'Q']
# answer= ['A', 'Z', 'H', 'Q']
# prdict= ['P', 'F', 'C', 'Z']
# answer= ['F', 'F', 'C', 'Z']
# prdict= ['F', 'R', 'K', 'T']
# answer= ['F', 'R', 'K', 'T']
# prdict= ['P', 'Y', '3', 'N']
# answer= ['P', 'Y', '3', 'N']
# prdict= ['R', '5', '9', 'A']
# answer= ['R', '5', '9', 'A']
# prdict= ['F', 'F', 'H', 'R']
# answer= ['F', 'C', 'H', 'R']
# prdict= ['T', '5', 'M', '7']
# answer= ['T', '3', 'M', '7']
# prdict= ['P', 'K', 'M', '4']
# answer= ['P', 'R', 'M', '4']
# prdict= ['5', 'K', '2', '5']
# answer= ['5', 'K', 'Z', '5']

# %%
model2=load_model("models/Adamax-18-0.9920.h5")
Test_Wrong_Img(model2)
# Out:
# prdict= ['Q', 'H', 'M', 'A']
# answer= ['Q', 'H', 'M', 'A']
# prdict= ['9', 'Q', 'P', 'N']
# answer= ['3', 'Q', 'P', 'N']
# prdict= ['A', 'Z', 'H', 'Q']
# answer= ['A', 'Z', 'H', 'Q']
# prdict= ['F', 'F', 'C', 'Z']
# answer= ['F', 'F', 'C', 'Z']
# prdict= ['F', 'R', 'K', 'T']
# answer= ['F', 'R', 'K', 'T']
# prdict= ['F', 'Y', '9', 'N']
# answer= ['P', 'Y', '3', 'N']
# prdict= ['K', '5', '9', 'A']
# answer= ['R', '5', '9', 'A']
# prdict= ['T', 'C', 'H', 'R']
# answer= ['F', 'C', 'H', 'R']
# prdict= ['T', '5', 'M', '7']
# answer= ['T', '3', 'M', '7']
# prdict= ['P', 'K', 'M', '4']
# answer= ['P', 'R', 'M', '4']
# prdict= ['5', 'K', '2', '5']
# answer= ['5', 'K', 'Z', '5']

# %%
model3=load_model("models/Adamax-30-0.9904.h5")
Test_Wrong_Img(model3)
# Out:
# prdict= ['Q', 'H', 'N', 'A']
# answer= ['Q', 'H', 'M', 'A']
# prdict= ['5', 'Q', 'P', 'N']
# answer= ['3', 'Q', 'P', 'N']
# prdict= ['A', '2', 'H', 'Q']
# answer= ['A', 'Z', 'H', 'Q']
# prdict= ['P', 'F', 'C', 'Z']
# answer= ['F', 'F', 'C', 'Z']
# prdict= ['F', 'R', 'K', 'T']
# answer= ['F', 'R', 'K', 'T']
# prdict= ['F', 'Y', '3', 'N']
# answer= ['P', 'Y', '3', 'N']
# prdict= ['R', '5', '5', 'A']
# answer= ['R', '5', '9', 'A']
# prdict= ['F', 'C', 'H', 'R']
# answer= ['F', 'C', 'H', 'R']
# prdict= ['T', '3', 'M', '7']
# answer= ['T', '3', 'M', '7']
# prdict= ['P', 'R', 'M', '4']
# answer= ['P', 'R', 'M', '4']
# prdict= ['5', 'K', 'Z', '5']
# answer= ['5', 'K', 'Z', '5']

# %%
model=load_model("models/RMSprop-11-0.9952.h5")
def Test_Wrong_Img(model):
    testlist=[20,90,323,782,1304,1876,2457,2568,2185,2098,2093]
    datasheet={"0":"2","1":"3","2":"4","3":'5',"4":'7',"5":'9',"6":'A',"7":'C',"8":'F',"9":'H',"10":'K',"11":'M',"12":'N',"13":'P',"14":'Q',"15":'R',"16":'T',"17":'Y',"18":'Z'}
    y=y_onehot.reshape((int(y_onehot.shape[0]/4),4,19))
    for s in testlist:
        x1=np.argmax(model.predict(x_test[s:s+1]),axis=2)
        pdt=[datasheet[str(i[0])]for i in x1] #預測為['A','B','C','D']
        ans=[datasheet[str(np.argmax(y[s][i]))] for i in range(4)]#答案為['A','B','C','D']
        plt.imshow(x_test[s])
        plt.show()
        print("prdict=",pdt)
        print("answer=",ans)
Test_Wrong_Img(model)
# Out:
# prdict= ['Q', 'H', 'M', 'A']
# answer= ['Q', 'H', 'M', 'A']
# prdict= ['5', 'Q', 'P', 'N']
# answer= ['3', 'Q', 'P', 'N']
# prdict= ['A', 'Z', 'H', 'Q']
# answer= ['A', 'Z', 'H', 'Q']
# prdict= ['P', 'F', 'C', 'Z']
# answer= ['F', 'F', 'C', 'Z']
# prdict= ['R', 'R', 'K', 'T']
# answer= ['F', 'R', 'K', 'T']
# prdict= ['P', 'Y', 'P', 'N']
# answer= ['P', 'Y', '3', 'N']
# prdict= ['K', '5', '9', 'A']
# answer= ['R', '5', '9', 'A']
# prdict= ['P', 'C', 'H', 'R']
# answer= ['F', 'C', 'H', 'R']
# prdict= ['T', '3', 'M', '7']
# answer= ['T', '3', 'M', '7']
# prdict= ['P', 'R', 'M', '4']
# answer= ['P', 'R', 'M', '4']
# prdict= ['5', 'K', 'Z', '5']
# answer= ['5', 'K', 'Z', '5']

# %%
model3=load_model("models/RMSprop-19-0.9936.h5")
Test_Wrong_Img(model3)
# Out:
# prdict= ['Q', 'H', 'N', 'A']
# answer= ['Q', 'H', 'M', 'A']
# prdict= ['5', 'Q', 'P', 'N']
# answer= ['3', 'Q', 'P', 'N']
# prdict= ['A', 'Z', 'H', 'Q']
# answer= ['A', 'Z', 'H', 'Q']
# prdict= ['F', 'F', 'C', 'Z']
# answer= ['F', 'F', 'C', 'Z']
# prdict= ['R', 'R', 'K', 'T']
# answer= ['F', 'R', 'K', 'T']
# prdict= ['P', 'Y', '5', 'N']
# answer= ['P', 'Y', '3', 'N']
# prdict= ['K', '5', '9', 'A']
# answer= ['R', '5', '9', 'A']
# prdict= ['F', 'C', 'H', 'R']
# answer= ['F', 'C', 'H', 'R']
# prdict= ['T', '3', 'M', '7']
# answer= ['T', '3', 'M', '7']
# prdict= ['P', 'K', 'M', '4']
# answer= ['P', 'R', 'M', '4']
# prdict= ['5', 'K', '2', '5']
# answer= ['5', 'K', 'Z', '5']
