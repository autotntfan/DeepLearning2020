# %%
import math
import numpy as np
import h5py
import matplotlib.pyplot as plt
import scipy
from PIL import Image
from scipy import ndimage
import tensorflow as tf
from tensorflow.python.framework import ops
from cnn_utils import *

get_ipython().run_line_magic('matplotlib', 'inline')
np.random.seed(1)

# %%
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig, classes = load_dataset()

# %%
index = 6
plt.imshow(X_train_orig[index])
print ("y = " + str(np.squeeze(Y_train_orig[:, index])))
# Out:
# y = 2

# %%
X_train = X_train_orig/255.
X_test = X_test_orig/255.
Y_train = convert_to_one_hot(Y_train_orig, 6).T
Y_test = convert_to_one_hot(Y_test_orig, 6).T
print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
conv_layers = {}
# Out:
# number of training examples = 1080
# number of test examples = 120
# X_train shape: (1080, 64, 64, 3)
# Y_train shape: (1080, 6)
# X_test shape: (120, 64, 64, 3)
# Y_test shape: (120, 6)

# %%
def create_placeholders(n_H0, n_W0, n_C0, n_y):
    """
    Creates the placeholders for the tensorflow session.
    
    Arguments:
    n_H0 -- scalar, height of an input image
    n_W0 -- scalar, width of an input image
    n_C0 -- scalar, number of channels of the input
    n_y -- scalar, number of classes
        
    Returns:
    X -- placeholder for the data input, of shape [None, n_H0, n_W0, n_C0] and dtype "float"
    Y -- placeholder for the input labels, of shape [None, n_y] and dtype "float"
    """

    ### START CODE HERE ### (≈2 lines)
    X = tf.placeholder(tf.float32,shape=([None,n_H0,n_W0,n_C0]),name='Placeholder') 
    Y = tf.placeholder(tf.float32,shape=([None,n_y]),name='Placeholder')
    ### END CODE HERE ###
    
    return X, Y

# %%
X, Y = create_placeholders(64, 64, 3, 6)
print ("X = " + str(X))
print ("Y = " + str(Y))
# Out:
# X = Tensor("Placeholder:0", shape=(?, 64, 64, 3), dtype=float32)
# Y = Tensor("Placeholder_1:0", shape=(?, 6), dtype=float32)

# %%
def initialize_parameters():
    """
    Initializes weight parameters to build a neural network with tensorflow. The shapes are:
                        W1 : [4, 4, 3, 8]
                        W2 : [2, 2, 8, 16]
    Returns:
    parameters -- a dictionary of tensors containing W1, W2
    """
    
    tf.set_random_seed(1)                              # so that your "random" numbers match ours
        
    ### START CODE HERE ### (approx. 2 lines of code)
    W1 =  tf.get_variable("W1",[4,4,3,8],initializer=tf.contrib.layers.xavier_initializer(seed=0))
    W2 =  tf.get_variable("W2",[2,2,8,16],initializer=tf.contrib.layers.xavier_initializer(seed=0))
    W3 =  tf.get_variable("W3",[2,2,16,8],initializer=tf.contrib.layers.xavier_initializer(seed=0))

    ### END CODE HERE ###

    parameters = {"W1": W1,
                  "W2": W2,
                  "W3": W3
                  }
    
    return parameters

# %%
tf.reset_default_graph()
with tf.Session() as sess_test:
    parameters = initialize_parameters()
    init = tf.global_variables_initializer()
    sess_test.run(init)
    print("W1 = " + str(parameters["W1"].eval()[1,1,1]))
    print("W2 = " + str(parameters["W2"].eval()[1,1,1]))
# Out:
# W1 = [ 0.00131723  0.1417614  -0.04434952  0.09197326  0.14984085 -0.03514394
#  -0.06847463  0.05245192]
# W2 = [-0.08566415  0.17750949  0.11974221  0.16773748 -0.0830943  -0.08058
#  -0.00577033 -0.14643836  0.24162132 -0.05857408 -0.19055021  0.1345228
#  -0.22779644 -0.1601823  -0.16117483 -0.10286498]

# %%
def forward_propagation(X, parameters):
    """
    Implements the forward propagation for the model:
    CONV2D -> RELU -> MAXPOOL -> CONV2D -> RELU -> MAXPOOL -> FLATTEN -> FULLYCONNECTED
    
    Arguments:
    X -- input dataset placeholder, of shape (input size, number of examples)
    parameters -- python dictionary containing your parameters "W1", "W2"
                  the shapes are given in initialize_parameters

    Returns:
    Z3 -- the output of the last LINEAR unit
    """

    # Retrieve the parameters from the dictionary "parameters" 
    W1 = parameters['W1']
    W2 = parameters['W2']
    W3 = parameters['W3']
    ### START CODE HERE ###
    # CONV2D: stride of 1, padding 'SAME'
    Z1 =  tf.nn.conv2d(X,filter=W1,strides=(1,1,1,1),padding="SAME")
    # RELU
    A1 =  tf.nn.relu(Z1)
    # MAXPOOL: window 8x8, sride 8, padding 'SAME'
    P1 =  tf.nn.max_pool(A1,ksize=(1,8,8,1),strides=(1,8,8,1),padding='SAME')
    # CONV2D: filters W2, stride 1, padding 'SAME'
    Z2 =  tf.nn.conv2d(P1,filter=W2,strides=(1,1,1,1),padding="SAME")
    # RELU
    A2 =  tf.nn.relu(Z2)
    # MAXPOOL: window 4x4, stride 4, padding 'SAME'
    P2 =  tf.nn.max_pool(A2,ksize=(1,4,4,1),strides=(1,4,4,1),padding="SAME")
    Z3 =  tf.nn.conv2d(P2,filter=W3,strides=(1,1,1,1),padding="SAME")
    A3 =  tf.nn.relu(Z3)
    P3 =  tf.nn.max_pool(A3,ksize=(1,2,2,1),strides=(1,2,2,1),padding="SAME")
    # FLATTEN
    F =  tf.contrib.layers.flatten(P3)
    # FULLY-CONNECTED without non-linear activation function (not not call softmax).
    # 6 neurons in output layer. Hint: one of the arguments should be "activation_fn=None" 
    Z3 =  tf.contrib.layers.fully_connected(F,activation_fn=None,num_outputs=6)
    ### END CODE HERE ###

    return Z3

# %%
tf.reset_default_graph()

with tf.Session() as sess:
    np.random.seed(1)
    X, Y = create_placeholders(64, 64, 3, 6)
    parameters = initialize_parameters()
    Z3 = forward_propagation(X, parameters)
    init = tf.global_variables_initializer()
    sess.run(init)
    a = sess.run(Z3, {X: np.random.randn(2,64,64,3), Y: np.random.randn(2,6)})
    print("Z3 = " + str(a))
# Out:
# Z3 = [[ 0.9376771  -0.6095312  -2.0269983   0.17770252  1.7117052  -1.2806728 ]
#  [ 0.98200715 -0.6099043  -2.0166683   0.03753586  1.8335181  -1.2892926 ]]

# %%
def compute_cost(Z3, Y):
    """
    Computes the cost
    
    Arguments:
    Z3 -- output of forward propagation (output of the last LINEAR unit), of shape (6, number of examples)
    Y -- "true" labels vector placeholder, same shape as Z3
    
    Returns:
    cost - Tensor of the cost function
    """
    
    ### START CODE HERE ### (1 line of code)
    cost =  tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=Z3,labels=Y))
    ### END CODE HERE ###
    
    return cost

# %%
tf.reset_default_graph()

with tf.Session() as sess:
    np.random.seed(1)
    X, Y = create_placeholders(64, 64, 3, 6)
    parameters = initialize_parameters()
    Z3 = forward_propagation(X, parameters)
    cost = compute_cost(Z3, Y)
    init = tf.global_variables_initializer()
    sess.run(init)
    a = sess.run(cost, {X: np.random.randn(4,64,64,3), Y: np.random.randn(4,6)})
    print("cost = " + str(a))
# Out:
# cost = 1.0583959

# %%
def model(X_train, Y_train, X_test, Y_test, learning_rate = 0.009,
          num_epochs = 400, minibatch_size = 64, print_cost = True):
    """
    Implements a three-layer ConvNet in Tensorflow:
    CONV2D -> RELU -> MAXPOOL -> CONV2D -> RELU -> MAXPOOL -> FLATTEN -> FULLYCONNECTED
    
    Arguments:
    X_train -- training set, of shape (None, 64, 64, 3)
    Y_train -- test set, of shape (None, n_y = 6)
    X_test -- training set, of shape (None, 64, 64, 3)
    Y_test -- test set, of shape (None, n_y = 6)
    learning_rate -- learning rate of the optimization
    num_epochs -- number of epochs of the optimization loop
    minibatch_size -- size of a minibatch
    print_cost -- True to print the cost every 100 epochs
    
    Returns:
    train_accuracy -- real number, accuracy on the train set (X_train)
    test_accuracy -- real number, testing accuracy on the test set (X_test)
    parameters -- parameters learnt by the model. They can then be used to predict.
    """
    
    ops.reset_default_graph()                         # to be able to rerun the model without overwriting tf variables
    tf.set_random_seed(1)                             # to keep results consistent (tensorflow seed)
    seed = 3                                          # to keep results consistent (numpy seed)
    (m, n_H0, n_W0, n_C0) = X_train.shape             
    n_y = Y_train.shape[1]                            
    costs = []                                        # To keep track of the cost
    
    # Create Placeholders of the correct shape
    ### START CODE HERE ### (1 line)
    X, Y =  create_placeholders(n_H0, n_W0, n_C0, n_y)
    ### END CODE HERE ###

    # Initialize parameters
    ### START CODE HERE ### (1 line)
    parameters =  initialize_parameters()
    ### END CODE HERE ###
    
    # Forward propagation: Build the forward propagation in the tensorflow graph
    ### START CODE HERE ### (1 line)
    Z3 =  forward_propagation(X,parameters)
    ### END CODE HERE ###
    
    # Cost function: Add cost function to tensorflow graph
    ### START CODE HERE ### (1 line)
    cost =  compute_cost(Z3, Y)
    ### END CODE HERE ###

    # Backpropagation: Define the tensorflow optimizer. Use an AdamOptimizer that minimizes the cost.
    ### START CODE HERE ### (1 line)
    optimizer =  tf.train.RMSPropOptimizer(learning_rate=learning_rate).minimize(cost)
    ### END CODE HERE ###
    
    # Initialize all the variables globally
    init = tf.global_variables_initializer()
     
    # Start the session to compute the tensorflow graph
    with tf.Session() as sess:
        
        # Run the initialization
        sess.run(init)
        
        # Do the training loop
        for epoch in range(num_epochs):

            minibatch_cost = 0.
            num_minibatches = int(m / minibatch_size) # number of minibatches of size minibatch_size in the train set
            seed = seed + 1
            minibatches = random_mini_batches(X_train, Y_train, minibatch_size, seed)

            for minibatch in minibatches:

                # Select a minibatch
                (minibatch_X, minibatch_Y) = minibatch
                # IMPORTANT: The line that runs the graph on a minibatch.
                # Run the session to execute the optimizer and the cost, the feedict should contain a minibatch for (X,Y).
                ### START CODE HERE ### (1 line)
                _ , temp_cost =  sess.run([optimizer,cost],feed_dict={X:minibatch_X, Y:minibatch_Y})
                ### END CODE HERE ###
                
                minibatch_cost += temp_cost / num_minibatches
                
            predict_op = tf.argmax(Z3, 1)
            correct_prediction = tf.equal(predict_op, tf.argmax(Y, 1))

            # Calculate accuracy on the test set
            accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))
            train_accuracy = accuracy.eval({X: X_train, Y: Y_train})
            test_accuracy = accuracy.eval({X: X_test, Y: Y_test})
            
            # Print the cost every epoch
            if print_cost == True and epoch % 5 == 0:
                print ("Cost after epoch %i: %f" % (epoch, minibatch_cost))
                print("Train Accuracy:", train_accuracy)
                print("Test Accuracy:", test_accuracy)
            if print_cost == True and epoch % 1 == 0:
                costs.append(minibatch_cost)
            if test_accuracy >0.94:
                break
           
        
        
        # plot the cost
        plt.plot(np.squeeze(costs))
        plt.ylabel('cost')
        plt.xlabel('iterations (per tens)')
        plt.title("Learning rate =" + str(learning_rate))
        plt.show()

        # Calculate the correct predictions
        #predict_op = tf.argmax(Z3, 1)
        #correct_prediction = tf.equal(predict_op, tf.argmax(Y, 1))
        
        # Calculate accuracy on the test set
        #accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))
        #print(accuracy)
        #train_accuracy = accuracy.eval({X: X_train, Y: Y_train})
        #test_accuracy = accuracy.eval({X: X_test, Y: Y_test})
        #print("Train Accuracy:", train_accuracy)
        #print("Test Accuracy:", test_accuracy)
                
        return train_accuracy, test_accuracy, parameters

# %%
_, _, parameters = model(X_train, Y_train, X_test, Y_test)
# Out:
# Cost after epoch 0: 1.927042
# Train Accuracy: 0.15185185
# Test Accuracy: 0.15833333
# Cost after epoch 5: 1.906419
# Train Accuracy: 0.18888889
# Test Accuracy: 0.19166666
# Cost after epoch 10: 1.649267
# Train Accuracy: 0.41759259
# Test Accuracy: 0.39166668
# Cost after epoch 15: 1.238018
# Train Accuracy: 0.63703704
# Test Accuracy: 0.6
# Cost after epoch 20: 0.923319
# Train Accuracy: 0.76203704
# Test Accuracy: 0.71666664
# Cost after epoch 25: 0.703411
# Train Accuracy: 0.8138889
# Test Accuracy: 0.8
# Cost after epoch 30: 0.653558
# Train Accuracy: 0.80185187
# Test Accuracy: 0.775
# Cost after epoch 35: 0.567019
# Train Accuracy: 0.837963
# Test Accuracy: 0.85
# Cost after epoch 40: 0.504821
# Train Accuracy: 0.8824074
# Test Accuracy: 0.7916667
# Cost after epoch 45: 0.442252
# Train Accuracy: 0.84166664
# Test Accuracy: 0.7583333
# Cost after epoch 50: 0.429899
# Train Accuracy: 0.84166664
# Test Accuracy: 0.80833334
# Cost after epoch 55: 0.401475
# Train Accuracy: 0.9287037
# Test Accuracy: 0.84166664
# Cost after epoch 60: 0.318628
# Train Accuracy: 0.8972222
# Test Accuracy: 0.84166664
# Cost after epoch 65: 0.286007
# Train Accuracy: 0.9203704
# Test Accuracy: 0.81666666
# Cost after epoch 70: 0.270656
# Train Accuracy: 0.89444447
# Test Accuracy: 0.8333333
# Cost after epoch 75: 0.217289
# Train Accuracy: 0.962037
# Test Accuracy: 0.89166665
# Cost after epoch 80: 0.222015
# Train Accuracy: 0.93796295
# Test Accuracy: 0.825
# Cost after epoch 85: 0.172826
# Train Accuracy: 0.9824074
# Test Accuracy: 0.8666667
# Cost after epoch 90: 0.180810
# Train Accuracy: 0.9814815
# Test Accuracy: 0.85833335
# Cost after epoch 95: 0.387941
# Train Accuracy: 0.98425925
# Test Accuracy: 0.89166665
# Cost after epoch 100: 0.220149
# Train Accuracy: 0.97407407
# Test Accuracy: 0.8666667
# Cost after epoch 105: 0.259559
# Train Accuracy: 0.9925926
# Test Accuracy: 0.89166665
# Cost after epoch 110: 0.113485
# Train Accuracy: 0.92777777
# Test Accuracy: 0.8
# Cost after epoch 115: 0.139674
# Train Accuracy: 0.9490741
# Test Accuracy: 0.84166664
# Cost after epoch 120: 0.242646
# Train Accuracy: 0.9814815
# Test Accuracy: 0.875
# Cost after epoch 125: 0.072356
# Train Accuracy: 0.98796296
# Test Accuracy: 0.8666667
# Cost after epoch 130: 0.085061
# Train Accuracy: 0.9962963
# Test Accuracy: 0.875
# Cost after epoch 135: 0.034687
# Train Accuracy: 0.95648146
# Test Accuracy: 0.85833335
# Cost after epoch 140: 0.257312
# Train Accuracy: 0.9962963
# Test Accuracy: 0.875
# Cost after epoch 145: 0.021947
# Train Accuracy: 0.9916667
# Test Accuracy: 0.85833335
# Cost after epoch 150: 0.220865
# Train Accuracy: 0.99444443
# Test Accuracy: 0.8833333
# Cost after epoch 155: 0.029356
# Train Accuracy: 0.7740741
# Test Accuracy: 0.78333336
# Cost after epoch 160: 0.017210
# Train Accuracy: 0.96944445
# Test Accuracy: 0.85
# Cost after epoch 165: 0.035196
# Train Accuracy: 0.85462964
# Test Accuracy: 0.7916667
# Cost after epoch 170: 0.028185
# Train Accuracy: 0.9814815
# Test Accuracy: 0.9
# Cost after epoch 175: 0.020934
# Train Accuracy: 0.9953704
# Test Accuracy: 0.9166667
# Cost after epoch 180: 0.009571
# Train Accuracy: 0.962037
# Test Accuracy: 0.8666667
# Cost after epoch 185: 0.209270
# Train Accuracy: 0.9953704
# Test Accuracy: 0.89166665
# Cost after epoch 190: 0.008566
# Train Accuracy: 0.9361111
# Test Accuracy: 0.85
# Cost after epoch 195: 0.209923
# Train Accuracy: 0.9953704
# Test Accuracy: 0.90833336
# Cost after epoch 200: 0.020950
# Train Accuracy: 0.91481483
# Test Accuracy: 0.8333333
# Cost after epoch 205: 0.018346
# Train Accuracy: 0.97962964
# Test Accuracy: 0.89166665
# Cost after epoch 210: 0.004871
# Train Accuracy: 0.92314816
# Test Accuracy: 0.84166664
# Cost after epoch 215: 0.228191
# Train Accuracy: 0.7574074
# Test Accuracy: 0.71666664
# Cost after epoch 220: 0.047650
# Train Accuracy: 0.94166666
# Test Accuracy: 0.84166664
# Cost after epoch 225: 0.257527
# Train Accuracy: 0.9759259
# Test Accuracy: 0.9
# Cost after epoch 230: 0.002691
# Train Accuracy: 1.0
# Test Accuracy: 0.89166665
# Cost after epoch 235: 0.202991
# Train Accuracy: 0.99814814
# Test Accuracy: 0.9166667
# Cost after epoch 240: 0.004070
# Train Accuracy: 1.0
# Test Accuracy: 0.90833336
# Cost after epoch 245: 0.002801
# Train Accuracy: 1.0
# Test Accuracy: 0.925
# Cost after epoch 250: 0.014758
# Train Accuracy: 0.9990741
# Test Accuracy: 0.9166667
# Cost after epoch 255: 0.066961
# Train Accuracy: 1.0
# Test Accuracy: 0.90833336
# Cost after epoch 260: 0.023555
# Train Accuracy: 1.0
# Test Accuracy: 0.90833336
# Cost after epoch 265: 0.138927
# Train Accuracy: 0.9990741
# Test Accuracy: 0.9166667
# Cost after epoch 270: 0.001643
# Train Accuracy: 0.90185183
# Test Accuracy: 0.825
# Cost after epoch 275: 0.020252
# Train Accuracy: 1.0
# Test Accuracy: 0.925
# Cost after epoch 280: 0.208637
# Train Accuracy: 0.99814814
# Test Accuracy: 0.90833336
# Cost after epoch 285: 0.059347
# Train Accuracy: 0.99814814
# Test Accuracy: 0.9
# Cost after epoch 290: 0.000937
# Train Accuracy: 1.0
# Test Accuracy: 0.9
# Cost after epoch 295: 0.284846
# Train Accuracy: 0.9546296
# Test Accuracy: 0.85
# Cost after epoch 300: 0.352601
# Train Accuracy: 0.9990741
# Test Accuracy: 0.925
# Cost after epoch 305: 0.014313
# Train Accuracy: 1.0
# Test Accuracy: 0.89166665
# Cost after epoch 310: 0.139181
# Train Accuracy: 1.0
# Test Accuracy: 0.9166667
# Cost after epoch 315: 0.001763
# Train Accuracy: 0.9990741
# Test Accuracy: 0.93333334
# Cost after epoch 320: 0.035396
# Train Accuracy: 0.99722224
# Test Accuracy: 0.89166665
# Cost after epoch 325: 0.208142
# Train Accuracy: 1.0
# Test Accuracy: 0.90833336
# Cost after epoch 330: 0.002646
# Train Accuracy: 0.9907407
# Test Accuracy: 0.89166665
# Cost after epoch 335: 0.005509
# Train Accuracy: 0.96944445
# Test Accuracy: 0.9
# Cost after epoch 340: 0.002882
# Train Accuracy: 0.9990741
# Test Accuracy: 0.9
# Cost after epoch 345: 0.036239
# Train Accuracy: 1.0
# Test Accuracy: 0.925
# Cost after epoch 350: 0.001319
# Train Accuracy: 1.0
# Test Accuracy: 0.90833336
# Cost after epoch 355: 0.149671
# Train Accuracy: 0.75555557
# Test Accuracy: 0.76666665
# Cost after epoch 360: 0.418446
# Train Accuracy: 1.0
# Test Accuracy: 0.9166667
# Cost after epoch 365: 0.013316
# Train Accuracy: 0.8194444
# Test Accuracy: 0.78333336
# Cost after epoch 370: 0.023591
# Train Accuracy: 0.99814814
# Test Accuracy: 0.8833333
# Cost after epoch 375: 0.000604
# Train Accuracy: 1.0
# Test Accuracy: 0.9
# Cost after epoch 380: 0.000586
# Train Accuracy: 1.0
# Test Accuracy: 0.9
# Cost after epoch 385: 0.026889
# Train Accuracy: 0.97962964
# Test Accuracy: 0.8833333
# Cost after epoch 390: 0.027799
# Train Accuracy: 1.0
# Test Accuracy: 0.9
# Cost after epoch 395: 0.163517
# Train Accuracy: 0.9990741
# Test Accuracy: 0.89166665
